# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
nuc_rotated_DNAcycP_pred = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/nuc_rotated_cycle_norm_DNAcycP.txt", header=None)
nuc_rotated = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/ir_lstm_smooth_104bp_cn_mean2_tiling_nuc_rotated_predictions.csv")

nuc_DNAcycP_pred = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/cycle1_cycle_norm_DNAcycP.txt", header=None)
nuc = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/ir_lstm_smooth_104bp_cn_mean2_tiling_cycle1_predictions.csv")

# %%
nuc_rotated["DNAcycP_pred"] = nuc_rotated_DNAcycP_pred
nuc["DNAcycP_pred"] = nuc_DNAcycP_pred

nuc_rotated["DNAcycP_rotation_pred_abs_difference"] = abs(nuc_rotated["DNAcycP_pred"] - nuc["DNAcycP_pred"])
nuc_rotated["DNAcycP_rotation_pred_difference"] = nuc_rotated["DNAcycP_pred"] - nuc["DNAcycP_pred"]
nuc_rotated["smooth_rotation_pred_abs_difference"] = abs(nuc_rotated["smooth_10.4bp_cn_mean2_predictions"] - nuc["smooth_10.4bp_cn_mean2_predictions"])
nuc_rotated["smooth_rotation_pred_difference"] = nuc_rotated["smooth_10.4bp_cn_mean2_predictions"] - nuc["smooth_10.4bp_cn_mean2_predictions"]

# %%
print(f'Nucleosome Library correlation between DNAcycP predicted rotated sequences and Original C0: \n \t{np.corrcoef(nuc_rotated["DNAcycP_pred"], nuc_rotated["C0"])[0,1]}')
print(f'Nucleosome Library correlation between DNAcycP predicted rotated sequences and DNAcycP predicted original sequences: \n \t{np.corrcoef(random_rotated["DNAcycP_pred"], random["DNAcycP_pred"])[0,1]}')

print()

print(f'Nucleosome Library correlation between DNAcycP predicted rotated sequences and Raw C26: \n \t{np.corrcoef(nuc_rotated["DNAcycP_pred"], nuc_rotated["n=26"])[0,1]}')
print(f'Nucleosome Library correlation between DNAcycP predicted rotated sequences and Raw C29: \n \t{np.corrcoef(nuc_rotated["DNAcycP_pred"], nuc_rotated["n=29"])[0,1]}')
print(f'Nucleosome Library correlation between DNAcycP predicted rotated sequences and Raw C31: \n \t{np.corrcoef(nuc_rotated["DNAcycP_pred"], nuc_rotated["n=31"])[0,1]}')
# Out:
# Nucleosome Library correlation between DNAcycP predicted rotated sequences and Original C0:
#  	0.6141073714560671
# Nucleosome Library correlation between DNAcycP predicted rotated sequences and DNAcycP predicted original sequences:
#  	0.6778467098172032
#
# Nucleosome Library correlation between DNAcycP predicted rotated sequences and Raw C26:
#  	0.5784096914300855
# Nucleosome Library correlation between DNAcycP predicted rotated sequences and Raw C29:
#  	0.44088256422074096
# Nucleosome Library correlation between DNAcycP predicted rotated sequences and Raw C31:
#  	0.3516064486721448

# %%
print(f'Nucleosome Library correlation between smoothC0 predicted rotated sequences and Original C0: \n \t{np.corrcoef(nuc_rotated["smooth_10.4bp_cn_mean2_predictions"], nuc_rotated["C0"])[0,1]}')
print(f'Nucleosome Library correlation between smoothC0 predicted rotated sequences and smoothC0 predicted original sequences: \n \t{np.corrcoef(nuc_rotated["smooth_10.4bp_cn_mean2_predictions"], nuc["smooth_10.4bp_cn_mean2_predictions"])[0,1]}')

print()

print(f'Nucleosome Library correlation between smoothC0 predicted rotated sequences and Raw C26: \n \t{np.corrcoef(nuc_rotated["smooth_10.4bp_cn_mean2_predictions"], nuc_rotated["n=26"])[0,1]}')
print(f'Nucleosome Library correlation between smoothC0 predicted rotated sequences and Raw C29: \n \t{np.corrcoef(nuc_rotated["smooth_10.4bp_cn_mean2_predictions"], nuc_rotated["n=29"])[0,1]}')
print(f'Nucleosome Library correlation between smoothC0 predicted rotated sequences and Raw C31: \n \t{np.corrcoef(nuc_rotated["smooth_10.4bp_cn_mean2_predictions"], nuc_rotated["n=31"])[0,1]}')
# Out:
# Nucleosome Library correlation between smoothC0 predicted rotated sequences and Original C0:
#  	0.6287908353736091
# Nucleosome Library correlation between smoothC0 predicted rotated sequences and smoothC0 predicted original sequences:
#  	0.712819327274481
#
# Nucleosome Library correlation between smoothC0 predicted rotated sequences and Raw C26:
#  	0.5864614099370192
# Nucleosome Library correlation between smoothC0 predicted rotated sequences and Raw C29:
#  	0.4512358646056292
# Nucleosome Library correlation between smoothC0 predicted rotated sequences and Raw C31:
#  	0.36841613226419845

# %%
print(f'Nucleosome Library correlation between DNAcycP predicted rotated sequences and smoothC0 predicted rotated sequences: \n \t{np.corrcoef(nuc_rotated["DNAcycP_pred"], nuc_rotated["smooth_10.4bp_cn_mean2_predictions"])[0,1]}')
# Out:
# Nucleosome Library correlation between DNAcycP predicted rotated sequences and smoothC0 predicted rotated sequences:
#  	0.9670844211389069

# %%
plt.figure(figsize=(12,7))
plt.scatter(nuc_rotated["rotation_values"]%10, nuc_rotated["DNAcycP_rotation_pred_difference"], alpha=0.1)
plt.xlabel("Rotation Value")
plt.ylabel("Difference in Predicted Values (Rotated vs Original)")
plt.title("Nucleosome Library, DNAcycP")
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.scatter(nuc_rotated["rotation_values"]%10, nuc_rotated["smooth_rotation_pred_difference"], alpha=0.1)
plt.xlabel("Rotation Value")
plt.ylabel("Difference in Predicted Values (Rotated vs Original)")
plt.title("Nucleosome Library, Smooth C0")
# plt.grid(axis="x")
plt.show()

# %%
random_rotated_DNAcycP_pred = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/random_rotated_cycle_norm_DNAcycP.txt", header=None)
random_rotated = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/ir_lstm_smooth_104bp_cn_mean2_tiling_random_rotated_predictions.csv")

random_DNAcycP_pred = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/cycle3_cycle_norm_DNAcycP.txt", header=None)
random = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/ir_lstm_smooth_104bp_cn_mean2_tiling_cycle3_predictions.csv")

# %%
random_rotated["DNAcycP_pred"] = random_rotated_DNAcycP_pred
random["DNAcycP_pred"] = random_DNAcycP_pred

random_rotated["DNAcycP_rotation_pred_abs_difference"] = abs(random_rotated["DNAcycP_pred"] - random["DNAcycP_pred"])
random_rotated["DNAcycP_rotation_pred_difference"] = random_rotated["DNAcycP_pred"] - random["DNAcycP_pred"]
random_rotated["smooth_rotation_pred_abs_difference"] = abs(random_rotated["smooth_10.4bp_cn_mean2_predictions"] - random["smooth_10.4bp_cn_mean2_predictions"])
random_rotated["smooth_rotation_pred_difference"] = random_rotated["smooth_10.4bp_cn_mean2_predictions"] - random["smooth_10.4bp_cn_mean2_predictions"]

# %%
print(f'Random Library correlation between DNAcycP predicted rotated sequences and Original C0: \n \t{np.corrcoef(random_rotated["DNAcycP_pred"], random_rotated["C0"])[0,1]}')
print(f'Random Library correlation between DNAcycP predicted rotated sequences and DNAcycP predicted original sequences: \n \t{np.corrcoef(random_rotated["DNAcycP_pred"], random["DNAcycP_pred"])[0,1]}')

print()

print(f'Random Library correlation between DNAcycP predicted rotated sequences and Raw C26: \n \t{np.corrcoef(random_rotated["DNAcycP_pred"], random_rotated["n=26"])[0,1]}')
print(f'Random Library correlation between DNAcycP predicted rotated sequences and Raw C29: \n \t{np.corrcoef(random_rotated["DNAcycP_pred"], random_rotated["n=29"])[0,1]}')
print(f'Random Library correlation between DNAcycP predicted rotated sequences and Raw C31: \n \t{np.corrcoef(random_rotated["DNAcycP_pred"], random_rotated["n=31"])[0,1]}')
# Out:
# Random Library correlation between DNAcycP predicted rotated sequences and Original C0:
#  	0.6446677878961105
# Random Library correlation between DNAcycP predicted rotated sequences and DNAcycP predicted original sequences:
#  	0.6778467098172032
#
# Random Library correlation between DNAcycP predicted rotated sequences and Raw C26:
#  	0.5297579730206431
# Random Library correlation between DNAcycP predicted rotated sequences and Raw C29:
#  	0.4311874776302121
# Random Library correlation between DNAcycP predicted rotated sequences and Raw C31:
#  	0.4430033457232113

# %%
print(f'Random Library correlation between smoothC0 predicted rotated sequences and Original C0: \n \t{np.corrcoef(random_rotated["smooth_10.4bp_cn_mean2_predictions"], random_rotated["C0"])[0,1]}')
print(f'Random Library correlation between smoothC0 predicted rotated sequences and smoothC0 predicted original sequences: \n \t{np.corrcoef(random_rotated["smooth_10.4bp_cn_mean2_predictions"], random["smooth_10.4bp_cn_mean2_predictions"])[0,1]}')

print()

print(f'Random Library correlation between smoothC0 predicted rotated sequences and Raw C26: \n \t{np.corrcoef(random_rotated["smooth_10.4bp_cn_mean2_predictions"], random_rotated["n=26"])[0,1]}')
print(f'Random Library correlation between smoothC0 predicted rotated sequences and Raw C29: \n \t{np.corrcoef(random_rotated["smooth_10.4bp_cn_mean2_predictions"], random_rotated["n=29"])[0,1]}')
print(f'Random Library correlation between smoothC0 predicted rotated sequences and Raw C31: \n \t{np.corrcoef(random_rotated["smooth_10.4bp_cn_mean2_predictions"], random_rotated["n=31"])[0,1]}')
# Out:
# Random Library correlation between smoothC0 predicted rotated sequences and Original C0:
#  	0.658847639701129
# Random Library correlation between smoothC0 predicted rotated sequences and smoothC0 predicted original sequences:
#  	0.7118822255080336
#
# Random Library correlation between smoothC0 predicted rotated sequences and Raw C26:
#  	0.5397981098954013
# Random Library correlation between smoothC0 predicted rotated sequences and Raw C29:
#  	0.43652457841211606
# Random Library correlation between smoothC0 predicted rotated sequences and Raw C31:
#  	0.4541047510784659

# %%
print(f'Random Library correlation between DNAcycP predicted rotated sequences and smoothC0 predicted rotated sequences: \n \t{np.corrcoef(random_rotated["DNAcycP_pred"], random_rotated["smooth_10.4bp_cn_mean2_predictions"])[0,1]}')
# Out:
# Random Library correlation between DNAcycP predicted rotated sequences and smoothC0 predicted rotated sequences:
#  	0.96437082920504

# %%
plt.figure(figsize=(12,7))
plt.scatter(random_rotated["rotation_values"], random_rotated["DNAcycP_rotation_pred_difference"], alpha=0.1)
plt.xlabel("Rotation Value")
plt.ylabel("Difference in Predicted Values (Rotated vs Original)")
plt.title("Random Library, DNAcycP")
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.scatter(random_rotated["rotation_values"], random_rotated["smooth_rotation_pred_difference"], alpha=0.1)
plt.xlabel("Rotation Value")
plt.ylabel("Difference in Predicted Values (Rotated vs Original)")
plt.title("Random Library, Smooth C0")
plt.show()

# %%
tiling_rotated_DNAcycP_pred = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/tiling_rotated_cycle_norm_DNAcycP.txt", header=None)
tiling_rotated = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/ir_lstm_smooth_104bp_cn_mean2_tiling_tiling_rotated_predictions.csv")

# tiling_DNAcycP_pred = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/cycle5_cycle_norm_DNAcycP.txt", header=None)
tiling = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/ir_lstm_smooth_104bp_cn_mean2_tiling_cycle5_predictions.csv")

# %%
tiling_rotated["DNAcycP_pred"] = tiling_rotated_DNAcycP_pred
# tiling["DNAcycP_pred"] = tiling_DNAcycP_pred

# tiling_rotated["DNAcycP_rotation_pred_abs_difference"] = abs(tiling_rotated["DNAcycP_pred"] - tiling["DNAcycP_pred"])
tiling_rotated["smooth_rotation_pred_abs_difference"] = abs(tiling_rotated["smooth_10.4bp_cn_mean2_predictions"] - tiling["smooth_10.4bp_cn_mean2_predictions"])
tiling_rotated["smooth_rotation_pred_difference"] = tiling_rotated["smooth_10.4bp_cn_mean2_predictions"] - tiling["smooth_10.4bp_cn_mean2_predictions"]

# %%
print(f'Tiling Library correlation between DNAcycP predicted rotated sequences and Original C0: \n \t{np.corrcoef(tiling_rotated["DNAcycP_pred"], tiling_rotated["C0"])[0,1]}')
# print(f'Tiling Library correlation between DNAcycP predicted rotated sequences and DNAcycP predicted original sequences: \n \t{np.corrcoef(tiling_rotated["DNAcycP_pred"], tiling["DNAcycP_pred"])[0,1]}')

print()

print(f'Tiling Library correlation between DNAcycP predicted rotated sequences and Raw C26: \n \t{np.corrcoef(tiling_rotated["DNAcycP_pred"], tiling_rotated["n=26"])[0,1]}')
print(f'Tiling Library correlation between DNAcycP predicted rotated sequences and Raw C29: \n \t{np.corrcoef(tiling_rotated["DNAcycP_pred"], tiling_rotated["n=29"])[0,1]}')
print(f'Tiling Library correlation between DNAcycP predicted rotated sequences and Raw C31: \n \t{np.corrcoef(tiling_rotated["DNAcycP_pred"], tiling_rotated["n=31"])[0,1]}')
# Out:
# Tiling Library correlation between DNAcycP predicted rotated sequences and Original C0:
#  	0.6404435087894887
#
# Tiling Library correlation between DNAcycP predicted rotated sequences and Raw C26:
#  	0.5222633559220846
# Tiling Library correlation between DNAcycP predicted rotated sequences and Raw C29:
#  	0.4697326242052282
# Tiling Library correlation between DNAcycP predicted rotated sequences and Raw C31:
#  	0.49521252324493786

# %%
print(f'Tiling Library correlation between smoothC0 predicted rotated sequences and Original C0: \n \t{np.corrcoef(tiling_rotated["smooth_10.4bp_cn_mean2_predictions"], tiling_rotated["C0"])[0,1]}')
print(f'Tiling Library correlation between smoothC0 predicted rotated sequences and DNAcycP predicted original sequences: \n \t{np.corrcoef(tiling_rotated["smooth_10.4bp_cn_mean2_predictions"], tiling["smooth_10.4bp_cn_mean2_predictions"])[0,1]}')

print()

print(f'Tiling Library correlation between smoothC0 predicted rotated sequences and Raw C26: \n \t{np.corrcoef(tiling_rotated["smooth_10.4bp_cn_mean2_predictions"], tiling_rotated["n=26"])[0,1]}')
print(f'Tiling Library correlation between smoothC0 predicted rotated sequences and Raw C29: \n \t{np.corrcoef(tiling_rotated["smooth_10.4bp_cn_mean2_predictions"], tiling_rotated["n=29"])[0,1]}')
print(f'Tiling Library correlation between smoothC0 predicted rotated sequences and Raw C31: \n \t{np.corrcoef(tiling_rotated["smooth_10.4bp_cn_mean2_predictions"], tiling_rotated["n=31"])[0,1]}')
# Out:
# Tiling Library correlation between smoothC0 predicted rotated sequences and Original C0:
#  	0.6576936344471659
# Tiling Library correlation between smoothC0 predicted rotated sequences and DNAcycP predicted original sequences:
#  	0.7286857033164647
#
# Tiling Library correlation between smoothC0 predicted rotated sequences and Raw C26:
#  	0.5346508302721331
# Tiling Library correlation between smoothC0 predicted rotated sequences and Raw C29:
#  	0.4832855828794335
# Tiling Library correlation between smoothC0 predicted rotated sequences and Raw C31:
#  	0.5107089727051054

# %%
print(f'Tiling Library correlation between DNAcycP predicted rotated sequences and smoothC0 predicted rotated sequences: \n \t{np.corrcoef(tiling_rotated["DNAcycP_pred"], tiling_rotated["smooth_10.4bp_cn_mean2_predictions"])[0,1]}')
# Out:
# Tiling Library correlation between DNAcycP predicted rotated sequences and smoothC0 predicted rotated sequences:
#  	0.9681626849472086

# %%
# plt.figure(figsize=(12,7))
# plt.scatter(tiling_rotated["rotation_values"], tiling_rotated["DNAcycP_rotation_pred_difference"], alpha=0.05)
# plt.xlabel("Rotation Value")
# plt.ylabel("Difference in Predicted Values (Rotated vs Original)")
# plt.title("Tiling Library")

# %%
plt.figure(figsize=(12,7))
plt.scatter(tiling_rotated["rotation_values"], tiling_rotated["smooth_rotation_pred_difference"], alpha=0.05)
plt.xlabel("Rotation Value")
plt.ylabel("Difference in Predicted Values (Rotated vs Original)")
plt.title("Tiling Library")
# Out:
# Text(0.5, 1.0, 'Tiling Library')

# %%
chrv_rotated_DNAcycP_pred = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/chrv_rotated_cycle_norm_DNAcycP.txt", header=None)
chrv_rotated = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/ir_lstm_smooth_104bp_cn_mean2_tiling_chrv_rotated_predictions.csv")

chrv_DNAcycP_pred = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/cycle6_cycle_norm_DNAcycP.txt", header=None)
chrv = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/data/predictions/ir_lstm_smooth_104bp_cn_mean2_tiling_cycle6_predictions.csv")

# %%
chrv_rotated["DNAcycP_pred"] = chrv_rotated_DNAcycP_pred
chrv["DNAcycP_pred"] = chrv_DNAcycP_pred

# %%
print(f'ChrV Library correlation between DNAcycP predicted rotated sequences and Original C0: \n \t{np.corrcoef(chrv_rotated["DNAcycP_pred"], chrv_rotated["C0"])[0,1]}')
print(f'ChrV Library correlation between DNAcycP predicted rotated sequences and DNAcycP predicted original sequences: \n \t{np.corrcoef(chrv_rotated["DNAcycP_pred"], chrv["DNAcycP_pred"])[0,1]}')

print()

print(f'ChrV Library correlation between DNAcycP predicted rotated sequences and Raw C26: \n \t{np.corrcoef(chrv_rotated["DNAcycP_pred"], chrv_rotated["n=26"])[0,1]}')
print(f'ChrV Library correlation between DNAcycP predicted rotated sequences and Raw C29: \n \t{np.corrcoef(chrv_rotated["DNAcycP_pred"], chrv_rotated["n=29"])[0,1]}')
print(f'ChrV Library correlation between DNAcycP predicted rotated sequences and Raw C31: \n \t{np.corrcoef(chrv_rotated["DNAcycP_pred"], chrv_rotated["n=31"])[0,1]}')
# Out:
# ChrV Library correlation between DNAcycP predicted rotated sequences and Original C0:
#  	0.5255000613116951
# ChrV Library correlation between DNAcycP predicted rotated sequences and DNAcycP predicted original sequences:
#  	0.6720188937604729
#
# ChrV Library correlation between DNAcycP predicted rotated sequences and Raw C26:
#  	0.4148426912866894
# ChrV Library correlation between DNAcycP predicted rotated sequences and Raw C29:
#  	0.386382862160986
# ChrV Library correlation between DNAcycP predicted rotated sequences and Raw C31:
#  	0.40977806246337933

# %%
print(f'ChrV Library correlation between smoothC0 predicted rotated sequences and Original C0: \n \t{np.corrcoef(chrv_rotated["smooth_10.4bp_cn_mean2_predictions"], chrv_rotated["C0"])[0,1]}')
print(f'ChrV Library correlation between smoothC0 predicted rotated sequences and smoothC0 predicted original sequences: \n \t{np.corrcoef(chrv_rotated["smooth_10.4bp_cn_mean2_predictions"], chrv["smooth_10.4bp_cn_mean2_predictions"])[0,1]}')

print()

print(f'ChrV Library correlation between smoothC0 predicted rotated sequences and Raw C26: \n \t{np.corrcoef(chrv_rotated["smooth_10.4bp_cn_mean2_predictions"], chrv_rotated["n=26"])[0,1]}')
print(f'ChrV Library correlation between smoothC0 predicted rotated sequences and Raw C29: \n \t{np.corrcoef(chrv_rotated["smooth_10.4bp_cn_mean2_predictions"], chrv_rotated["n=29"])[0,1]}')
print(f'ChrV Library correlation between smoothC0 predicted rotated sequences and Raw C31: \n \t{np.corrcoef(chrv_rotated["smooth_10.4bp_cn_mean2_predictions"], chrv_rotated["n=31"])[0,1]}')
# Out:
# ChrV Library correlation between smoothC0 predicted rotated sequences and Original C0:
#  	0.539876289856259
# ChrV Library correlation between smoothC0 predicted rotated sequences and smoothC0 predicted original sequences:
#  	0.71346173395291
#
# ChrV Library correlation between smoothC0 predicted rotated sequences and Raw C26:
#  	0.4253124410813584
# ChrV Library correlation between smoothC0 predicted rotated sequences and Raw C29:
#  	0.3968162140513437
# ChrV Library correlation between smoothC0 predicted rotated sequences and Raw C31:
#  	0.4221495715892434
