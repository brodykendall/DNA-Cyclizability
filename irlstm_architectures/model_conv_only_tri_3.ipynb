# %%
import time
import keras

from keras.models import Model
from keras.layers import Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Add, Concatenate
from keras.layers import Dense, Conv2D, MaxPooling2D, LSTM, TimeDistributed, Reshape
import keras.backend as K
import keras.callbacks as callbacks

import pandas as pd
import numpy as np
from numpy import array
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
# Out:
# 2023-04-12 11:20:28.817384: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
save_path = "/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/"
model_name = "conv_only_tri_3"
kf = KFold(n_splits = 10, shuffle =True)
num_epochs = 10

#### define functions ####

def model_cycle():
    inputs = Input(shape=(48, 64, 1))
        
    x = Conv2D(48, kernel_size=(41,64),
                   activation='relu',
                   padding='valid')(inputs)
    x = MaxPooling2D((2,1),padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # print(f"After first convolutional layer: x.shape = {x.shape}")

    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = Conv1D(48, kernel_size=(11),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After second convolutional layer: x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((24,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After third convolutional layer, x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((12,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # # parallel line 1
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(fx1)
    # fx1 = MaxPooling2D((2,1),padding='same')(fx1)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    
    # # parallel line 2
    # fx2 = Conv2D(48, kernel_size=(11,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    # fx2 = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(fx2)
    # fx2 = MaxPooling2D((2,1),padding='same')(fx2)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    
    # # # Add
    # x1 = Concatenate(axis=-3)([fx1, fx2])
    # x = Add()([x, x1])
    # x = MaxPooling2D((2,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    
    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = LSTM(20, return_sequences=False)(x)
    # x = Dropout(0.2)(x)

    # x = Reshape((1, 24*48))(x)
    x = Flatten()(x)

    outputs = Dense(1, activation='linear')(x)
    # print(outputs.shape)
    network = Model(inputs, outputs)
    network.compile(optimizer='rmsprop',
                    loss='mean_squared_error')
    return network

# %%
def triOneHot(sequence):
    code = {"AAA": [0], "AAC": [1], "AAG": [2], "AAT": [3],
            "ACA": [4], "ACC": [5], "ACG": [6], "ACT": [7], 
            "AGA": [8], "AGC": [9], "AGG": [10], "AGT": [11], 
            "ATA": [12], "ATC": [13], "ATG": [14], "ATT": [15], 
            "CAA": [16], "CAC": [17], "CAG": [18], "CAT": [19], 
            "CCA": [20], "CCC": [21], "CCG": [22], "CCT": [23], 
            "CGA": [24], "CGC": [25], "CGG": [26], "CGT": [27], 
            "CTA": [28], "CTC": [29], "CTG": [30], "CTT": [31], 
            "GAA": [32], "GAC": [33], "GAG": [34], "GAT": [35],
            "GCA": [36], "GCC": [37], "GCG": [38], "GCT": [39], 
            "GGA": [40], "GGC": [41], "GGG": [42], "GGT": [43], 
            "GTA": [44], "GTC": [45], "GTG": [46], "GTT": [47], 
            "TAA": [48], "TAC": [49], "TAG": [50], "TAT": [51], 
            "TCA": [52], "TCC": [53], "TCG": [54], "TCT": [55], 
            "TGA": [56], "TGC": [57], "TGG": [58], "TGT": [59], 
            "TTA": [60], "TTC": [61], "TTG": [62], "TTT": [63],   "N": [64]}
    onehot_encoded_seq = []
    for i, _ in enumerate(sequence[:(len(sequence)-2)]):
        onehot_encoded = np.zeros(65)
        onehot_encoded[code[sequence[i:i+3]]] = 1
        onehot_encoded_seq.append(onehot_encoded[0:64])
    return onehot_encoded_seq

# %%
def display_fits(fits):
    print(f"Average correlation on tiling: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 5])}",
          f"\nAverage MSE on tiling: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 5])}",
          f"\nAverage correlation on random: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 3])}",
          f"\nAverage MSE on random: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 3])}",
          f"\nAverage correlation on ChrV: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 7])}",
          f"\nAverage MSE on ChrV: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 7])}",
          f"\nAverage correlation on CN: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 0])}",
          f"\nAverage MSE on CN: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 0])}")

# %%
def find_c0new(dat):
  mat = np.empty((3,3), float)
  k = 2*np.pi/10.4
  n = array([26, 29, 31])
  mat[0:3,0] = 1
  mat[0:3, 1] = np.sin(n*k)
  mat[0:3, 2] = np.cos(n*k)
  inv_mat = np.linalg.inv(mat)
  c0A1A2 = array(np.matmul(dat[["n=26", "n=29", "n=31"]], np.transpose(inv_mat)))
  c0Aphi = c0A1A2
  c0Aphi[:,0] = c0A1A2[:,0]
  c0Aphi[:,1] = np.sqrt(c0A1A2[:,1]**2 + c0A1A2[:,2]**2)
  c0Aphi[:,2] <- np.sign(c0A1A2[:,2]) * np.arccos(c0A1A2[:,1]/c0Aphi[:,1])
  return c0Aphi[:,0]

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.process_time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.process_time() - self.epoch_time_start)
        
#### preparing data ####

data_cerevisiae_nucle = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle1.txt",delimiter = ",")
X1 = []
for sequence_nt in data_cerevisiae_nucle["Sequence"]:
    X1.append(triOneHot(sequence_nt))
X1 = array(X1)
X1 = X1.reshape((X1.shape[0],48,64,1))
X1_reverse = np.flip(X1,[1,2])
# Y1 = data_cerevisiae_nucle["C0"].values.astype(float)
Y1 = find_c0new(data_cerevisiae_nucle).astype(float)

# %%
data_random_library = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle3.txt",delimiter = ",")
X3 = []
for sequence_nt in data_random_library["Sequence"]:
    X3.append(triOneHot(sequence_nt))
X3 = array(X3)
X3 = X3.reshape((X3.shape[0],48,64,1))
X3_reverse = np.flip(X3,[1,2])
# Y3 = data_random_library["C0"].values.astype(float)
Y3 = find_c0new(data_random_library).astype(float)

# %%
data_tiling = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle5.txt",delimiter = ",")
X5 = []
for sequence_nt in data_tiling["Sequence"]:
    X5.append(triOneHot(sequence_nt))
X5 = array(X5)
X5 = X5.reshape((X5.shape[0],48,64,1))
X5_reverse = np.flip(X5,[1,2])
# Y5 = data_tiling["C0"].values.astype(float)
Y5 = find_c0new(data_tiling).astype(float)

# %%
data_chr5 = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle6.txt",delimiter = ",")
X6 = []
for sequence_nt in data_chr5["Sequence"]:
    X6.append(triOneHot(sequence_nt))
X6 = array(X6)
X6 = X6.reshape((X6.shape[0],48,64,1))
X6_reverse = np.flip(X6,[1,2])
# Y6 = data_chr5["C0"].values.astype(float)
Y6 = find_c0new(data_chr5).astype(float)

# %%
#### tiling

VALIDATION_LOSS = []
fold_var = 1
n = Y5.shape[0]

fits = []
detrend = []
times = []
times2 = []

for train_index, val_index in kf.split(Y5):
    training_X = X5[train_index]
    training_X_reverse = X5_reverse[train_index]
    validation_X = X5[val_index]
    validation_X_reverse = X5_reverse[val_index]
    training_Y = Y5[train_index]
    validation_Y = Y5[val_index]
    # CREATE NEW MODEL
    model = model_cycle()
    # CREATE CALLBACKS
    checkpoint = callbacks.ModelCheckpoint(save_path + model_name+"_tiling_"+str(fold_var)+".h5",
                                                    monitor='val_loss', verbose=1,
                                                    save_best_only=True, mode='min')
    time_callback = TimeHistory()

    history = model.fit(training_X, training_Y,
                        epochs=num_epochs,
                        callbacks= [checkpoint, time_callback],
                        validation_data=(validation_X, validation_Y))
    model.load_weights(save_path + model_name+"_tiling_"+str(fold_var)+".h5")
    model.save(save_path+model_name+"_tiling_"+str(fold_var),save_traces=False)
    times.append(time_callback.times)

    pred_Y = model.predict(training_X)
    pred_Y = pred_Y.reshape(pred_Y.shape[0])
    pred_Y_reverse = model.predict(training_X_reverse)
    pred_Y_reverse = pred_Y_reverse.reshape(pred_Y_reverse.shape[0])
    pred_Y = (pred_Y+pred_Y_reverse)/2
    reg =  LinearRegression().fit(array(pred_Y).reshape(-1, 1), array(training_Y).reshape(-1, 1))
    
    detrend_int = reg.intercept_
    detrend_slope = reg.coef_
    detrend.append([float(detrend_int), float(detrend_slope)])

    start_time = time.process_time()
    fit = model.predict(X1)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X1_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X3)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X3_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(validation_X)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(validation_X_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X6)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X6_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    K.clear_session()
    fold_var += 1
    
detrend = array(detrend)
detrend = pd.DataFrame(detrend)
detrend.to_csv(save_path +model_name+"_detrend_tiling.txt", index = False)

fits = array(fits)
fits = pd.DataFrame((fits))
fits.to_csv(save_path +model_name+ "_fits_tiling.txt", index = False)

with open(save_path +model_name+"_time_tiling.txt", "w") as file:
    for row in times:
        s = " ".join(map(str, row))
        file.write(s+'\n')

with open(save_path +model_name+"_pred_time_tiling.txt", "w") as file:
    for row in times2:
        s = " ".join(map(str, row))
        file.write(s+'\n')
# Out:
# 2023-04-12 11:21:39.185461: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1514
# Epoch 1: val_loss improved from inf to 0.08994, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_1.h5
# 2317/2317 [==============================] - 11s 4ms/step - loss: 0.1512 - val_loss: 0.0899
# Epoch 2/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1013
# Epoch 2: val_loss improved from 0.08994 to 0.08457, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_1.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1013 - val_loss: 0.0846
# Epoch 3/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.0953
# Epoch 3: val_loss improved from 0.08457 to 0.08179, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_1.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0953 - val_loss: 0.0818
# Epoch 4/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.0912
# Epoch 4: val_loss improved from 0.08179 to 0.08006, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_1.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0912 - val_loss: 0.0801
# Epoch 5/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0873
# Epoch 5: val_loss improved from 0.08006 to 0.07998, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_1.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0873 - val_loss: 0.0800
# Epoch 6/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0847
# Epoch 6: val_loss improved from 0.07998 to 0.07961, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_1.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0846 - val_loss: 0.0796
# Epoch 7/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0833
# Epoch 7: val_loss improved from 0.07961 to 0.07878, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_1.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0833 - val_loss: 0.0788
# Epoch 8/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.0812
# Epoch 8: val_loss did not improve from 0.07878
# 2317/2317 [==============================] - 18s 8ms/step - loss: 0.0811 - val_loss: 0.0796
# Epoch 9/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.0796
# Epoch 9: val_loss did not improve from 0.07878
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.0797 - val_loss: 0.0803
# Epoch 10/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0774
# Epoch 10: val_loss did not improve from 0.07878
# 2317/2317 [==============================] - 16s 7ms/step - loss: 0.0774 - val_loss: 0.0811
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_1/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_1/assets
# 2317/2317 [==============================] - 4s 2ms/step
# 2317/2317 [==============================] - 18s 8ms/step
# 623/623 [==============================] - 5s 7ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 6s 14ms/step
# 390/390 [==============================] - 1s 3ms/step
# 258/258 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 0s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# Epoch 1/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1507
# Epoch 1: val_loss improved from inf to 0.08571, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_2.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1506 - val_loss: 0.0857
# Epoch 2/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1014
# Epoch 2: val_loss improved from 0.08571 to 0.07848, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_2.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1014 - val_loss: 0.0785
# Epoch 3/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0945
# Epoch 3: val_loss improved from 0.07848 to 0.07659, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.0945 - val_loss: 0.0766
# Epoch 4/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.0906
# Epoch 4: val_loss improved from 0.07659 to 0.07549, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_2.h5
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.0905 - val_loss: 0.0755
# Epoch 5/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0875
# Epoch 5: val_loss improved from 0.07549 to 0.07542, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.0876 - val_loss: 0.0754
# Epoch 6/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0848
# Epoch 6: val_loss improved from 0.07542 to 0.07440, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.0848 - val_loss: 0.0744
# Epoch 7/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.0820
# Epoch 7: val_loss did not improve from 0.07440
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0821 - val_loss: 0.0747
# Epoch 8/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.0799
# Epoch 8: val_loss improved from 0.07440 to 0.07397, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_2.h5
# 2317/2317 [==============================] - 15s 7ms/step - loss: 0.0800 - val_loss: 0.0740
# Epoch 9/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0770
# Epoch 9: val_loss did not improve from 0.07397
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.0770 - val_loss: 0.0744
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0761
# Epoch 10: val_loss did not improve from 0.07397
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0761 - val_loss: 0.0744
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_2/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_2/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 4s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 7s 3ms/step
# 2576/2576 [==============================] - 4s 1ms/step
# Epoch 1/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1484
# Epoch 1: val_loss improved from inf to 0.08795, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_3.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1482 - val_loss: 0.0879
# Epoch 2/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.0984
# Epoch 2: val_loss improved from 0.08795 to 0.08225, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0984 - val_loss: 0.0822
# Epoch 3/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.0915
# Epoch 3: val_loss improved from 0.08225 to 0.07896, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0915 - val_loss: 0.0790
# Epoch 4/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0863
# Epoch 4: val_loss improved from 0.07896 to 0.07883, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0863 - val_loss: 0.0788
# Epoch 5/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.0837
# Epoch 5: val_loss improved from 0.07883 to 0.07623, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_3.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.0838 - val_loss: 0.0762
# Epoch 6/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.0796
# Epoch 6: val_loss did not improve from 0.07623
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0797 - val_loss: 0.0776
# Epoch 7/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0770
# Epoch 7: val_loss improved from 0.07623 to 0.07560, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_3.h5
# 2317/2317 [==============================] - 19s 8ms/step - loss: 0.0771 - val_loss: 0.0756
# Epoch 8/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.0750
# Epoch 8: val_loss improved from 0.07560 to 0.07520, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0750 - val_loss: 0.0752
# Epoch 9/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.0734
# Epoch 9: val_loss improved from 0.07520 to 0.07499, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0734 - val_loss: 0.0750
# Epoch 10/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.0719
# Epoch 10: val_loss did not improve from 0.07499
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.0719 - val_loss: 0.0770
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_3/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_3/assets
# 2317/2317 [==============================] - 12s 5ms/step
# 2317/2317 [==============================] - 21s 9ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 4s 1ms/step
# 2576/2576 [==============================] - 4s 1ms/step
# Epoch 1/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1520
# Epoch 1: val_loss improved from inf to 0.09431, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_4.h5
# 2317/2317 [==============================] - 11s 4ms/step - loss: 0.1518 - val_loss: 0.0943
# Epoch 2/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1009
# Epoch 2: val_loss improved from 0.09431 to 0.08926, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_4.h5
# 2317/2317 [==============================] - 21s 9ms/step - loss: 0.1009 - val_loss: 0.0893
# Epoch 3/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.0946
# Epoch 3: val_loss improved from 0.08926 to 0.08707, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_4.h5
# 2317/2317 [==============================] - 15s 7ms/step - loss: 0.0946 - val_loss: 0.0871
# Epoch 4/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.0909
# Epoch 4: val_loss improved from 0.08707 to 0.08402, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_4.h5
# 2317/2317 [==============================] - 16s 7ms/step - loss: 0.0910 - val_loss: 0.0840
# Epoch 5/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0871
# Epoch 5: val_loss did not improve from 0.08402
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0871 - val_loss: 0.0841
# Epoch 6/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.0833
# Epoch 6: val_loss improved from 0.08402 to 0.08292, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_4.h5
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.0834 - val_loss: 0.0829
# Epoch 7/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0808
# Epoch 7: val_loss improved from 0.08292 to 0.08246, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_4.h5
# 2317/2317 [==============================] - 18s 8ms/step - loss: 0.0808 - val_loss: 0.0825
# Epoch 8/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.0785
# Epoch 8: val_loss did not improve from 0.08246
# 2317/2317 [==============================] - 16s 7ms/step - loss: 0.0786 - val_loss: 0.0844
# Epoch 9/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.0758
# Epoch 9: val_loss did not improve from 0.08246
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.0758 - val_loss: 0.0826
# Epoch 10/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0741
# Epoch 10: val_loss improved from 0.08246 to 0.08148, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_4.h5
# 2317/2317 [==============================] - 15s 6ms/step - loss: 0.0742 - val_loss: 0.0815
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_4/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_4/assets
# 2317/2317 [==============================] - 4s 2ms/step
# 2317/2317 [==============================] - 4s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 2s 4ms/step
# 258/258 [==============================] - 3s 11ms/step
# 258/258 [==============================] - 2s 8ms/step
# 2576/2576 [==============================] - 10s 4ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# Epoch 1/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1495
# Epoch 1: val_loss improved from inf to 0.09134, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_5.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1493 - val_loss: 0.0913
# Epoch 2/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1042
# Epoch 2: val_loss improved from 0.09134 to 0.08277, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_5.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1042 - val_loss: 0.0828
# Epoch 3/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0988
# Epoch 3: val_loss improved from 0.08277 to 0.08075, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_5.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0988 - val_loss: 0.0808
# Epoch 4/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.0931
# Epoch 4: val_loss improved from 0.08075 to 0.07831, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_5.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0931 - val_loss: 0.0783
# Epoch 5/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.0890
# Epoch 5: val_loss did not improve from 0.07831
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0890 - val_loss: 0.0796
# Epoch 6/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0850
# Epoch 6: val_loss did not improve from 0.07831
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.0850 - val_loss: 0.0788
# Epoch 7/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.0833
# Epoch 7: val_loss improved from 0.07831 to 0.07688, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_5.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0832 - val_loss: 0.0769
# Epoch 8/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.0817
# Epoch 8: val_loss improved from 0.07688 to 0.07546, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_5.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.0817 - val_loss: 0.0755
# Epoch 9/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0783
# Epoch 9: val_loss did not improve from 0.07546
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0783 - val_loss: 0.0771
# Epoch 10/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.0762
# Epoch 10: val_loss did not improve from 0.07546
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.0762 - val_loss: 0.0769
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_5/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_5/assets
# 2317/2317 [==============================] - 4s 2ms/step
# 2317/2317 [==============================] - 4s 2ms/step
# 623/623 [==============================] - 2s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 2576/2576 [==============================] - 4s 2ms/step
# 2576/2576 [==============================] - 4s 2ms/step
# Epoch 1/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1475
# Epoch 1: val_loss improved from inf to 0.08891, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_6.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1473 - val_loss: 0.0889
# Epoch 2/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.0988
# Epoch 2: val_loss improved from 0.08891 to 0.08256, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_6.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.0989 - val_loss: 0.0826
# Epoch 3/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.0927
# Epoch 3: val_loss improved from 0.08256 to 0.07837, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_6.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.0928 - val_loss: 0.0784
# Epoch 4/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.0885
# Epoch 4: val_loss improved from 0.07837 to 0.07735, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_6.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.0884 - val_loss: 0.0774
# Epoch 5/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0850
# Epoch 5: val_loss did not improve from 0.07735
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.0850 - val_loss: 0.0775
# Epoch 6/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0812
# Epoch 6: val_loss improved from 0.07735 to 0.07603, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_6.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.0812 - val_loss: 0.0760
# Epoch 7/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0784
# Epoch 7: val_loss did not improve from 0.07603
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0784 - val_loss: 0.0781
# Epoch 8/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0764
# Epoch 8: val_loss did not improve from 0.07603
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0764 - val_loss: 0.0780
# Epoch 9/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.0742
# Epoch 9: val_loss did not improve from 0.07603
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0742 - val_loss: 0.0765
# Epoch 10/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0719
# Epoch 10: val_loss did not improve from 0.07603
# 2317/2317 [==============================] - 15s 6ms/step - loss: 0.0719 - val_loss: 0.0783
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_6/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_6/assets
# 2317/2317 [==============================] - 5s 2ms/step
# 2317/2317 [==============================] - 4s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# Epoch 1/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1570
# Epoch 1: val_loss improved from inf to 0.08888, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_7.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1569 - val_loss: 0.0889
# Epoch 2/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1024
# Epoch 2: val_loss improved from 0.08888 to 0.08115, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_7.h5
# 2317/2317 [==============================] - 23s 10ms/step - loss: 0.1024 - val_loss: 0.0812
# Epoch 3/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0969
# Epoch 3: val_loss improved from 0.08115 to 0.07789, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_7.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.0969 - val_loss: 0.0779
# Epoch 4/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0932
# Epoch 4: val_loss improved from 0.07789 to 0.07695, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_7.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.0932 - val_loss: 0.0770
# Epoch 5/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0914
# Epoch 5: val_loss improved from 0.07695 to 0.07674, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_7.h5
# 2317/2317 [==============================] - 16s 7ms/step - loss: 0.0914 - val_loss: 0.0767
# Epoch 6/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.0874
# Epoch 6: val_loss did not improve from 0.07674
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.0876 - val_loss: 0.0781
# Epoch 7/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.0863
# Epoch 7: val_loss did not improve from 0.07674
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.0863 - val_loss: 0.0771
# Epoch 8/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0839
# Epoch 8: val_loss improved from 0.07674 to 0.07610, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_7.h5
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.0840 - val_loss: 0.0761
# Epoch 9/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0824
# Epoch 9: val_loss did not improve from 0.07610
# 2317/2317 [==============================] - 22s 9ms/step - loss: 0.0824 - val_loss: 0.0774
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0811
# Epoch 10: val_loss did not improve from 0.07610
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0811 - val_loss: 0.0775
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_7/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_7/assets
# 2317/2317 [==============================] - 7s 3ms/step
# 2317/2317 [==============================] - 7s 3ms/step
# 623/623 [==============================] - 2s 3ms/step
# 623/623 [==============================] - 2s 3ms/step
# 390/390 [==============================] - 1s 3ms/step
# 390/390 [==============================] - 1s 3ms/step
# 258/258 [==============================] - 1s 3ms/step
# 258/258 [==============================] - 1s 3ms/step
# 2576/2576 [==============================] - 7s 3ms/step
# 2576/2576 [==============================] - 8s 3ms/step
# Epoch 1/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1550
# Epoch 1: val_loss improved from inf to 0.09730, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_8.h5
# 2317/2317 [==============================] - 18s 8ms/step - loss: 0.1549 - val_loss: 0.0973
# Epoch 2/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1041
# Epoch 2: val_loss improved from 0.09730 to 0.08901, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_8.h5
# 2317/2317 [==============================] - 21s 9ms/step - loss: 0.1041 - val_loss: 0.0890
# Epoch 3/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0996
# Epoch 3: val_loss improved from 0.08901 to 0.08487, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_8.h5
# 2317/2317 [==============================] - 20s 9ms/step - loss: 0.0996 - val_loss: 0.0849
# Epoch 4/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0939
# Epoch 4: val_loss improved from 0.08487 to 0.08216, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_8.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.0938 - val_loss: 0.0822
# Epoch 5/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.0896
# Epoch 5: val_loss did not improve from 0.08216
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.0896 - val_loss: 0.0826
# Epoch 6/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.0865
# Epoch 6: val_loss improved from 0.08216 to 0.08165, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_8.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0865 - val_loss: 0.0816
# Epoch 7/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.0832
# Epoch 7: val_loss did not improve from 0.08165
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.0831 - val_loss: 0.0841
# Epoch 8/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0804
# Epoch 8: val_loss improved from 0.08165 to 0.08158, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_8.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.0804 - val_loss: 0.0816
# Epoch 9/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.0775
# Epoch 9: val_loss did not improve from 0.08158
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.0775 - val_loss: 0.0821
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0758
# Epoch 10: val_loss did not improve from 0.08158
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.0758 - val_loss: 0.0819
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_8/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_8/assets
# 2317/2317 [==============================] - 11s 5ms/step
# 2317/2317 [==============================] - 5s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 0s 2ms/step
# 258/258 [==============================] - 0s 2ms/step
# 2576/2576 [==============================] - 4s 2ms/step
# 2576/2576 [==============================] - 11s 4ms/step
# Epoch 1/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1584
# Epoch 1: val_loss improved from inf to 0.09276, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_9.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1583 - val_loss: 0.0928
# Epoch 2/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1025
# Epoch 2: val_loss improved from 0.09276 to 0.08761, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_9.h5
# 2317/2317 [==============================] - 16s 7ms/step - loss: 0.1026 - val_loss: 0.0876
# Epoch 3/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.0966
# Epoch 3: val_loss improved from 0.08761 to 0.08548, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_9.h5
# 2317/2317 [==============================] - 19s 8ms/step - loss: 0.0966 - val_loss: 0.0855
# Epoch 4/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0917
# Epoch 4: val_loss improved from 0.08548 to 0.08179, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_9.h5
# 2317/2317 [==============================] - 15s 7ms/step - loss: 0.0917 - val_loss: 0.0818
# Epoch 5/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0882
# Epoch 5: val_loss improved from 0.08179 to 0.08030, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_9.h5
# 2317/2317 [==============================] - 19s 8ms/step - loss: 0.0882 - val_loss: 0.0803
# Epoch 6/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.0855
# Epoch 6: val_loss did not improve from 0.08030
# 2317/2317 [==============================] - 15s 7ms/step - loss: 0.0855 - val_loss: 0.0811
# Epoch 7/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0832
# Epoch 7: val_loss improved from 0.08030 to 0.07974, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_9.h5
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0832 - val_loss: 0.0797
# Epoch 8/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0816
# Epoch 8: val_loss did not improve from 0.07974
# 2317/2317 [==============================] - 20s 8ms/step - loss: 0.0816 - val_loss: 0.0819
# Epoch 9/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0797
# Epoch 9: val_loss did not improve from 0.07974
# 2317/2317 [==============================] - 22s 9ms/step - loss: 0.0797 - val_loss: 0.0818
# Epoch 10/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.0791
# Epoch 10: val_loss did not improve from 0.07974
# 2317/2317 [==============================] - 18s 8ms/step - loss: 0.0791 - val_loss: 0.0811
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_9/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_9/assets
# 2317/2317 [==============================] - 5s 2ms/step
# 2317/2317 [==============================] - 4s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 0s 2ms/step
# 258/258 [==============================] - 0s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# Epoch 1/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1476
# Epoch 1: val_loss improved from inf to 0.08623, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_10.h5
# 2317/2317 [==============================] - 16s 7ms/step - loss: 0.1476 - val_loss: 0.0862
# Epoch 2/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0957
# Epoch 2: val_loss improved from 0.08623 to 0.07924, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_10.h5
# 2317/2317 [==============================] - 16s 7ms/step - loss: 0.0957 - val_loss: 0.0792
# Epoch 3/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0889
# Epoch 3: val_loss improved from 0.07924 to 0.07670, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_10.h5
# 2317/2317 [==============================] - 19s 8ms/step - loss: 0.0889 - val_loss: 0.0767
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.0850
# Epoch 4: val_loss improved from 0.07670 to 0.07522, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_10.h5
# 2317/2317 [==============================] - 23s 10ms/step - loss: 0.0850 - val_loss: 0.0752
# Epoch 5/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0823
# Epoch 5: val_loss did not improve from 0.07522
# 2317/2317 [==============================] - 31s 13ms/step - loss: 0.0823 - val_loss: 0.0754
# Epoch 6/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0796
# Epoch 6: val_loss did not improve from 0.07522
# 2317/2317 [==============================] - 18s 8ms/step - loss: 0.0796 - val_loss: 0.0759
# Epoch 7/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.0775
# Epoch 7: val_loss improved from 0.07522 to 0.07351, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_10.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.0775 - val_loss: 0.0735
# Epoch 8/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0756
# Epoch 8: val_loss did not improve from 0.07351
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.0756 - val_loss: 0.0747
# Epoch 9/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.0736
# Epoch 9: val_loss did not improve from 0.07351
# 2317/2317 [==============================] - 15s 7ms/step - loss: 0.0736 - val_loss: 0.0741
# Epoch 10/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0725
# Epoch 10: val_loss did not improve from 0.07351
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.0725 - val_loss: 0.0749
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_10/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_3_tiling_10/assets
# 2317/2317 [==============================] - 6s 2ms/step
# 2317/2317 [==============================] - 5s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 0s 2ms/step
# 258/258 [==============================] - 0s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# 2576/2576 [==============================] - 4s 2ms/step

# %%
display_fits(fits)
# Out:
# Average correlation on tiling: 0.7683891379748434
# Average MSE on tiling: 0.09938749507249059
# Average correlation on random: 0.7385039570879596
# Average MSE on random: 0.06558267344930362
# Average correlation on ChrV: 0.6413963065975763
# Average MSE on ChrV: 0.1716898243019831
# Average correlation on CN: 0.712381398437249
# Average MSE on CN: 0.12278114090550282

# %%
first_conv_model = Model(inputs = model.input, outputs = model.layers[1].output)
first_conv_output = first_conv_model.predict(X5)
pd.DataFrame(first_conv_output.reshape(first_conv_output.shape[0], -1)).to_csv(save_path + model_name+"_tiling_tiling_first_conv_output")
first_conv_output_random = first_conv_model.predict(X3)
pd.DataFrame(first_conv_output_random.reshape(first_conv_output_random.shape[0], -1)).to_csv(save_path + model_name+"_tiling_random_first_conv_output")
# Out:
# 2574/2574 [==============================] - 10s 4ms/step
# 390/390 [==============================] - 2s 4ms/step

# %%
first_conv_weights = model.layers[1].weights[0]
first_conv_biases = model.layers[1].weights[1]
# Format: [Position 0: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT  Position 1: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT,
# ..., Position 20: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT]
pd.DataFrame(array(first_conv_weights).transpose((3,2,0,1)).reshape(first_conv_weights.shape[-1], -1)).to_csv(save_path + model_name+"_tiling_first_conv_kernels")
pd.DataFrame(first_conv_biases).to_csv(save_path + model_name+"_tiling_first_conv_biases")
