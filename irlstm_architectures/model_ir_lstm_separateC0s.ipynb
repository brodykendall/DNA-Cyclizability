# %%
import time
# import keras

# from keras.models import Model
# from keras.layers import Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Add, Concatenate
# from keras.layers import Dense, Conv2D, MaxPooling2D, LSTM, TimeDistributed, Reshape
# import keras.backend as K
# import keras.callbacks as callbacks

# import pandas as pd
# import numpy as np
# from numpy import array
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import KFold

# %%
import keras

from keras.models import Model
from keras.layers import Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Add, Concatenate
from keras.layers import Dense, Conv2D, MaxPooling2D, LSTM, TimeDistributed, Reshape
import keras.backend as K
import keras.callbacks as callbacks

import pandas as pd
import numpy as np
from numpy import array
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold

# %%
save_path = "/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/"
model_name = "ir_lstm_separateC0s"
kf = KFold(n_splits = 10, shuffle =True)
num_epochs = 60

#### define functions ####

def model_cycle():
    inputs = Input(shape=(50, 4, 1))
        
    x = Conv2D(48, kernel_size=(3,4),
                   activation='relu',
                   padding='valid')(inputs)
    x = MaxPooling2D((2,1),padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # parallel line 1
    fx1 = Conv2D(48, kernel_size=(3,1),
                   activation='relu',
                   padding='same')(x)
    fx1 = BatchNormalization()(fx1)
    fx1 = Dropout(0.2)(fx1)
    fx1 = Conv2D(48, kernel_size=(3,1),
                   activation='relu',
                   padding='same')(fx1)
    fx1 = MaxPooling2D((2,1),padding='same')(fx1)
    fx1 = BatchNormalization()(fx1)
    fx1 = Dropout(0.2)(fx1)

    # parallel line 2
    fx2 = Conv2D(48, kernel_size=(11,1),
                   activation='relu',
                   padding='same')(x)
    fx2 = BatchNormalization()(fx2)
    fx2 = Dropout(0.2)(fx2)
    fx2 = Conv2D(48, kernel_size=(21,1),
                   activation='relu',
                   padding='same')(fx2)
    fx2 = MaxPooling2D((2,1),padding='same')(fx2)
    fx2 = BatchNormalization()(fx2)
    fx2 = Dropout(0.2)(fx2)
    
    # Add
    x1 = Concatenate(axis=-3)([fx1, fx2])
    x = Add()([x, x1])
    x = MaxPooling2D((2,1),padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    x = LSTM(20, return_sequences=False)(x)
    x = Dropout(0.2)(x)

    outputs = Dense(1, activation='linear')(x)

    network = Model(inputs, outputs)
    network.compile(optimizer='rmsprop',
                    loss='mean_squared_error')
    return network
    
def dnaOneHot(sequence):
    seq_array = array(list(sequence))
    code = {"A": [0], "C": [1], "G": [2], "T": [3], "N": [4],
            "a": [0], "c": [1], "g": [2], "t": [3], "n": [4]}
    onehot_encoded_seq = []
    for char in seq_array:
        onehot_encoded = np.zeros(5)
        onehot_encoded[code[char]] = 1
        onehot_encoded_seq.append(onehot_encoded[0:4])
    return onehot_encoded_seq

# %%
def display_fits(fits):
    print(f"Average correlation on tiling: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 5])}",
          f"\nAverage MSE on tiling: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 5])}",
          f"\nAverage correlation on random: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 3])}",
          f"\nAverage MSE on random: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 3])}",
          f"\nAverage correlation on ChrV: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 7])}",
          f"\nAverage MSE on ChrV: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 7])}",
          f"\nAverage correlation on CN: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 0])}",
          f"\nAverage MSE on CN: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 0])}")

# %%
def find_c0new(dat, aa):
  mat = np.empty((3,3), float)
  k = 2*np.pi/10.4
  n = array([26, 29, 31])
  mat[0:3,0] = 1
  mat[0:3, 1] = np.sin(n*k)
  mat[0:3, 2] = np.cos(n*k)
  mat[0,1:3] = mat[0,1:3]*aa[0]
  mat[1,1:3] = mat[1,1:3]*aa[1]
  mat[2,1:3] = mat[2,1:3]*aa[2]
  inv_mat = np.linalg.inv(mat)
  c0A1A2 = array(np.matmul(dat[["n=26", "n=29", "n=31"]], np.transpose(inv_mat)))
  c0Aphi = c0A1A2
  c0Aphi[:,0] = c0A1A2[:,0]
  c0Aphi[:,1] = np.sqrt(c0A1A2[:,1]**2 + c0A1A2[:,2]**2)
  c0Aphi[:,2] = np.sign(c0A1A2[:,2]) * np.arccos(c0A1A2[:,1]/c0Aphi[:,1])
  return c0Aphi[:,0]

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.process_time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.process_time() - self.epoch_time_start)

# %%
data_cerevisiae_nucle = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/cycle1.txt",delimiter = ",")
X1 = []
for sequence_nt in data_cerevisiae_nucle["Sequence"]:
    X1.append(dnaOneHot(sequence_nt))
X1 = array(X1)
X1 = X1.reshape((X1.shape[0],50,4,1))
X1_reverse = np.flip(X1,[1,2])
# Y1 = data_cerevisiae_nucle["C0"].values.astype(float)
# v6:
Y1 = find_c0new(data_cerevisiae_nucle, aa=[1, 0.35, 1.11]).astype(float)

# %%
Y1_26 = data_cerevisiae_nucle["n=26"]
Y1_31 = data_cerevisiae_nucle["n=31"]

# %%
Y1 = np.concatenate([array(Y1_26), array(Y1_31)])

# %%
X1.shape
# Out:
# (19907, 50, 4, 1)

# %%
X1_2 = np.concatenate([X1, X1], axis=0)

# %%
X1_2.shape
# Out:
# (39814, 50, 4, 1)

# %%
data_random_library = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/cycle3.txt",delimiter = ",")
X3 = []
for sequence_nt in data_random_library["Sequence"]:
    X3.append(dnaOneHot(sequence_nt))
X3 = array(X3)
X3 = X3.reshape((X3.shape[0],50,4,1))
X3_reverse = np.flip(X3,[1,2])
Y3 = data_random_library["C0"].values.astype(float)

# %%
data_tiling = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/cycle5.txt",delimiter = ",")
X5 = []
for sequence_nt in data_tiling["Sequence"]:
    X5.append(dnaOneHot(sequence_nt))
X5 = array(X5)
X5 = X5.reshape((X5.shape[0],50,4,1))
X5_reverse = np.flip(X5,[1,2])
# Y5 = data_tiling["C0"].values.astype(float)
# v4:
Y5 = find_c0new(data_tiling, aa=[1, 0.39, 1.18]).astype(float)

# %%
data_chr5 = pd.read_csv("/Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/cycle6.txt",delimiter = ",")
X6 = []
for sequence_nt in data_chr5["Sequence"]:
    X6.append(dnaOneHot(sequence_nt))
X6 = array(X6)
X6 = X6.reshape((X6.shape[0],50,4,1))
X6_reverse = np.flip(X6,[1,2])
# Y6 = data_chr5["C0"].values.astype(float)
# v6:
Y6 = find_c0new(data_chr5, aa=[1, 0.35, 1.11]).astype(float)

# %%
m1 = np.mean(Y1)
std1 = np.std(Y1)
Z1 = (Y1-m1)/std1

m3 = np.mean(Y3)
std3 = np.std(Y3)
Z3 = (Y3-m3)/std3


m5 = np.mean(Y5)
std5 = np.std(Y5)
Z5 = (Y5-m5)/std5


m6 = np.mean(Y6)
std6 = np.std(Y6)
Z6 = (Y6-m6)/std6

# %%
Y1[:6], Y3[:6], Y5[:6], Y6[:6]
# Out:
# (array([ 0.02360541, -0.40108617,  1.30018368,  0.3337653 ,  0.23685198,
#         -0.68780525]),
#  array([-0.081574, -0.005321, -0.08891 , -0.044137, -0.225836,  0.158945]),
#  array([-0.55739014, -0.55253899, -0.2752565 , -0.4208636 , -0.25469771,
#          0.37953686]),
#  array([ 0.06143367, -0.76210367, -0.45450441,  0.30210197,  0.06623511,
#         -0.21504718]))

# %%
#### tiling

VALIDATION_LOSS = []
fold_var = 1
n = Y5.shape[0]

fits = []
detrend = []
times = []
times2 = []

for train_index, val_index in kf.split(Y5):
    training_X = X5[train_index]
    training_X_reverse = X5_reverse[train_index]
    validation_X = X5[val_index]
    validation_X_reverse = X5_reverse[val_index]
    training_Y = Y5[train_index]
    validation_Y = Y5[val_index]
    # CREATE NEW MODEL
    model = model_cycle()
    # CREATE CALLBACKS
    checkpoint = callbacks.ModelCheckpoint(save_path + model_name+"_tiling_"+str(fold_var)+".h5",
                                                    monitor='val_loss', verbose=1,
                                                    save_best_only=True, mode='min')
    time_callback = TimeHistory()

    history = model.fit(training_X, training_Y,
                        epochs=num_epochs,
                        callbacks= [checkpoint, time_callback],
                        validation_data=(validation_X, validation_Y))
    model.load_weights(save_path + model_name+"_tiling_"+str(fold_var)+".h5")
    model.save(save_path+model_name+"_tiling_"+str(fold_var),save_traces=False)
    times.append(time_callback.times)

    pred_Y = model.predict(training_X)
    pred_Y = pred_Y.reshape(pred_Y.shape[0])
    pred_Y_reverse = model.predict(training_X_reverse)
    pred_Y_reverse = pred_Y_reverse.reshape(pred_Y_reverse.shape[0])
    pred_Y = (pred_Y+pred_Y_reverse)/2
    reg =  LinearRegression().fit(array(pred_Y).reshape(-1, 1), array(training_Y).reshape(-1, 1))
    
    detrend_int = reg.intercept_
    detrend_slope = reg.coef_
    detrend.append([float(detrend_int), float(detrend_slope)])

    start_time = time.process_time()
    fit = model.predict(X1)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X1_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X3)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X3_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(validation_X)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(validation_X_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X6)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X6_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    K.clear_session()
    fold_var += 1
    
detrend = array(detrend)
detrend = pd.DataFrame(detrend)
detrend.to_csv(save_path +model_name+"_detrend_tiling.txt", index = False)

fits = array(fits)
fits = pd.DataFrame((fits))
fits.to_csv(save_path +model_name+ "_fits_tiling.txt", index = False)

with open(save_path +model_name+"_time_tiling.txt", "w") as file:
    for row in times:
        s = " ".join(map(str, row))
        file.write(s+'\n')

with open(save_path +model_name+"_pred_time_tiling.txt", "w") as file:
    for row in times2:
        s = " ".join(map(str, row))
        file.write(s+'\n')
# Out:
# 2023-12-18 16:13:42.412872: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/60
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1399
# Epoch 1: val_loss improved from inf to 0.07410, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 27s 11ms/step - loss: 0.1398 - val_loss: 0.0741
# Epoch 2/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0967
# Epoch 2: val_loss improved from 0.07410 to 0.06652, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 24s 10ms/step - loss: 0.0967 - val_loss: 0.0665
# Epoch 3/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0891
# Epoch 3: val_loss improved from 0.06652 to 0.06174, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 24s 10ms/step - loss: 0.0891 - val_loss: 0.0617
# Epoch 4/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0845
# Epoch 4: val_loss improved from 0.06174 to 0.05744, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0845 - val_loss: 0.0574
# Epoch 5/60
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.0822
# Epoch 5: val_loss improved from 0.05744 to 0.05719, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0822 - val_loss: 0.0572
# Epoch 6/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0800
# Epoch 6: val_loss did not improve from 0.05719
# 2317/2317 [==============================] - 24s 10ms/step - loss: 0.0800 - val_loss: 0.0583
# Epoch 7/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0783
# Epoch 7: val_loss improved from 0.05719 to 0.05665, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0783 - val_loss: 0.0566
# Epoch 8/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0768
# Epoch 8: val_loss did not improve from 0.05665
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0768 - val_loss: 0.0624
# Epoch 9/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0755
# Epoch 9: val_loss did not improve from 0.05665
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0755 - val_loss: 0.0599
# Epoch 10/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0746
# Epoch 10: val_loss did not improve from 0.05665
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0746 - val_loss: 0.0572
# Epoch 11/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0736
# Epoch 11: val_loss improved from 0.05665 to 0.05083, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0735 - val_loss: 0.0508
# Epoch 12/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0726
# Epoch 12: val_loss did not improve from 0.05083
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0726 - val_loss: 0.0511
# Epoch 13/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0722
# Epoch 13: val_loss improved from 0.05083 to 0.05061, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0722 - val_loss: 0.0506
# Epoch 14/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0714
# Epoch 14: val_loss did not improve from 0.05061
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0714 - val_loss: 0.0517
# Epoch 15/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0709
# Epoch 15: val_loss did not improve from 0.05061
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0709 - val_loss: 0.0514
# Epoch 16/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0707
# Epoch 16: val_loss improved from 0.05061 to 0.04976, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0707 - val_loss: 0.0498
# Epoch 17/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0696
# Epoch 17: val_loss did not improve from 0.04976
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0696 - val_loss: 0.0524
# Epoch 18/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0695
# Epoch 18: val_loss did not improve from 0.04976
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0695 - val_loss: 0.0508
# Epoch 19/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0693
# Epoch 19: val_loss did not improve from 0.04976
# 2317/2317 [==============================] - 27s 11ms/step - loss: 0.0693 - val_loss: 0.0504
# Epoch 20/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0687
# Epoch 20: val_loss improved from 0.04976 to 0.04777, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0687 - val_loss: 0.0478
# Epoch 21/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0676
# Epoch 21: val_loss improved from 0.04777 to 0.04702, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0676 - val_loss: 0.0470
# Epoch 22/60
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.0675
# Epoch 22: val_loss did not improve from 0.04702
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0676 - val_loss: 0.0476
# Epoch 23/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0671
# Epoch 23: val_loss improved from 0.04702 to 0.04699, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0671 - val_loss: 0.0470
# Epoch 24/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0666
# Epoch 24: val_loss did not improve from 0.04699
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0666 - val_loss: 0.0476
# Epoch 25/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0669
# Epoch 25: val_loss did not improve from 0.04699
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0669 - val_loss: 0.0495
# Epoch 26/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0660
# Epoch 26: val_loss improved from 0.04699 to 0.04585, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0660 - val_loss: 0.0458
# Epoch 27/60
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.0656
# Epoch 27: val_loss did not improve from 0.04585
# 2317/2317 [==============================] - 27s 11ms/step - loss: 0.0657 - val_loss: 0.0533
# Epoch 28/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0658
# Epoch 28: val_loss did not improve from 0.04585
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0658 - val_loss: 0.0467
# Epoch 29/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0654
# Epoch 29: val_loss improved from 0.04585 to 0.04438, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0654 - val_loss: 0.0444
# Epoch 30/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0655
# Epoch 30: val_loss did not improve from 0.04438
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0655 - val_loss: 0.0505
# Epoch 31/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0646
# Epoch 31: val_loss did not improve from 0.04438
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0646 - val_loss: 0.0445
# Epoch 32/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0641
# Epoch 32: val_loss did not improve from 0.04438
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0641 - val_loss: 0.0455
# Epoch 33/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0643
# Epoch 33: val_loss did not improve from 0.04438
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0643 - val_loss: 0.0446
# Epoch 34/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0639
# Epoch 34: val_loss did not improve from 0.04438
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0639 - val_loss: 0.0462
# Epoch 35/60
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.0645
# Epoch 35: val_loss improved from 0.04438 to 0.04397, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0645 - val_loss: 0.0440
# Epoch 36/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0639
# Epoch 36: val_loss did not improve from 0.04397
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0638 - val_loss: 0.0465
# Epoch 37/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0642
# Epoch 37: val_loss improved from 0.04397 to 0.04337, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0642 - val_loss: 0.0434
# Epoch 38/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0633
# Epoch 38: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0633 - val_loss: 0.0457
# Epoch 39/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0631
# Epoch 39: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0632 - val_loss: 0.0461
# Epoch 40/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0629
# Epoch 40: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0629 - val_loss: 0.0451
# Epoch 41/60
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.0632
# Epoch 41: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0632 - val_loss: 0.0455
# Epoch 42/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0630
# Epoch 42: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0630 - val_loss: 0.0444
# Epoch 43/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0632
# Epoch 43: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0632 - val_loss: 0.0462
# Epoch 44/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0624
# Epoch 44: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0624 - val_loss: 0.0449
# Epoch 45/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0621
# Epoch 45: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 27s 11ms/step - loss: 0.0621 - val_loss: 0.0437
# Epoch 46/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0618
# Epoch 46: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0618 - val_loss: 0.0439
# Epoch 47/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0615
# Epoch 47: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 27s 11ms/step - loss: 0.0615 - val_loss: 0.0507
# Epoch 48/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0610
# Epoch 48: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0610 - val_loss: 0.0440
# Epoch 49/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0607
# Epoch 49: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 27s 11ms/step - loss: 0.0607 - val_loss: 0.0461
# Epoch 50/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0614
# Epoch 50: val_loss did not improve from 0.04337
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0614 - val_loss: 0.0508
# Epoch 51/60
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.0610
# Epoch 51: val_loss improved from 0.04337 to 0.04329, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0610 - val_loss: 0.0433
# Epoch 52/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0611
# Epoch 52: val_loss did not improve from 0.04329
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0611 - val_loss: 0.0476
# Epoch 53/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0606
# Epoch 53: val_loss did not improve from 0.04329
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0606 - val_loss: 0.0441
# Epoch 54/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0600
# Epoch 54: val_loss did not improve from 0.04329
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0600 - val_loss: 0.0454
# Epoch 55/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0597
# Epoch 55: val_loss did not improve from 0.04329
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0597 - val_loss: 0.0436
# Epoch 56/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0600
# Epoch 56: val_loss improved from 0.04329 to 0.04267, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 25s 11ms/step - loss: 0.0601 - val_loss: 0.0427
# Epoch 57/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0602
# Epoch 57: val_loss improved from 0.04267 to 0.04250, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0602 - val_loss: 0.0425
# Epoch 58/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0602
# Epoch 58: val_loss did not improve from 0.04250
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0601 - val_loss: 0.0432
# Epoch 59/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0599
# Epoch 59: val_loss did not improve from 0.04250
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0599 - val_loss: 0.0443
# Epoch 60/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0594
# Epoch 60: val_loss did not improve from 0.04250
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0594 - val_loss: 0.0445
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_1/assets
# 2317/2317 [==============================] - 8s 3ms/step
# 2317/2317 [==============================] - 7s 3ms/step
# 623/623 [==============================] - 2s 3ms/step
# 623/623 [==============================] - 2s 3ms/step
# 390/390 [==============================] - 1s 3ms/step
# 390/390 [==============================] - 1s 3ms/step
# 258/258 [==============================] - 1s 3ms/step
# 258/258 [==============================] - 1s 3ms/step
# 2576/2576 [==============================] - 8s 3ms/step
# 2576/2576 [==============================] - 8s 3ms/step
# Epoch 1/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1403
# Epoch 1: val_loss improved from inf to 0.09278, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 30s 12ms/step - loss: 0.1402 - val_loss: 0.0928
# Epoch 2/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0967
# Epoch 2: val_loss improved from 0.09278 to 0.08015, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0967 - val_loss: 0.0802
# Epoch 3/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0884
# Epoch 3: val_loss improved from 0.08015 to 0.07073, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0884 - val_loss: 0.0707
# Epoch 4/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0840
# Epoch 4: val_loss improved from 0.07073 to 0.06095, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0840 - val_loss: 0.0610
# Epoch 5/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0813
# Epoch 5: val_loss improved from 0.06095 to 0.05963, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0813 - val_loss: 0.0596
# Epoch 6/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0788
# Epoch 6: val_loss did not improve from 0.05963
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0789 - val_loss: 0.0602
# Epoch 7/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0777
# Epoch 7: val_loss did not improve from 0.05963
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0778 - val_loss: 0.0597
# Epoch 8/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0762
# Epoch 8: val_loss improved from 0.05963 to 0.05916, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0762 - val_loss: 0.0592
# Epoch 9/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0750
# Epoch 9: val_loss did not improve from 0.05916
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0750 - val_loss: 0.0611
# Epoch 10/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0740
# Epoch 10: val_loss improved from 0.05916 to 0.05772, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0740 - val_loss: 0.0577
# Epoch 11/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0735
# Epoch 11: val_loss did not improve from 0.05772
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0735 - val_loss: 0.0590
# Epoch 12/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0724
# Epoch 12: val_loss improved from 0.05772 to 0.05751, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 32s 14ms/step - loss: 0.0724 - val_loss: 0.0575
# Epoch 13/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0717
# Epoch 13: val_loss did not improve from 0.05751
# 2317/2317 [==============================] - 34s 15ms/step - loss: 0.0717 - val_loss: 0.0578
# Epoch 14/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0711
# Epoch 14: val_loss improved from 0.05751 to 0.05583, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 33s 14ms/step - loss: 0.0711 - val_loss: 0.0558
# Epoch 15/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0705
# Epoch 15: val_loss did not improve from 0.05583
# 2317/2317 [==============================] - 33s 14ms/step - loss: 0.0706 - val_loss: 0.0570
# Epoch 16/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0700
# Epoch 16: val_loss improved from 0.05583 to 0.05568, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 36s 16ms/step - loss: 0.0700 - val_loss: 0.0557
# Epoch 17/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0696
# Epoch 17: val_loss improved from 0.05568 to 0.05450, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 36s 16ms/step - loss: 0.0697 - val_loss: 0.0545
# Epoch 18/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0689
# Epoch 18: val_loss did not improve from 0.05450
# 2317/2317 [==============================] - 35s 15ms/step - loss: 0.0689 - val_loss: 0.0603
# Epoch 19/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0686
# Epoch 19: val_loss did not improve from 0.05450
# 2317/2317 [==============================] - 34s 14ms/step - loss: 0.0686 - val_loss: 0.0553
# Epoch 20/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0679
# Epoch 20: val_loss improved from 0.05450 to 0.05281, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0679 - val_loss: 0.0528
# Epoch 21/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0671
# Epoch 21: val_loss did not improve from 0.05281
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0673 - val_loss: 0.0539
# Epoch 22/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0673
# Epoch 22: val_loss did not improve from 0.05281
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0673 - val_loss: 0.0530
# Epoch 23/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0667
# Epoch 23: val_loss improved from 0.05281 to 0.05092, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0667 - val_loss: 0.0509
# Epoch 24/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0664
# Epoch 24: val_loss improved from 0.05092 to 0.05090, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0664 - val_loss: 0.0509
# Epoch 25/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0658
# Epoch 25: val_loss improved from 0.05090 to 0.05003, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0658 - val_loss: 0.0500
# Epoch 26/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0656
# Epoch 26: val_loss did not improve from 0.05003
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0656 - val_loss: 0.0538
# Epoch 27/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0657
# Epoch 27: val_loss did not improve from 0.05003
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0657 - val_loss: 0.0509
# Epoch 28/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0650
# Epoch 28: val_loss did not improve from 0.05003
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0650 - val_loss: 0.0506
# Epoch 29/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0645
# Epoch 29: val_loss did not improve from 0.05003
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0645 - val_loss: 0.0503
# Epoch 30/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0648
# Epoch 30: val_loss improved from 0.05003 to 0.04996, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0648 - val_loss: 0.0500
# Epoch 31/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0639
# Epoch 31: val_loss improved from 0.04996 to 0.04935, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0639 - val_loss: 0.0494
# Epoch 32/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0635
# Epoch 32: val_loss did not improve from 0.04935
# 2317/2317 [==============================] - 27s 11ms/step - loss: 0.0635 - val_loss: 0.0505
# Epoch 33/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0633
# Epoch 33: val_loss improved from 0.04935 to 0.04879, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 26s 11ms/step - loss: 0.0633 - val_loss: 0.0488
# Epoch 34/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0631
# Epoch 34: val_loss did not improve from 0.04879
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0631 - val_loss: 0.0537
# Epoch 35/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0625
# Epoch 35: val_loss did not improve from 0.04879
# 2317/2317 [==============================] - 27s 11ms/step - loss: 0.0625 - val_loss: 0.0518
# Epoch 36/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0625
# Epoch 36: val_loss improved from 0.04879 to 0.04816, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0625 - val_loss: 0.0482
# Epoch 37/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0635
# Epoch 37: val_loss did not improve from 0.04816
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0635 - val_loss: 0.0494
# Epoch 38/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0623
# Epoch 38: val_loss did not improve from 0.04816
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0623 - val_loss: 0.0516
# Epoch 39/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0621
# Epoch 39: val_loss did not improve from 0.04816
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0621 - val_loss: 0.0505
# Epoch 40/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0618
# Epoch 40: val_loss improved from 0.04816 to 0.04810, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0618 - val_loss: 0.0481
# Epoch 41/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0616
# Epoch 41: val_loss did not improve from 0.04810
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0616 - val_loss: 0.0481
# Epoch 42/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0612
# Epoch 42: val_loss did not improve from 0.04810
# 2317/2317 [==============================] - 27s 11ms/step - loss: 0.0613 - val_loss: 0.0521
# Epoch 43/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0615
# Epoch 43: val_loss did not improve from 0.04810
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0615 - val_loss: 0.0498
# Epoch 44/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0611
# Epoch 44: val_loss did not improve from 0.04810
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0611 - val_loss: 0.0499
# Epoch 45/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0610
# Epoch 45: val_loss improved from 0.04810 to 0.04770, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0610 - val_loss: 0.0477
# Epoch 46/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0605
# Epoch 46: val_loss did not improve from 0.04770
# 2317/2317 [==============================] - 31s 13ms/step - loss: 0.0605 - val_loss: 0.0493
# Epoch 47/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0601
# Epoch 47: val_loss did not improve from 0.04770
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0601 - val_loss: 0.0493
# Epoch 48/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0600
# Epoch 48: val_loss did not improve from 0.04770
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0600 - val_loss: 0.0491
# Epoch 49/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0600
# Epoch 49: val_loss did not improve from 0.04770
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0600 - val_loss: 0.0481
# Epoch 50/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0600
# Epoch 50: val_loss improved from 0.04770 to 0.04741, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0600 - val_loss: 0.0474
# Epoch 51/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0598
# Epoch 51: val_loss improved from 0.04741 to 0.04690, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0598 - val_loss: 0.0469
# Epoch 52/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0593
# Epoch 52: val_loss did not improve from 0.04690
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0593 - val_loss: 0.0479
# Epoch 53/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0593
# Epoch 53: val_loss did not improve from 0.04690
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0593 - val_loss: 0.0477
# Epoch 54/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0592
# Epoch 54: val_loss improved from 0.04690 to 0.04664, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0592 - val_loss: 0.0466
# Epoch 55/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0594
# Epoch 55: val_loss improved from 0.04664 to 0.04613, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0594 - val_loss: 0.0461
# Epoch 56/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0592
# Epoch 56: val_loss did not improve from 0.04613
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0592 - val_loss: 0.0463
# Epoch 57/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0596
# Epoch 57: val_loss improved from 0.04613 to 0.04598, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 32s 14ms/step - loss: 0.0596 - val_loss: 0.0460
# Epoch 58/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0591
# Epoch 58: val_loss improved from 0.04598 to 0.04586, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2.h5
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0590 - val_loss: 0.0459
# Epoch 59/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0586
# Epoch 59: val_loss did not improve from 0.04586
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0586 - val_loss: 0.0484
# Epoch 60/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0587
# Epoch 60: val_loss did not improve from 0.04586
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0587 - val_loss: 0.0459
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_2/assets
# 2317/2317 [==============================] - 9s 4ms/step
# 2317/2317 [==============================] - 8s 4ms/step
# 623/623 [==============================] - 2s 4ms/step
# 623/623 [==============================] - 2s 4ms/step
# 390/390 [==============================] - 1s 3ms/step
# 390/390 [==============================] - 1s 4ms/step
# 258/258 [==============================] - 1s 3ms/step
# 258/258 [==============================] - 1s 3ms/step
# 2576/2576 [==============================] - 9s 4ms/step
# 2576/2576 [==============================] - 9s 4ms/step
# Epoch 1/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1385
# Epoch 1: val_loss improved from inf to 0.08320, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 31s 12ms/step - loss: 0.1385 - val_loss: 0.0832
# Epoch 2/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0966
# Epoch 2: val_loss improved from 0.08320 to 0.06324, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0966 - val_loss: 0.0632
# Epoch 3/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0887
# Epoch 3: val_loss improved from 0.06324 to 0.06229, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0887 - val_loss: 0.0623
# Epoch 4/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0852
# Epoch 4: val_loss improved from 0.06229 to 0.05777, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0852 - val_loss: 0.0578
# Epoch 5/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0817
# Epoch 5: val_loss improved from 0.05777 to 0.05617, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0817 - val_loss: 0.0562
# Epoch 6/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0799
# Epoch 6: val_loss improved from 0.05617 to 0.05548, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0799 - val_loss: 0.0555
# Epoch 7/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0783
# Epoch 7: val_loss improved from 0.05548 to 0.05405, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 32s 14ms/step - loss: 0.0783 - val_loss: 0.0541
# Epoch 8/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0765
# Epoch 8: val_loss did not improve from 0.05405
# 2317/2317 [==============================] - 32s 14ms/step - loss: 0.0765 - val_loss: 0.0590
# Epoch 9/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0754
# Epoch 9: val_loss improved from 0.05405 to 0.05168, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 32s 14ms/step - loss: 0.0755 - val_loss: 0.0517
# Epoch 10/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0747
# Epoch 10: val_loss did not improve from 0.05168
# 2317/2317 [==============================] - 32s 14ms/step - loss: 0.0747 - val_loss: 0.0547
# Epoch 11/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0737
# Epoch 11: val_loss did not improve from 0.05168
# 2317/2317 [==============================] - 32s 14ms/step - loss: 0.0737 - val_loss: 0.0552
# Epoch 12/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0729
# Epoch 12: val_loss did not improve from 0.05168
# 2317/2317 [==============================] - 31s 14ms/step - loss: 0.0729 - val_loss: 0.0522
# Epoch 13/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0719
# Epoch 13: val_loss improved from 0.05168 to 0.04951, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 31s 13ms/step - loss: 0.0719 - val_loss: 0.0495
# Epoch 14/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0715
# Epoch 14: val_loss did not improve from 0.04951
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0715 - val_loss: 0.0507
# Epoch 15/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0708
# Epoch 15: val_loss did not improve from 0.04951
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0708 - val_loss: 0.0535
# Epoch 16/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0693
# Epoch 16: val_loss did not improve from 0.04951
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0693 - val_loss: 0.0541
# Epoch 17/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0692
# Epoch 17: val_loss improved from 0.04951 to 0.04869, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0692 - val_loss: 0.0487
# Epoch 18/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0686
# Epoch 18: val_loss improved from 0.04869 to 0.04810, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0686 - val_loss: 0.0481
# Epoch 19/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0677
# Epoch 19: val_loss did not improve from 0.04810
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0677 - val_loss: 0.0515
# Epoch 20/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0681
# Epoch 20: val_loss did not improve from 0.04810
# 2317/2317 [==============================] - 31s 13ms/step - loss: 0.0681 - val_loss: 0.0514
# Epoch 21/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0672
# Epoch 21: val_loss improved from 0.04810 to 0.04543, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0671 - val_loss: 0.0454
# Epoch 22/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0668
# Epoch 22: val_loss did not improve from 0.04543
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0668 - val_loss: 0.0497
# Epoch 23/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0662
# Epoch 23: val_loss did not improve from 0.04543
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0662 - val_loss: 0.0467
# Epoch 24/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0659
# Epoch 24: val_loss did not improve from 0.04543
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0659 - val_loss: 0.0481
# Epoch 25/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0662
# Epoch 25: val_loss did not improve from 0.04543
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0662 - val_loss: 0.0466
# Epoch 26/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0652
# Epoch 26: val_loss did not improve from 0.04543
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0652 - val_loss: 0.0460
# Epoch 27/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0650
# Epoch 27: val_loss did not improve from 0.04543
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0650 - val_loss: 0.0496
# Epoch 28/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0646
# Epoch 28: val_loss did not improve from 0.04543
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0646 - val_loss: 0.0489
# Epoch 29/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0645
# Epoch 29: val_loss improved from 0.04543 to 0.04531, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0645 - val_loss: 0.0453
# Epoch 30/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0648
# Epoch 30: val_loss improved from 0.04531 to 0.04399, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0649 - val_loss: 0.0440
# Epoch 31/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0642
# Epoch 31: val_loss improved from 0.04399 to 0.04399, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0642 - val_loss: 0.0440
# Epoch 32/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0636
# Epoch 32: val_loss did not improve from 0.04399
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0636 - val_loss: 0.0484
# Epoch 33/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0636
# Epoch 33: val_loss improved from 0.04399 to 0.04366, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0636 - val_loss: 0.0437
# Epoch 34/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0629
# Epoch 34: val_loss did not improve from 0.04366
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0629 - val_loss: 0.0461
# Epoch 35/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0626
# Epoch 35: val_loss did not improve from 0.04366
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0626 - val_loss: 0.0450
# Epoch 36/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0622
# Epoch 36: val_loss did not improve from 0.04366
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0622 - val_loss: 0.0485
# Epoch 37/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0622
# Epoch 37: val_loss did not improve from 0.04366
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0622 - val_loss: 0.0437
# Epoch 38/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0628
# Epoch 38: val_loss improved from 0.04366 to 0.04341, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0628 - val_loss: 0.0434
# Epoch 39/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0627
# Epoch 39: val_loss improved from 0.04341 to 0.04329, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 33s 14ms/step - loss: 0.0627 - val_loss: 0.0433
# Epoch 40/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0619
# Epoch 40: val_loss did not improve from 0.04329
# 2317/2317 [==============================] - 31s 14ms/step - loss: 0.0620 - val_loss: 0.0437
# Epoch 41/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0621
# Epoch 41: val_loss did not improve from 0.04329
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0621 - val_loss: 0.0442
# Epoch 42/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0616
# Epoch 42: val_loss did not improve from 0.04329
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0616 - val_loss: 0.0456
# Epoch 43/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0613
# Epoch 43: val_loss did not improve from 0.04329
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0613 - val_loss: 0.0444
# Epoch 44/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0609
# Epoch 44: val_loss did not improve from 0.04329
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0610 - val_loss: 0.0440
# Epoch 45/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0608
# Epoch 45: val_loss did not improve from 0.04329
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0608 - val_loss: 0.0450
# Epoch 46/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0604
# Epoch 46: val_loss improved from 0.04329 to 0.04302, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_3.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0604 - val_loss: 0.0430
# Epoch 47/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0608
# Epoch 47: val_loss did not improve from 0.04302
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0608 - val_loss: 0.0435
# ...
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0834 - val_loss: 0.0630
# Epoch 5/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0807
# Epoch 5: val_loss improved from 0.06305 to 0.06034, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0807 - val_loss: 0.0603
# Epoch 6/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0789
# Epoch 6: val_loss did not improve from 0.06034
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0789 - val_loss: 0.0640
# Epoch 7/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0768
# Epoch 7: val_loss did not improve from 0.06034
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0769 - val_loss: 0.0619
# Epoch 8/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0755
# Epoch 8: val_loss improved from 0.06034 to 0.05769, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0755 - val_loss: 0.0577
# Epoch 9/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0742
# Epoch 9: val_loss did not improve from 0.05769
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0742 - val_loss: 0.0594
# Epoch 10/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0737
# Epoch 10: val_loss did not improve from 0.05769
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0737 - val_loss: 0.0594
# Epoch 11/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0728
# Epoch 11: val_loss improved from 0.05769 to 0.05510, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0728 - val_loss: 0.0551
# Epoch 12/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0718
# Epoch 12: val_loss did not improve from 0.05510
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0718 - val_loss: 0.0553
# Epoch 13/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0717
# Epoch 13: val_loss did not improve from 0.05510
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0717 - val_loss: 0.0579
# Epoch 14/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0711
# Epoch 14: val_loss did not improve from 0.05510
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0711 - val_loss: 0.0557
# Epoch 15/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0700
# Epoch 15: val_loss did not improve from 0.05510
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0700 - val_loss: 0.0551
# Epoch 16/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0691
# Epoch 16: val_loss improved from 0.05510 to 0.05424, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0691 - val_loss: 0.0542
# Epoch 17/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0690
# Epoch 17: val_loss improved from 0.05424 to 0.05366, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0690 - val_loss: 0.0537
# Epoch 18/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0680
# Epoch 18: val_loss did not improve from 0.05366
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0680 - val_loss: 0.0543
# Epoch 19/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0679
# Epoch 19: val_loss improved from 0.05366 to 0.05196, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0679 - val_loss: 0.0520
# Epoch 20/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0673
# Epoch 20: val_loss improved from 0.05196 to 0.05024, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0673 - val_loss: 0.0502
# Epoch 21/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0669
# Epoch 21: val_loss did not improve from 0.05024
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0669 - val_loss: 0.0513
# Epoch 22/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0657
# Epoch 22: val_loss improved from 0.05024 to 0.04834, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0657 - val_loss: 0.0483
# Epoch 23/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0652
# Epoch 23: val_loss improved from 0.04834 to 0.04834, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0652 - val_loss: 0.0483
# Epoch 24/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0652
# Epoch 24: val_loss improved from 0.04834 to 0.04828, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0652 - val_loss: 0.0483
# Epoch 25/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0650
# Epoch 25: val_loss did not improve from 0.04828
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0649 - val_loss: 0.0494
# Epoch 26/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0645
# Epoch 26: val_loss improved from 0.04828 to 0.04644, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0645 - val_loss: 0.0464
# Epoch 27/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0645
# Epoch 27: val_loss did not improve from 0.04644
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0645 - val_loss: 0.0508
# Epoch 28/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0633
# Epoch 28: val_loss did not improve from 0.04644
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0633 - val_loss: 0.0478
# Epoch 29/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0635
# Epoch 29: val_loss did not improve from 0.04644
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0635 - val_loss: 0.0476
# Epoch 30/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0629
# Epoch 30: val_loss did not improve from 0.04644
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0629 - val_loss: 0.0468
# Epoch 31/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0624
# Epoch 31: val_loss improved from 0.04644 to 0.04606, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0624 - val_loss: 0.0461
# Epoch 32/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0626
# Epoch 32: val_loss did not improve from 0.04606
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0626 - val_loss: 0.0465
# Epoch 33/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0621
# Epoch 33: val_loss improved from 0.04606 to 0.04569, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0621 - val_loss: 0.0457
# Epoch 34/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0619
# Epoch 34: val_loss did not improve from 0.04569
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0619 - val_loss: 0.0459
# Epoch 35/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0614
# Epoch 35: val_loss did not improve from 0.04569
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0614 - val_loss: 0.0462
# Epoch 36/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0617
# Epoch 36: val_loss did not improve from 0.04569
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0617 - val_loss: 0.0458
# Epoch 37/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0617
# Epoch 37: val_loss improved from 0.04569 to 0.04521, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0617 - val_loss: 0.0452
# Epoch 38/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0612
# Epoch 38: val_loss improved from 0.04521 to 0.04494, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0612 - val_loss: 0.0449
# Epoch 39/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0600
# Epoch 39: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0600 - val_loss: 0.0454
# Epoch 40/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0607
# Epoch 40: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0606 - val_loss: 0.0451
# Epoch 41/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0604
# Epoch 41: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0604 - val_loss: 0.0551
# Epoch 42/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0598
# Epoch 42: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0598 - val_loss: 0.0480
# Epoch 43/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0598
# Epoch 43: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0598 - val_loss: 0.0452
# Epoch 44/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0604
# Epoch 44: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0604 - val_loss: 0.0472
# Epoch 45/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0592
# Epoch 45: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0593 - val_loss: 0.0454
# Epoch 46/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0596
# Epoch 46: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0596 - val_loss: 0.0471
# Epoch 47/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0595
# Epoch 47: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0595 - val_loss: 0.0452
# Epoch 48/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0589
# Epoch 48: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0589 - val_loss: 0.0457
# Epoch 49/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0586
# Epoch 49: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 29s 13ms/step - loss: 0.0586 - val_loss: 0.0451
# Epoch 50/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0587
# Epoch 50: val_loss did not improve from 0.04494
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0587 - val_loss: 0.0474
# Epoch 51/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0587
# Epoch 51: val_loss improved from 0.04494 to 0.04493, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0587 - val_loss: 0.0449
# Epoch 52/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0586
# Epoch 52: val_loss improved from 0.04493 to 0.04410, saving model to /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10.h5
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0586 - val_loss: 0.0441
# Epoch 53/60
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.0581
# Epoch 53: val_loss did not improve from 0.04410
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0582 - val_loss: 0.0477
# Epoch 54/60
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.0580
# Epoch 54: val_loss did not improve from 0.04410
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0580 - val_loss: 0.0445
# Epoch 55/60
# 2317/2317 [==============================] - ETA: 0s - loss: 0.0581
# Epoch 55: val_loss did not improve from 0.04410
# 2317/2317 [==============================] - 27s 12ms/step - loss: 0.0581 - val_loss: 0.0448
# Epoch 56/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0585
# Epoch 56: val_loss did not improve from 0.04410
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0585 - val_loss: 0.0445
# Epoch 57/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0582
# Epoch 57: val_loss did not improve from 0.04410
# 2317/2317 [==============================] - 29s 12ms/step - loss: 0.0582 - val_loss: 0.0456
# Epoch 58/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0583
# Epoch 58: val_loss did not improve from 0.04410
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0583 - val_loss: 0.0462
# Epoch 59/60
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.0580
# Epoch 59: val_loss did not improve from 0.04410
# 2317/2317 [==============================] - 30s 13ms/step - loss: 0.0580 - val_loss: 0.0449
# Epoch 60/60
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.0579
# Epoch 60: val_loss did not improve from 0.04410
# 2317/2317 [==============================] - 28s 12ms/step - loss: 0.0579 - val_loss: 0.0466
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Dropbox/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/ir_lstm_separateC0s_tiling_10/assets
# 2317/2317 [==============================] - 8s 3ms/step
# 2317/2317 [==============================] - 8s 3ms/step
# 623/623 [==============================] - 2s 3ms/step
# 623/623 [==============================] - 2s 3ms/step
# 390/390 [==============================] - 1s 3ms/step
# 390/390 [==============================] - 1s 3ms/step
# 258/258 [==============================] - 1s 3ms/step
# 258/258 [==============================] - 1s 3ms/step
# 2576/2576 [==============================] - 9s 3ms/step
# 2576/2576 [==============================] - 9s 3ms/step

# %%
display_fits(fits)
# Out:
# Average correlation on tiling: 0.9013694587755691
# Average MSE on tiling: 0.04777046223240339
# Average correlation on random: 0.9220625033300693
# Average MSE on random: 0.022342553494513494
# Average correlation on ChrV: 0.7283251672048034
# Average MSE on ChrV: 0.15735308762791916
# Average correlation on CN: 0.8499667871598776
# Average MSE on CN: 0.06589976338471867

# %%
nuc_pred = model.predict(X1)
random_pred = model.predict(X3)
tiling_pred = model.predict(X5)
chrv_pred = model.predict(X6)
# Out:
# 623/623 [==============================] - 3s 4ms/step
# 390/390 [==============================] - 1s 3ms/step
# 2574/2574 [==============================] - 9s 4ms/step
# 2576/2576 [==============================] - 9s 4ms/step

# %%
print(np.corrcoef(nuc_pred.flatten(), Y1)[0,1])
print(np.corrcoef(random_pred.flatten(), Y3)[0,1])
print(np.corrcoef(tiling_pred.flatten(), Y5)[0,1])
print(np.corrcoef(chrv_pred.flatten(), Y6)[0,1])
# Out:
# 0.8552795186859308
# 0.9260616633253925
# 0.9292724214132013
# 0.7317199214228032

# %%
Y1_new = find_c0new(data_cerevisiae_nucle, aa=[1, 0.39, 1.18]).astype(float)
Y3_new = find_c0new(data_random_library, aa=[1, 0.39, 1.18]).astype(float)
Y6_new = find_c0new(data_chr5, aa=[1, 0.39, 1.18]).astype(float)

# %%
data_chr5["C0"][:6], Y6[:6], Y6_new[:6]
# Out:
# (0   -0.069223
#  1   -0.688533
#  2   -0.464485
#  3    0.383790
#  4    0.122761
#  5   -0.189704
#  Name: C0, dtype: float64,
#  array([ 0.06143367, -0.76210367, -0.45450441,  0.30210197,  0.06623511,
#         -0.21504718]),
#  array([ 0.04252972, -0.74574527, -0.46804797,  0.31988126,  0.08478749,
#         -0.22350587]))

# %%
print(np.corrcoef(nuc_pred.flatten(), Y1_new)[0,1])
print(np.corrcoef(random_pred.flatten(), Y3_new)[0,1])
print(np.corrcoef(tiling_pred.flatten(), Y5)[0,1])
print(np.corrcoef(chrv_pred.flatten(), Y6_new)[0,1])
# Out:
# 0.8622618087092941
# 0.9209422179638825
# 0.9292724214132013
# 0.7363685624221729

# %%
Y3_other_new = find_c0new(data_random_library, aa=[1, 1.66, 1.40]).astype(float)
print(np.corrcoef(random_pred.flatten(), Y3_other_new)[0,1])
# Out:
# 0.9263142339515524
