# %%
import time
import keras

from keras.models import Model
from keras.layers import Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Add, Concatenate
from keras.layers import Dense, Conv2D, MaxPooling2D, LSTM, TimeDistributed, Reshape
import keras.backend as K
import keras.callbacks as callbacks

import pandas as pd
import numpy as np
from numpy import array
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
# Out:
# 2023-04-25 20:36:03.148800: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
save_path = "/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/"
model_name = "conv_only_tri_5"
kf = KFold(n_splits = 10, shuffle =True)
num_epochs = 10

#### define functions ####

def model_cycle():
    inputs = Input(shape=(48, 64, 1))
        
    x = Conv2D(8, kernel_size=(21,64),
                   activation='relu',
                   padding='valid')(inputs)
    x = MaxPooling2D((2,1),padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # print(f"After first convolutional layer: x.shape = {x.shape}")

    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = Conv1D(48, kernel_size=(11),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After second convolutional layer: x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((24,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After third convolutional layer, x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((12,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # # parallel line 1
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(fx1)
    # fx1 = MaxPooling2D((2,1),padding='same')(fx1)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    
    # # parallel line 2
    # fx2 = Conv2D(48, kernel_size=(11,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    # fx2 = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(fx2)
    # fx2 = MaxPooling2D((2,1),padding='same')(fx2)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    
    # # # Add
    # x1 = Concatenate(axis=-3)([fx1, fx2])
    # x = Add()([x, x1])
    # x = MaxPooling2D((2,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    
    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = LSTM(20, return_sequences=False)(x)
    # x = Dropout(0.2)(x)

    # x = Reshape((1, 24*48))(x)
    x = Flatten()(x)

    outputs = Dense(1, activation='linear')(x)
    # print(outputs.shape)
    network = Model(inputs, outputs)
    network.compile(optimizer='rmsprop',
                    loss='mean_squared_error')
    return network

# %%
def triOneHot(sequence):
    code = {"AAA": [0], "AAC": [1], "AAG": [2], "AAT": [3],
            "ACA": [4], "ACC": [5], "ACG": [6], "ACT": [7], 
            "AGA": [8], "AGC": [9], "AGG": [10], "AGT": [11], 
            "ATA": [12], "ATC": [13], "ATG": [14], "ATT": [15], 
            "CAA": [16], "CAC": [17], "CAG": [18], "CAT": [19], 
            "CCA": [20], "CCC": [21], "CCG": [22], "CCT": [23], 
            "CGA": [24], "CGC": [25], "CGG": [26], "CGT": [27], 
            "CTA": [28], "CTC": [29], "CTG": [30], "CTT": [31], 
            "GAA": [32], "GAC": [33], "GAG": [34], "GAT": [35],
            "GCA": [36], "GCC": [37], "GCG": [38], "GCT": [39], 
            "GGA": [40], "GGC": [41], "GGG": [42], "GGT": [43], 
            "GTA": [44], "GTC": [45], "GTG": [46], "GTT": [47], 
            "TAA": [48], "TAC": [49], "TAG": [50], "TAT": [51], 
            "TCA": [52], "TCC": [53], "TCG": [54], "TCT": [55], 
            "TGA": [56], "TGC": [57], "TGG": [58], "TGT": [59], 
            "TTA": [60], "TTC": [61], "TTG": [62], "TTT": [63],   "N": [64]}
    onehot_encoded_seq = []
    for i, _ in enumerate(sequence[:(len(sequence)-2)]):
        onehot_encoded = np.zeros(65)
        onehot_encoded[code[sequence[i:i+3]]] = 1
        onehot_encoded_seq.append(onehot_encoded[0:64])
    return onehot_encoded_seq

# %%
def display_fits(fits):
    print(f"Average correlation on tiling: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 5])}",
          f"\nAverage MSE on tiling: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 5])}",
          f"\nAverage correlation on random: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 3])}",
          f"\nAverage MSE on random: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 3])}",
          f"\nAverage correlation on ChrV: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 7])}",
          f"\nAverage MSE on ChrV: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 7])}",
          f"\nAverage correlation on CN: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 0])}",
          f"\nAverage MSE on CN: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 0])}")

# %%
def find_c0new(dat):
  mat = np.empty((3,3), float)
  k = 2*np.pi/10.4
  n = array([26, 29, 31])
  mat[0:3,0] = 1
  mat[0:3, 1] = np.sin(n*k)
  mat[0:3, 2] = np.cos(n*k)
  inv_mat = np.linalg.inv(mat)
  c0A1A2 = array(np.matmul(dat[["n=26", "n=29", "n=31"]], np.transpose(inv_mat)))
  c0Aphi = c0A1A2
  c0Aphi[:,0] = c0A1A2[:,0]
  c0Aphi[:,1] = np.sqrt(c0A1A2[:,1]**2 + c0A1A2[:,2]**2)
  c0Aphi[:,2] <- np.sign(c0A1A2[:,2]) * np.arccos(c0A1A2[:,1]/c0Aphi[:,1])
  return c0Aphi[:,0]

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.process_time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.process_time() - self.epoch_time_start)
        
#### preparing data ####

data_cerevisiae_nucle = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle1.txt",delimiter = ",")
X1 = []
for sequence_nt in data_cerevisiae_nucle["Sequence"]:
    X1.append(triOneHot(sequence_nt))
X1 = array(X1)
X1 = X1.reshape((X1.shape[0],48,64,1))
X1_reverse = np.flip(X1,[1,2])
# Y1 = data_cerevisiae_nucle["C0"].values.astype(float)
Y1 = find_c0new(data_cerevisiae_nucle).astype(float)

# %%
data_random_library = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle3.txt",delimiter = ",")
X3 = []
for sequence_nt in data_random_library["Sequence"]:
    X3.append(triOneHot(sequence_nt))
X3 = array(X3)
X3 = X3.reshape((X3.shape[0],48,64,1))
X3_reverse = np.flip(X3,[1,2])
# Y3 = data_random_library["C0"].values.astype(float)
Y3 = find_c0new(data_random_library).astype(float)

# %%
data_tiling = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle5.txt",delimiter = ",")
X5 = []
for sequence_nt in data_tiling["Sequence"]:
    X5.append(triOneHot(sequence_nt))
X5 = array(X5)
X5 = X5.reshape((X5.shape[0],48,64,1))
X5_reverse = np.flip(X5,[1,2])
# Y5 = data_tiling["C0"].values.astype(float)
Y5 = find_c0new(data_tiling).astype(float)

# %%
data_chr5 = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle6.txt",delimiter = ",")
X6 = []
for sequence_nt in data_chr5["Sequence"]:
    X6.append(triOneHot(sequence_nt))
X6 = array(X6)
X6 = X6.reshape((X6.shape[0],48,64,1))
X6_reverse = np.flip(X6,[1,2])
# Y6 = data_chr5["C0"].values.astype(float)
Y6 = find_c0new(data_chr5).astype(float)

# %%
#### tiling

VALIDATION_LOSS = []
fold_var = 1
n = Y5.shape[0]

fits = []
detrend = []
times = []
times2 = []

for train_index, val_index in kf.split(Y5):
    training_X = X5[train_index]
    training_X_reverse = X5_reverse[train_index]
    validation_X = X5[val_index]
    validation_X_reverse = X5_reverse[val_index]
    training_Y = Y5[train_index]
    validation_Y = Y5[val_index]
    # CREATE NEW MODEL
    model = model_cycle()
    # CREATE CALLBACKS
    checkpoint = callbacks.ModelCheckpoint(save_path + model_name+"_tiling_"+str(fold_var)+".h5",
                                                    monitor='val_loss', verbose=1,
                                                    save_best_only=True, mode='min')
    time_callback = TimeHistory()

    history = model.fit(training_X, training_Y,
                        epochs=num_epochs,
                        callbacks= [checkpoint, time_callback],
                        validation_data=(validation_X, validation_Y))
    model.load_weights(save_path + model_name+"_tiling_"+str(fold_var)+".h5")
    model.save(save_path+model_name+"_tiling_"+str(fold_var),save_traces=False)
    times.append(time_callback.times)

    pred_Y = model.predict(training_X)
    pred_Y = pred_Y.reshape(pred_Y.shape[0])
    pred_Y_reverse = model.predict(training_X_reverse)
    pred_Y_reverse = pred_Y_reverse.reshape(pred_Y_reverse.shape[0])
    pred_Y = (pred_Y+pred_Y_reverse)/2
    reg =  LinearRegression().fit(array(pred_Y).reshape(-1, 1), array(training_Y).reshape(-1, 1))
    
    detrend_int = reg.intercept_
    detrend_slope = reg.coef_
    detrend.append([float(detrend_int), float(detrend_slope)])

    start_time = time.process_time()
    fit = model.predict(X1)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X1_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X3)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X3_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(validation_X)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(validation_X_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X6)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X6_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    K.clear_session()
    fold_var += 1
    
detrend = array(detrend)
detrend = pd.DataFrame(detrend)
detrend.to_csv(save_path +model_name+"_detrend_tiling.txt", index = False)

fits = array(fits)
fits = pd.DataFrame((fits))
fits.to_csv(save_path +model_name+ "_fits_tiling.txt", index = False)

with open(save_path +model_name+"_time_tiling.txt", "w") as file:
    for row in times:
        s = " ".join(map(str, row))
        file.write(s+'\n')

with open(save_path +model_name+"_pred_time_tiling.txt", "w") as file:
    for row in times2:
        s = " ".join(map(str, row))
        file.write(s+'\n')
# Out:
# 2023-04-25 20:37:11.621446: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.2677
# Epoch 1: val_loss improved from inf to 0.20933, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.2675 - val_loss: 0.2093
# Epoch 2/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1823
# Epoch 2: val_loss improved from 0.20933 to 0.13790, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1822 - val_loss: 0.1379
# Epoch 3/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1499
# Epoch 3: val_loss improved from 0.13790 to 0.13374, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1498 - val_loss: 0.1337
# Epoch 4/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1467
# Epoch 4: val_loss improved from 0.13374 to 0.13281, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1467 - val_loss: 0.1328
# Epoch 5/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1449
# Epoch 5: val_loss improved from 0.13281 to 0.13158, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1448 - val_loss: 0.1316
# Epoch 6/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1445
# Epoch 6: val_loss improved from 0.13158 to 0.13077, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1444 - val_loss: 0.1308
# Epoch 7/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1437
# Epoch 7: val_loss did not improve from 0.13077
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1437 - val_loss: 0.1327
# Epoch 8/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1441
# Epoch 8: val_loss improved from 0.13077 to 0.13052, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1441 - val_loss: 0.1305
# Epoch 9/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1423
# Epoch 9: val_loss improved from 0.13052 to 0.13032, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1423 - val_loss: 0.1303
# Epoch 10/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1426
# Epoch 10: val_loss improved from 0.13032 to 0.12966, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1426 - val_loss: 0.1297
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.2218
# Epoch 1: val_loss improved from inf to 0.15914, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.2217 - val_loss: 0.1591
# Epoch 2/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1714
# Epoch 2: val_loss improved from 0.15914 to 0.15511, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1713 - val_loss: 0.1551
# Epoch 3/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1690
# Epoch 3: val_loss improved from 0.15511 to 0.14990, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1690 - val_loss: 0.1499
# Epoch 4/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1654
# Epoch 4: val_loss improved from 0.14990 to 0.14858, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1654 - val_loss: 0.1486
# Epoch 5/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1630
# Epoch 5: val_loss improved from 0.14858 to 0.14680, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1630 - val_loss: 0.1468
# Epoch 6/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1596
# Epoch 6: val_loss improved from 0.14680 to 0.14370, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1598 - val_loss: 0.1437
# Epoch 7/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1585
# Epoch 7: val_loss improved from 0.14370 to 0.14295, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1584 - val_loss: 0.1429
# Epoch 8/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1588
# Epoch 8: val_loss improved from 0.14295 to 0.14214, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1588 - val_loss: 0.1421
# Epoch 9/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1569
# Epoch 9: val_loss improved from 0.14214 to 0.14030, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1569 - val_loss: 0.1403
# Epoch 10/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1549
# Epoch 10: val_loss improved from 0.14030 to 0.13925, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1549 - val_loss: 0.1392
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.2156
# Epoch 1: val_loss improved from inf to 0.14577, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.2155 - val_loss: 0.1458
# Epoch 2/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1604
# Epoch 2: val_loss improved from 0.14577 to 0.14382, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1605 - val_loss: 0.1438
# Epoch 3/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1586
# Epoch 3: val_loss improved from 0.14382 to 0.14145, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1586 - val_loss: 0.1414
# Epoch 4/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1562
# Epoch 4: val_loss did not improve from 0.14145
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1562 - val_loss: 0.1417
# Epoch 5/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1562
# Epoch 5: val_loss improved from 0.14145 to 0.14104, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1562 - val_loss: 0.1410
# Epoch 6/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1557
# Epoch 6: val_loss improved from 0.14104 to 0.14088, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1557 - val_loss: 0.1409
# Epoch 7/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1553
# Epoch 7: val_loss improved from 0.14088 to 0.13997, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1553 - val_loss: 0.1400
# Epoch 8/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1557
# Epoch 8: val_loss did not improve from 0.13997
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1557 - val_loss: 0.1402
# Epoch 9/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1548
# Epoch 9: val_loss did not improve from 0.13997
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1548 - val_loss: 0.1409
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1544
# Epoch 10: val_loss improved from 0.13997 to 0.13974, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1544 - val_loss: 0.1397
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.2114
# Epoch 1: val_loss improved from inf to 0.13686, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.2112 - val_loss: 0.1369
# Epoch 2/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1521
# Epoch 2: val_loss improved from 0.13686 to 0.13087, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1521 - val_loss: 0.1309
# Epoch 3/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1492
# Epoch 3: val_loss improved from 0.13087 to 0.12975, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1492 - val_loss: 0.1297
# Epoch 4/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1464
# Epoch 4: val_loss improved from 0.12975 to 0.12811, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1464 - val_loss: 0.1281
# Epoch 5/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1451
# Epoch 5: val_loss improved from 0.12811 to 0.12804, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1451 - val_loss: 0.1280
# Epoch 6/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1449
# Epoch 6: val_loss improved from 0.12804 to 0.12783, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1449 - val_loss: 0.1278
# Epoch 7/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1444
# Epoch 7: val_loss improved from 0.12783 to 0.12675, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1443 - val_loss: 0.1267
# Epoch 8/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1428
# Epoch 8: val_loss improved from 0.12675 to 0.12485, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1427 - val_loss: 0.1248
# Epoch 9/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1425
# Epoch 9: val_loss improved from 0.12485 to 0.12463, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1426 - val_loss: 0.1246
# Epoch 10/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1427
# Epoch 10: val_loss did not improve from 0.12463
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1427 - val_loss: 0.1257
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.2514
# Epoch 1: val_loss improved from inf to 0.18470, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.2511 - val_loss: 0.1847
# Epoch 2/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1931
# Epoch 2: val_loss improved from 0.18470 to 0.17537, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1931 - val_loss: 0.1754
# Epoch 3/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1884
# Epoch 3: val_loss improved from 0.17537 to 0.17091, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1884 - val_loss: 0.1709
# Epoch 4/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1857
# Epoch 4: val_loss improved from 0.17091 to 0.16765, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1857 - val_loss: 0.1676
# Epoch 5/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1842
# Epoch 5: val_loss improved from 0.16765 to 0.16679, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1842 - val_loss: 0.1668
# Epoch 6/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1828
# Epoch 6: val_loss improved from 0.16679 to 0.16597, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1828 - val_loss: 0.1660
# Epoch 7/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1815
# Epoch 7: val_loss improved from 0.16597 to 0.16456, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1815 - val_loss: 0.1646
# Epoch 8/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1792
# Epoch 8: val_loss improved from 0.16456 to 0.15640, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1792 - val_loss: 0.1564
# Epoch 9/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1541
# Epoch 9: val_loss improved from 0.15640 to 0.12394, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1542 - val_loss: 0.1239
# Epoch 10/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1415
# Epoch 10: val_loss improved from 0.12394 to 0.12096, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1415 - val_loss: 0.1210
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.2358
# Epoch 1: val_loss improved from inf to 0.15787, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.2356 - val_loss: 0.1579
# Epoch 2/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1614
# Epoch 2: val_loss improved from 0.15787 to 0.14760, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1615 - val_loss: 0.1476
# Epoch 3/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1540
# Epoch 3: val_loss improved from 0.14760 to 0.13853, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1540 - val_loss: 0.1385
# Epoch 4/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1477
# Epoch 4: val_loss improved from 0.13853 to 0.13538, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1478 - val_loss: 0.1354
# Epoch 5/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1452
# Epoch 5: val_loss improved from 0.13538 to 0.13393, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1452 - val_loss: 0.1339
# Epoch 6/10
# 2304/2317 [============================>.] - ETA: 0s - loss: 0.1443
# Epoch 6: val_loss improved from 0.13393 to 0.13039, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1443 - val_loss: 0.1304
# Epoch 7/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1422
# Epoch 7: val_loss did not improve from 0.13039
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1422 - val_loss: 0.1314
# Epoch 8/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1409
# Epoch 8: val_loss improved from 0.13039 to 0.13029, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1409 - val_loss: 0.1303
# Epoch 9/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1396
# Epoch 9: val_loss did not improve from 0.13029
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1396 - val_loss: 0.1321
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1400
# Epoch 10: val_loss did not improve from 0.13029
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1399 - val_loss: 0.1305
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6/assets
# 2317/2317 [==============================] - 2s 1ms/step
# 2317/2317 [==============================] - 2s 1ms/step
# 623/623 [==============================] - 1s 985us/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 975us/step
# 390/390 [==============================] - 0s 970us/step
# 258/258 [==============================] - 0s 962us/step
# 258/258 [==============================] - 0s 971us/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.2560
# Epoch 1: val_loss improved from inf to 0.21686, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.2558 - val_loss: 0.2169
# Epoch 2/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.2104
# Epoch 2: val_loss improved from 0.21686 to 0.21579, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.2106 - val_loss: 0.2158
# Epoch 3/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.2083
# Epoch 3: val_loss improved from 0.21579 to 0.21381, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.2083 - val_loss: 0.2138
# Epoch 4/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1985
# Epoch 4: val_loss improved from 0.21381 to 0.19225, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1985 - val_loss: 0.1922
# Epoch 5/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1915
# Epoch 5: val_loss improved from 0.19225 to 0.18911, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1915 - val_loss: 0.1891
# Epoch 6/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1898
# Epoch 6: val_loss improved from 0.18911 to 0.18623, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1897 - val_loss: 0.1862
# Epoch 7/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1881
# Epoch 7: val_loss improved from 0.18623 to 0.18465, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1881 - val_loss: 0.1847
# Epoch 8/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1860
# Epoch 8: val_loss improved from 0.18465 to 0.18334, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1860 - val_loss: 0.1833
# Epoch 9/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1846
# Epoch 9: val_loss improved from 0.18334 to 0.18170, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1846 - val_loss: 0.1817
# Epoch 10/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1840
# Epoch 10: val_loss improved from 0.18170 to 0.18156, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1840 - val_loss: 0.1816
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7/assets
# 2317/2317 [==============================] - 2s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 971us/step
# 623/623 [==============================] - 1s 974us/step
# 390/390 [==============================] - 0s 980us/step
# 390/390 [==============================] - 0s 976us/step
# 258/258 [==============================] - 0s 970us/step
# 258/258 [==============================] - 0s 972us/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.2206
# Epoch 1: val_loss improved from inf to 0.15449, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.2203 - val_loss: 0.1545
# Epoch 2/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1549
# Epoch 2: val_loss improved from 0.15449 to 0.12903, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1550 - val_loss: 0.1290
# Epoch 3/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1405
# Epoch 3: val_loss improved from 0.12903 to 0.12035, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1405 - val_loss: 0.1204
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1337
# Epoch 4: val_loss improved from 0.12035 to 0.11746, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1337 - val_loss: 0.1175
# Epoch 5/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1307
# Epoch 5: val_loss improved from 0.11746 to 0.11645, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1307 - val_loss: 0.1165
# Epoch 6/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1300
# Epoch 6: val_loss improved from 0.11645 to 0.11636, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1301 - val_loss: 0.1164
# Epoch 7/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1286
# Epoch 7: val_loss improved from 0.11636 to 0.11465, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1286 - val_loss: 0.1147
# Epoch 8/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1279
# Epoch 8: val_loss improved from 0.11465 to 0.11335, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1278 - val_loss: 0.1133
# Epoch 9/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1265
# Epoch 9: val_loss did not improve from 0.11335
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1265 - val_loss: 0.1150
# Epoch 10/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1261
# Epoch 10: val_loss did not improve from 0.11335
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1261 - val_loss: 0.1141
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.2152
# Epoch 1: val_loss improved from inf to 0.15884, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.2151 - val_loss: 0.1588
# Epoch 2/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1641
# Epoch 2: val_loss improved from 0.15884 to 0.15360, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1641 - val_loss: 0.1536
# Epoch 3/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1621
# Epoch 3: val_loss did not improve from 0.15360
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1621 - val_loss: 0.1539
# Epoch 4/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1607
# Epoch 4: val_loss improved from 0.15360 to 0.15115, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1606 - val_loss: 0.1512
# Epoch 5/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1602
# Epoch 5: val_loss improved from 0.15115 to 0.15096, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1603 - val_loss: 0.1510
# Epoch 6/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1591
# Epoch 6: val_loss improved from 0.15096 to 0.15081, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1590 - val_loss: 0.1508
# Epoch 7/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1588
# Epoch 7: val_loss improved from 0.15081 to 0.14967, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1587 - val_loss: 0.1497
# Epoch 8/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1591
# Epoch 8: val_loss improved from 0.14967 to 0.14848, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1591 - val_loss: 0.1485
# Epoch 9/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1582
# Epoch 9: val_loss did not improve from 0.14848
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1582 - val_loss: 0.1511
# Epoch 10/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1529
# Epoch 10: val_loss improved from 0.14848 to 0.13674, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1528 - val_loss: 0.1367
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.2373
# Epoch 1: val_loss improved from inf to 0.14824, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.2373 - val_loss: 0.1482
# Epoch 2/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1559
# Epoch 2: val_loss improved from 0.14824 to 0.13883, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1558 - val_loss: 0.1388
# Epoch 3/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1483
# Epoch 3: val_loss improved from 0.13883 to 0.13008, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1484 - val_loss: 0.1301
# Epoch 4/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1427
# Epoch 4: val_loss improved from 0.13008 to 0.12580, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1427 - val_loss: 0.1258
# Epoch 5/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1401
# Epoch 5: val_loss did not improve from 0.12580
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1402 - val_loss: 0.1271
# Epoch 6/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1396
# Epoch 6: val_loss improved from 0.12580 to 0.12378, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1396 - val_loss: 0.1238
# Epoch 7/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1377
# Epoch 7: val_loss improved from 0.12378 to 0.12326, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1377 - val_loss: 0.1233
# Epoch 8/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1366
# Epoch 8: val_loss did not improve from 0.12326
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1366 - val_loss: 0.1240
# Epoch 9/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1354
# Epoch 9: val_loss improved from 0.12326 to 0.12286, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1355 - val_loss: 0.1229
# Epoch 10/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1348
# Epoch 10: val_loss improved from 0.12286 to 0.12168, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1349 - val_loss: 0.1217
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step

# %%
display_fits(fits)
# Out:
# Average correlation on tiling: 0.6134174799599459
# Average MSE on tiling: 0.15028655988279344
# Average correlation on random: 0.5837504984544717
# Average MSE on random: 0.09654731487191784
# Average correlation on ChrV: 0.5004991498477619
# Average MSE on ChrV: 0.2173859786944802
# Average correlation on CN: 0.5633976647103635
# Average MSE on CN: 0.16134434999753533

# %%
first_conv_model = Model(inputs = model.input, outputs = model.layers[1].output)
first_conv_output = first_conv_model.predict(X5)
pd.DataFrame(first_conv_output.reshape(first_conv_output.shape[0], -1)).to_csv(save_path + model_name+"_tiling_tiling_first_conv_output")
first_conv_output_random = first_conv_model.predict(X3)
pd.DataFrame(first_conv_output_random.reshape(first_conv_output_random.shape[0], -1)).to_csv(save_path + model_name+"_tiling_random_first_conv_output")
# Out:
# 2574/2574 [==============================] - 3s 1ms/step
# 390/390 [==============================] - 0s 964us/step

# %%
first_conv_weights = model.layers[1].weights[0]
first_conv_biases = model.layers[1].weights[1]
# Format: [Position 0: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT  Position 1: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT,
# ..., Position 20: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT]
pd.DataFrame(array(first_conv_weights).transpose((3,2,0,1)).reshape(first_conv_weights.shape[-1], -1)).to_csv(save_path + model_name+"_tiling_first_conv_kernels")
pd.DataFrame(first_conv_biases).to_csv(save_path + model_name+"_tiling_first_conv_biases")
