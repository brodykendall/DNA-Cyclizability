# %%
import time
import keras

from keras.models import Model
from keras.layers import Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Add, Concatenate
from keras.layers import Dense, Conv2D, MaxPooling2D, LSTM, TimeDistributed, Reshape
import keras.backend as K
import keras.callbacks as callbacks

import pandas as pd
import numpy as np
from numpy import array
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
# Out:
# 2023-04-19 12:35:14.377485: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
save_path = "/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/"
model_name = "conv_only_6"
kf = KFold(n_splits = 10, shuffle =True)
num_epochs = 10

#### define functions ####

def model_cycle():
    inputs = Input(shape=(50, 4, 1))
        
    x = Conv2D(48, kernel_size=(21,4),
                   activation='relu',
                   padding='valid')(inputs)
    x = MaxPooling2D((2,1),padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # print(f"After first convolutional layer: x.shape = {x.shape}")

    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = Conv1D(48, kernel_size=(11),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After second convolutional layer: x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((24,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After third convolutional layer, x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((12,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # # parallel line 1
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(fx1)
    # fx1 = MaxPooling2D((2,1),padding='same')(fx1)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    
    # # parallel line 2
    # fx2 = Conv2D(48, kernel_size=(11,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    # fx2 = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(fx2)
    # fx2 = MaxPooling2D((2,1),padding='same')(fx2)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    
    # # # Add
    # x1 = Concatenate(axis=-3)([fx1, fx2])
    # x = Add()([x, x1])
    # x = MaxPooling2D((2,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    
    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = LSTM(20, return_sequences=False)(x)
    # x = Dropout(0.2)(x)

    # x = Reshape((1, 24*48))(x)
    x = Flatten()(x)

    outputs = Dense(1, activation='linear')(x)
    # print(outputs.shape)
    network = Model(inputs, outputs)
    network.compile(optimizer='rmsprop',
                    loss='mean_squared_error')
    return network
    
def dnaOneHot(sequence):
    seq_array = array(list(sequence))
    code = {"A": [0], "C": [1], "G": [2], "T": [3], "N": [4],
            "a": [0], "c": [1], "g": [2], "t": [3], "n": [4]}
    onehot_encoded_seq = []
    for char in seq_array:
        onehot_encoded = np.zeros(5)
        onehot_encoded[code[char]] = 1
        onehot_encoded_seq.append(onehot_encoded[0:4])
    return onehot_encoded_seq

# %%
def display_fits(fits):
    print(f"Average correlation on tiling: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 5])}",
          f"\nAverage MSE on tiling: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 5])}",
          f"\nAverage correlation on random: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 3])}",
          f"\nAverage MSE on random: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 3])}",
          f"\nAverage correlation on ChrV: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 7])}",
          f"\nAverage MSE on ChrV: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 7])}",
          f"\nAverage correlation on CN: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 0])}",
          f"\nAverage MSE on CN: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 0])}")

# %%
def find_c0new(dat):
  mat = np.empty((3,3), float)
  k = 2*np.pi/10.4
  n = array([26, 29, 31])
  mat[0:3,0] = 1
  mat[0:3, 1] = np.sin(n*k)
  mat[0:3, 2] = np.cos(n*k)
  inv_mat = np.linalg.inv(mat)
  c0A1A2 = array(np.matmul(dat[["n=26", "n=29", "n=31"]], np.transpose(inv_mat)))
  c0Aphi = c0A1A2
  c0Aphi[:,0] = c0A1A2[:,0]
  c0Aphi[:,1] = np.sqrt(c0A1A2[:,1]**2 + c0A1A2[:,2]**2)
  c0Aphi[:,2] <- np.sign(c0A1A2[:,2]) * np.arccos(c0A1A2[:,1]/c0Aphi[:,1])
  return c0Aphi[:,0]

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.process_time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.process_time() - self.epoch_time_start)
        
#### preparing data ####

data_cerevisiae_nucle = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle1.txt",delimiter = ",")
X1 = []
for sequence_nt in data_cerevisiae_nucle["Sequence"]:
    X1.append(dnaOneHot(sequence_nt))
X1 = array(X1)
X1 = X1.reshape((X1.shape[0],50,4,1))
X1_reverse = np.flip(X1,[1,2])
# Y1 = data_cerevisiae_nucle["C0"].values.astype(float)
Y1 = find_c0new(data_cerevisiae_nucle).astype(float)

# %%
data_random_library = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle3.txt",delimiter = ",")
X3 = []
for sequence_nt in data_random_library["Sequence"]:
    X3.append(dnaOneHot(sequence_nt))
X3 = array(X3)
X3 = X3.reshape((X3.shape[0],50,4,1))
X3_reverse = np.flip(X3,[1,2])
# Y3 = data_random_library["C0"].values.astype(float)
Y3 = find_c0new(data_random_library).astype(float)

# %%
data_tiling = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle5.txt",delimiter = ",")
X5 = []
for sequence_nt in data_tiling["Sequence"]:
    X5.append(dnaOneHot(sequence_nt))
X5 = array(X5)
X5 = X5.reshape((X5.shape[0],50,4,1))
X5_reverse = np.flip(X5,[1,2])
# Y5 = data_tiling["C0"].values.astype(float)
Y5 = find_c0new(data_tiling).astype(float)

# %%
data_chr5 = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle6.txt",delimiter = ",")
X6 = []
for sequence_nt in data_chr5["Sequence"]:
    X6.append(dnaOneHot(sequence_nt))
X6 = array(X6)
X6 = X6.reshape((X6.shape[0],50,4,1))
X6_reverse = np.flip(X6,[1,2])
# Y6 = data_chr5["C0"].values.astype(float)
Y6 = find_c0new(data_chr5).astype(float)

# %%
#### tiling

VALIDATION_LOSS = []
fold_var = 1
n = Y5.shape[0]

fits = []
detrend = []
times = []
times2 = []

for train_index, val_index in kf.split(Y5):
    training_X = X5[train_index]
    training_X_reverse = X5_reverse[train_index]
    validation_X = X5[val_index]
    validation_X_reverse = X5_reverse[val_index]
    training_Y = Y5[train_index]
    validation_Y = Y5[val_index]
    # CREATE NEW MODEL
    model = model_cycle()
    # CREATE CALLBACKS
    checkpoint = callbacks.ModelCheckpoint(save_path + model_name+"_tiling_"+str(fold_var)+".h5",
                                                    monitor='val_loss', verbose=1,
                                                    save_best_only=True, mode='min')
    time_callback = TimeHistory()

    history = model.fit(training_X, training_Y,
                        epochs=num_epochs,
                        callbacks= [checkpoint, time_callback],
                        validation_data=(validation_X, validation_Y))
    model.load_weights(save_path + model_name+"_tiling_"+str(fold_var)+".h5")
    model.save(save_path+model_name+"_tiling_"+str(fold_var),save_traces=False)
    times.append(time_callback.times)

    pred_Y = model.predict(training_X)
    pred_Y = pred_Y.reshape(pred_Y.shape[0])
    pred_Y_reverse = model.predict(training_X_reverse)
    pred_Y_reverse = pred_Y_reverse.reshape(pred_Y_reverse.shape[0])
    pred_Y = (pred_Y+pred_Y_reverse)/2
    reg =  LinearRegression().fit(array(pred_Y).reshape(-1, 1), array(training_Y).reshape(-1, 1))
    
    detrend_int = reg.intercept_
    detrend_slope = reg.coef_
    detrend.append([float(detrend_int), float(detrend_slope)])

    start_time = time.process_time()
    fit = model.predict(X1)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X1_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X3)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X3_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(validation_X)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(validation_X_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X6)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X6_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    K.clear_session()
    fold_var += 1
    
detrend = array(detrend)
detrend = pd.DataFrame(detrend)
detrend.to_csv(save_path +model_name+"_detrend_tiling.txt", index = False)

fits = array(fits)
fits = pd.DataFrame((fits))
fits.to_csv(save_path +model_name+ "_fits_tiling.txt", index = False)

with open(save_path +model_name+"_time_tiling.txt", "w") as file:
    for row in times:
        s = " ".join(map(str, row))
        file.write(s+'\n')

with open(save_path +model_name+"_pred_time_tiling.txt", "w") as file:
    for row in times2:
        s = " ".join(map(str, row))
        file.write(s+'\n')
# Out:
# Epoch 1/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.2401
# Epoch 1: val_loss improved from inf to 0.16885, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_1.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.2400 - val_loss: 0.1689
# Epoch 2/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1678
# Epoch 2: val_loss improved from 0.16885 to 0.15421, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_1.h5
# 2317/2317 [==============================] - 5s 2ms/step - loss: 0.1679 - val_loss: 0.1542
# Epoch 3/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1605
# Epoch 3: val_loss did not improve from 0.15421
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1605 - val_loss: 0.1571
# Epoch 4/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1567
# Epoch 4: val_loss improved from 0.15421 to 0.14366, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_1.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1567 - val_loss: 0.1437
# Epoch 5/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1545
# Epoch 5: val_loss improved from 0.14366 to 0.14196, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_1.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1545 - val_loss: 0.1420
# Epoch 6/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1522
# Epoch 6: val_loss improved from 0.14196 to 0.14172, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_1.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1522 - val_loss: 0.1417
# Epoch 7/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1506
# Epoch 7: val_loss improved from 0.14172 to 0.14123, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_1.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1506 - val_loss: 0.1412
# Epoch 8/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1502
# Epoch 8: val_loss did not improve from 0.14123
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1501 - val_loss: 0.1418
# Epoch 9/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1490
# Epoch 9: val_loss improved from 0.14123 to 0.13820, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_1.h5
# 2317/2317 [==============================] - 5s 2ms/step - loss: 0.1489 - val_loss: 0.1382
# Epoch 10/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1485
# Epoch 10: val_loss did not improve from 0.13820
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1485 - val_loss: 0.1412
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_1/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_1/assets
# 2317/2317 [==============================] - 2s 812us/step
# 2317/2317 [==============================] - 2s 783us/step
# 623/623 [==============================] - 0s 765us/step
# 623/623 [==============================] - 0s 764us/step
# 390/390 [==============================] - 0s 785us/step
# 390/390 [==============================] - 0s 789us/step
# 258/258 [==============================] - 0s 794us/step
# 258/258 [==============================] - 0s 801us/step
# 2576/2576 [==============================] - 2s 775us/step
# 2576/2576 [==============================] - 2s 768us/step
# Epoch 1/10
# 2303/2317 [============================>.] - ETA: 0s - loss: 0.2401
# Epoch 1: val_loss improved from inf to 0.17788, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_2.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.2397 - val_loss: 0.1779
# Epoch 2/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1675
# Epoch 2: val_loss improved from 0.17788 to 0.16024, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_2.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1675 - val_loss: 0.1602
# Epoch 3/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1585
# Epoch 3: val_loss improved from 0.16024 to 0.15105, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_2.h5
# 2317/2317 [==============================] - 5s 2ms/step - loss: 0.1585 - val_loss: 0.1511
# Epoch 4/10
# 2295/2317 [============================>.] - ETA: 0s - loss: 0.1555
# Epoch 4: val_loss did not improve from 0.15105
# 2317/2317 [==============================] - 5s 2ms/step - loss: 0.1557 - val_loss: 0.1576
# Epoch 5/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1536
# Epoch 5: val_loss improved from 0.15105 to 0.14727, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_2.h5
# 2317/2317 [==============================] - 5s 2ms/step - loss: 0.1536 - val_loss: 0.1473
# Epoch 6/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1519
# Epoch 6: val_loss improved from 0.14727 to 0.14621, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_2.h5
# 2317/2317 [==============================] - 5s 2ms/step - loss: 0.1519 - val_loss: 0.1462
# Epoch 7/10
# 2300/2317 [============================>.] - ETA: 0s - loss: 0.1502
# Epoch 7: val_loss improved from 0.14621 to 0.14439, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_2.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1503 - val_loss: 0.1444
# Epoch 8/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1493
# Epoch 8: val_loss improved from 0.14439 to 0.14438, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_2.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1494 - val_loss: 0.1444
# Epoch 9/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1484
# Epoch 9: val_loss improved from 0.14438 to 0.14152, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_2.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1485 - val_loss: 0.1415
# Epoch 10/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1487
# Epoch 10: val_loss did not improve from 0.14152
# 2317/2317 [==============================] - 5s 2ms/step - loss: 0.1487 - val_loss: 0.1419
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_2/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_2/assets
# 2317/2317 [==============================] - 2s 760us/step
# 2317/2317 [==============================] - 2s 761us/step
# 623/623 [==============================] - 1s 797us/step
# 623/623 [==============================] - 0s 763us/step
# 390/390 [==============================] - 0s 743us/step
# 390/390 [==============================] - 0s 737us/step
# 258/258 [==============================] - 0s 743us/step
# 258/258 [==============================] - 0s 768us/step
# 2576/2576 [==============================] - 2s 756us/step
# 2576/2576 [==============================] - 2s 768us/step
# Epoch 1/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2516
# Epoch 1: val_loss improved from inf to 0.16203, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_3.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.2515 - val_loss: 0.1620
# Epoch 2/10
# 2301/2317 [============================>.] - ETA: 0s - loss: 0.1667
# Epoch 2: val_loss improved from 0.16203 to 0.16093, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_3.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1666 - val_loss: 0.1609
# Epoch 3/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1592
# Epoch 3: val_loss improved from 0.16093 to 0.14840, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_3.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1593 - val_loss: 0.1484
# Epoch 4/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1554
# Epoch 4: val_loss improved from 0.14840 to 0.14813, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_3.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1554 - val_loss: 0.1481
# Epoch 5/10
# 2301/2317 [============================>.] - ETA: 0s - loss: 0.1530
# Epoch 5: val_loss improved from 0.14813 to 0.14222, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_3.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1530 - val_loss: 0.1422
# Epoch 6/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1507
# Epoch 6: val_loss improved from 0.14222 to 0.14026, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_3.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1507 - val_loss: 0.1403
# Epoch 7/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1482
# Epoch 7: val_loss did not improve from 0.14026
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1482 - val_loss: 0.1478
# Epoch 8/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1470
# Epoch 8: val_loss improved from 0.14026 to 0.13625, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_3.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1471 - val_loss: 0.1362
# Epoch 9/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1469
# Epoch 9: val_loss did not improve from 0.13625
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1469 - val_loss: 0.1394
# Epoch 10/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1463
# Epoch 10: val_loss improved from 0.13625 to 0.13622, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_3.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1462 - val_loss: 0.1362
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_3/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_3/assets
# 2317/2317 [==============================] - 2s 850us/step
# 2317/2317 [==============================] - 2s 882us/step
# 623/623 [==============================] - 1s 876us/step
# 623/623 [==============================] - 1s 823us/step
# 390/390 [==============================] - 0s 816us/step
# 390/390 [==============================] - 0s 759us/step
# 258/258 [==============================] - 0s 963us/step
# 258/258 [==============================] - 0s 821us/step
# 2576/2576 [==============================] - 11s 4ms/step
# 2576/2576 [==============================] - 2s 758us/step
# Epoch 1/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.2414
# Epoch 1: val_loss improved from inf to 0.19167, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_4.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.2410 - val_loss: 0.1917
# Epoch 2/10
# 2301/2317 [============================>.] - ETA: 0s - loss: 0.1666
# Epoch 2: val_loss improved from 0.19167 to 0.15143, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_4.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1665 - val_loss: 0.1514
# Epoch 3/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1605
# Epoch 3: val_loss improved from 0.15143 to 0.14619, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_4.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1604 - val_loss: 0.1462
# Epoch 4/10
# 2301/2317 [============================>.] - ETA: 0s - loss: 0.1563
# Epoch 4: val_loss improved from 0.14619 to 0.14339, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_4.h5
# 2317/2317 [==============================] - 8s 4ms/step - loss: 0.1564 - val_loss: 0.1434
# Epoch 5/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1548
# Epoch 5: val_loss did not improve from 0.14339
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1548 - val_loss: 0.1464
# Epoch 6/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1519
# Epoch 6: val_loss improved from 0.14339 to 0.13950, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_4.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1520 - val_loss: 0.1395
# Epoch 7/10
# 2298/2317 [============================>.] - ETA: 0s - loss: 0.1513
# Epoch 7: val_loss did not improve from 0.13950
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1513 - val_loss: 0.1444
# Epoch 8/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1506
# Epoch 8: val_loss did not improve from 0.13950
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1505 - val_loss: 0.1407
# Epoch 9/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1504
# Epoch 9: val_loss did not improve from 0.13950
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1505 - val_loss: 0.1532
# Epoch 10/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1499
# Epoch 10: val_loss did not improve from 0.13950
# 2317/2317 [==============================] - 5s 2ms/step - loss: 0.1499 - val_loss: 0.1419
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_4/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_4/assets
# 2317/2317 [==============================] - 2s 775us/step
# 2317/2317 [==============================] - 2s 771us/step
# 623/623 [==============================] - 1s 786us/step
# 623/623 [==============================] - 0s 777us/step
# 390/390 [==============================] - 0s 774us/step
# 390/390 [==============================] - 0s 762us/step
# 258/258 [==============================] - 0s 750us/step
# 258/258 [==============================] - 0s 786us/step
# 2576/2576 [==============================] - 7s 3ms/step
# 2576/2576 [==============================] - 2s 762us/step
# Epoch 1/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.2365
# Epoch 1: val_loss improved from inf to 0.16648, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_5.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.2365 - val_loss: 0.1665
# Epoch 2/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1665
# Epoch 2: val_loss improved from 0.16648 to 0.15166, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_5.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1665 - val_loss: 0.1517
# Epoch 3/10
# 2299/2317 [============================>.] - ETA: 0s - loss: 0.1587
# Epoch 3: val_loss improved from 0.15166 to 0.14799, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_5.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1588 - val_loss: 0.1480
# Epoch 4/10
# 2299/2317 [============================>.] - ETA: 0s - loss: 0.1561
# Epoch 4: val_loss improved from 0.14799 to 0.13877, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1561 - val_loss: 0.1388
# Epoch 5/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1530
# Epoch 5: val_loss improved from 0.13877 to 0.13816, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_5.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1531 - val_loss: 0.1382
# Epoch 6/10
# 2299/2317 [============================>.] - ETA: 0s - loss: 0.1513
# Epoch 6: val_loss improved from 0.13816 to 0.13443, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_5.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1512 - val_loss: 0.1344
# Epoch 7/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1493
# Epoch 7: val_loss did not improve from 0.13443
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1493 - val_loss: 0.1359
# Epoch 8/10
# 2298/2317 [============================>.] - ETA: 0s - loss: 0.1488
# Epoch 8: val_loss did not improve from 0.13443
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1488 - val_loss: 0.1345
# Epoch 9/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1480
# Epoch 9: val_loss improved from 0.13443 to 0.13111, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_5.h5
# 2317/2317 [==============================] - 5s 2ms/step - loss: 0.1480 - val_loss: 0.1311
# Epoch 10/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1475
# Epoch 10: val_loss did not improve from 0.13111
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1475 - val_loss: 0.1319
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_5/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_5/assets
# 2317/2317 [==============================] - 2s 763us/step
# 2317/2317 [==============================] - 2s 776us/step
# 623/623 [==============================] - 0s 765us/step
# 623/623 [==============================] - 0s 764us/step
# 390/390 [==============================] - 0s 773us/step
# 390/390 [==============================] - 0s 765us/step
# 258/258 [==============================] - 0s 767us/step
# 258/258 [==============================] - 0s 770us/step
# 2576/2576 [==============================] - 2s 772us/step
# 2576/2576 [==============================] - 2s 777us/step
# Epoch 1/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.2355
# Epoch 1: val_loss improved from inf to 0.16829, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_6.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.2351 - val_loss: 0.1683
# Epoch 2/10
# 2301/2317 [============================>.] - ETA: 0s - loss: 0.1690
# Epoch 2: val_loss improved from 0.16829 to 0.15376, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_6.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1689 - val_loss: 0.1538
# Epoch 3/10
# 2299/2317 [============================>.] - ETA: 0s - loss: 0.1613
# Epoch 3: val_loss improved from 0.15376 to 0.15192, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_6.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1612 - val_loss: 0.1519
# Epoch 4/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1577
# Epoch 4: val_loss improved from 0.15192 to 0.14578, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_6.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1577 - val_loss: 0.1458
# Epoch 5/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1550
# Epoch 5: val_loss did not improve from 0.14578
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1551 - val_loss: 0.1493
# Epoch 6/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1534
# Epoch 6: val_loss improved from 0.14578 to 0.14106, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_6.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1535 - val_loss: 0.1411
# Epoch 7/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1523
# Epoch 7: val_loss did not improve from 0.14106
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1524 - val_loss: 0.1425
# Epoch 8/10
# 2300/2317 [============================>.] - ETA: 0s - loss: 0.1523
# Epoch 8: val_loss improved from 0.14106 to 0.14068, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_6.h5
# 2317/2317 [==============================] - 8s 4ms/step - loss: 0.1522 - val_loss: 0.1407
# Epoch 9/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1514
# Epoch 9: val_loss did not improve from 0.14068
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1516 - val_loss: 0.1442
# Epoch 10/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1511
# Epoch 10: val_loss did not improve from 0.14068
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1511 - val_loss: 0.1425
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_6/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_6/assets
# 2317/2317 [==============================] - 2s 801us/step
# 2317/2317 [==============================] - 2s 815us/step
# 623/623 [==============================] - 1s 977us/step
# 623/623 [==============================] - 1s 956us/step
# 390/390 [==============================] - 0s 834us/step
# 390/390 [==============================] - 0s 807us/step
# 258/258 [==============================] - 0s 823us/step
# 258/258 [==============================] - 0s 801us/step
# 2576/2576 [==============================] - 2s 783us/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.2438
# Epoch 1: val_loss improved from inf to 0.17548, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_7.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.2437 - val_loss: 0.1755
# Epoch 2/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1669
# Epoch 2: val_loss improved from 0.17548 to 0.15595, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_7.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1669 - val_loss: 0.1560
# Epoch 3/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1590
# Epoch 3: val_loss improved from 0.15595 to 0.15166, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_7.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1590 - val_loss: 0.1517
# Epoch 4/10
# 2304/2317 [============================>.] - ETA: 0s - loss: 0.1550
# Epoch 4: val_loss improved from 0.15166 to 0.14944, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_7.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1550 - val_loss: 0.1494
# Epoch 5/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1524
# Epoch 5: val_loss did not improve from 0.14944
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1524 - val_loss: 0.1526
# Epoch 6/10
# 2300/2317 [============================>.] - ETA: 0s - loss: 0.1507
# Epoch 6: val_loss improved from 0.14944 to 0.14799, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_7.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1506 - val_loss: 0.1480
# Epoch 7/10
# 2301/2317 [============================>.] - ETA: 0s - loss: 0.1491
# Epoch 7: val_loss improved from 0.14799 to 0.14557, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_7.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1490 - val_loss: 0.1456
# Epoch 8/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1472
# Epoch 8: val_loss did not improve from 0.14557
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1472 - val_loss: 0.1478
# Epoch 9/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1468
# Epoch 9: val_loss did not improve from 0.14557
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1467 - val_loss: 0.1484
# Epoch 10/10
# 2298/2317 [============================>.] - ETA: 0s - loss: 0.1457
# Epoch 10: val_loss improved from 0.14557 to 0.14529, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_7.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1457 - val_loss: 0.1453
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_7/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_7/assets
# 2317/2317 [==============================] - 2s 781us/step
# 2317/2317 [==============================] - 2s 779us/step
# 623/623 [==============================] - 1s 795us/step
# 623/623 [==============================] - 1s 779us/step
# 390/390 [==============================] - 2s 5ms/step
# 390/390 [==============================] - 2s 6ms/step
# 258/258 [==============================] - 2s 6ms/step
# 258/258 [==============================] - 1s 3ms/step
# 2576/2576 [==============================] - 3s 991us/step
# 2576/2576 [==============================] - 2s 782us/step
# Epoch 1/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.2401
# Epoch 1: val_loss improved from inf to 0.18330, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_8.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.2400 - val_loss: 0.1833
# Epoch 2/10
# 2297/2317 [============================>.] - ETA: 0s - loss: 0.1671
# Epoch 2: val_loss improved from 0.18330 to 0.16536, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_8.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1670 - val_loss: 0.1654
# Epoch 3/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1591
# Epoch 3: val_loss improved from 0.16536 to 0.15128, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_8.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1591 - val_loss: 0.1513
# Epoch 4/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1547
# Epoch 4: val_loss did not improve from 0.15128
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1547 - val_loss: 0.1530
# Epoch 5/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1513
# Epoch 5: val_loss improved from 0.15128 to 0.15032, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_8.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1513 - val_loss: 0.1503
# Epoch 6/10
# 2297/2317 [============================>.] - ETA: 0s - loss: 0.1499
# Epoch 6: val_loss improved from 0.15032 to 0.14292, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_8.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1499 - val_loss: 0.1429
# Epoch 7/10
# 2299/2317 [============================>.] - ETA: 0s - loss: 0.1485
# Epoch 7: val_loss did not improve from 0.14292
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1485 - val_loss: 0.1450
# Epoch 8/10
# 2296/2317 [============================>.] - ETA: 0s - loss: 0.1476
# Epoch 8: val_loss improved from 0.14292 to 0.14206, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_8.h5
# 2317/2317 [==============================] - 5s 2ms/step - loss: 0.1475 - val_loss: 0.1421
# Epoch 9/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1466
# Epoch 9: val_loss did not improve from 0.14206
# 2317/2317 [==============================] - 5s 2ms/step - loss: 0.1466 - val_loss: 0.1449
# Epoch 10/10
# 2300/2317 [============================>.] - ETA: 0s - loss: 0.1452
# Epoch 10: val_loss improved from 0.14206 to 0.13606, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_8.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1452 - val_loss: 0.1361
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_8/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_8/assets
# 2317/2317 [==============================] - 2s 742us/step
# 2317/2317 [==============================] - 2s 752us/step
# 623/623 [==============================] - 1s 869us/step
# 623/623 [==============================] - 0s 759us/step
# 390/390 [==============================] - 0s 1000us/step
# 390/390 [==============================] - 0s 921us/step
# 258/258 [==============================] - 0s 775us/step
# 258/258 [==============================] - 0s 763us/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 2s 843us/step
# Epoch 1/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.2466
# Epoch 1: val_loss improved from inf to 0.16351, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_9.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.2462 - val_loss: 0.1635
# Epoch 2/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1685
# Epoch 2: val_loss improved from 0.16351 to 0.15442, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_9.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1686 - val_loss: 0.1544
# Epoch 3/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1616
# Epoch 3: val_loss did not improve from 0.15442
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1616 - val_loss: 0.1553
# Epoch 4/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1572
# Epoch 4: val_loss improved from 0.15442 to 0.15090, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_9.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1572 - val_loss: 0.1509
# Epoch 5/10
# 2301/2317 [============================>.] - ETA: 0s - loss: 0.1549
# Epoch 5: val_loss improved from 0.15090 to 0.14809, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_9.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1549 - val_loss: 0.1481
# Epoch 6/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1540
# Epoch 6: val_loss did not improve from 0.14809
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1539 - val_loss: 0.1526
# Epoch 7/10
# 2300/2317 [============================>.] - ETA: 0s - loss: 0.1516
# Epoch 7: val_loss did not improve from 0.14809
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1516 - val_loss: 0.1515
# Epoch 8/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1515
# Epoch 8: val_loss improved from 0.14809 to 0.14171, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_9.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1514 - val_loss: 0.1417
# Epoch 9/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1493
# Epoch 9: val_loss did not improve from 0.14171
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1493 - val_loss: 0.1420
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1495
# Epoch 10: val_loss improved from 0.14171 to 0.14005, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_9.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1495 - val_loss: 0.1401
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_9/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_9/assets
# 2317/2317 [==============================] - 2s 780us/step
# 2317/2317 [==============================] - 2s 780us/step
# 623/623 [==============================] - 1s 810us/step
# 623/623 [==============================] - 1s 779us/step
# 390/390 [==============================] - 0s 790us/step
# 390/390 [==============================] - 0s 791us/step
# 258/258 [==============================] - 0s 805us/step
# 258/258 [==============================] - 0s 785us/step
# 2576/2576 [==============================] - 2s 780us/step
# 2576/2576 [==============================] - 2s 781us/step
# Epoch 1/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.2345
# Epoch 1: val_loss improved from inf to 0.16373, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_10.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.2345 - val_loss: 0.1637
# Epoch 2/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1659
# Epoch 2: val_loss improved from 0.16373 to 0.15348, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_10.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1659 - val_loss: 0.1535
# Epoch 3/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1605
# Epoch 3: val_loss improved from 0.15348 to 0.14567, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_10.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1604 - val_loss: 0.1457
# Epoch 4/10
# 2303/2317 [============================>.] - ETA: 0s - loss: 0.1570
# Epoch 4: val_loss did not improve from 0.14567
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1569 - val_loss: 0.1464
# Epoch 5/10
# 2304/2317 [============================>.] - ETA: 0s - loss: 0.1547
# Epoch 5: val_loss improved from 0.14567 to 0.14220, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_10.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1548 - val_loss: 0.1422
# Epoch 6/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1527
# Epoch 6: val_loss improved from 0.14220 to 0.13834, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_10.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1527 - val_loss: 0.1383
# Epoch 7/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1522
# Epoch 7: val_loss did not improve from 0.13834
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1522 - val_loss: 0.1401
# Epoch 8/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1512
# Epoch 8: val_loss did not improve from 0.13834
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1513 - val_loss: 0.1401
# Epoch 9/10
# 2303/2317 [============================>.] - ETA: 0s - loss: 0.1504
# Epoch 9: val_loss improved from 0.13834 to 0.13699, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_10.h5
# 2317/2317 [==============================] - 6s 2ms/step - loss: 0.1505 - val_loss: 0.1370
# Epoch 10/10
# 2298/2317 [============================>.] - ETA: 0s - loss: 0.1502
# Epoch 10: val_loss improved from 0.13699 to 0.13522, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_10.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1502 - val_loss: 0.1352
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_10/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_6_tiling_10/assets
# 2317/2317 [==============================] - 2s 918us/step
# 2317/2317 [==============================] - 2s 800us/step
# 623/623 [==============================] - 1s 800us/step
# 623/623 [==============================] - 1s 792us/step
# 390/390 [==============================] - 0s 805us/step
# 390/390 [==============================] - 0s 796us/step
# 258/258 [==============================] - 0s 808us/step
# 258/258 [==============================] - 0s 832us/step
# 2576/2576 [==============================] - 2s 831us/step
# 2576/2576 [==============================] - 3s 965us/step

# %%
display_fits(fits)
# Out:
# Average correlation on tiling: 0.6590394330352688
# Average MSE on tiling: 0.13701102262638046
# Average correlation on random: 0.638575133606921
# Average MSE on random: 0.0861782779830948
# Average correlation on ChrV: 0.5408828757990819
# Average MSE on ChrV: 0.20603591560645845
# Average correlation on CN: 0.6125182092046465
# Average MSE on CN: 0.1366847946233453
