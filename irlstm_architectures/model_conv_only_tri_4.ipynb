# %%
import time
import keras

from keras.models import Model
from keras.layers import Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Add, Concatenate
from keras.layers import Dense, Conv2D, MaxPooling2D, LSTM, TimeDistributed, Reshape
import keras.backend as K
import keras.callbacks as callbacks

import pandas as pd
import numpy as np
from numpy import array
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
# Out:
# 2023-04-25 13:39:29.193981: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
save_path = "/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/"
model_name = "conv_only_tri_4"
kf = KFold(n_splits = 10, shuffle =True)
num_epochs = 10

#### define functions ####

def model_cycle():
    inputs = Input(shape=(48, 64, 1))
        
    x = Conv2D(4, kernel_size=(21,64),
                   activation='relu',
                   padding='valid')(inputs)
    x = MaxPooling2D((2,1),padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # print(f"After first convolutional layer: x.shape = {x.shape}")

    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = Conv1D(48, kernel_size=(11),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After second convolutional layer: x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((24,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After third convolutional layer, x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((12,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # # parallel line 1
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(fx1)
    # fx1 = MaxPooling2D((2,1),padding='same')(fx1)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    
    # # parallel line 2
    # fx2 = Conv2D(48, kernel_size=(11,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    # fx2 = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(fx2)
    # fx2 = MaxPooling2D((2,1),padding='same')(fx2)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    
    # # # Add
    # x1 = Concatenate(axis=-3)([fx1, fx2])
    # x = Add()([x, x1])
    # x = MaxPooling2D((2,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    
    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = LSTM(20, return_sequences=False)(x)
    # x = Dropout(0.2)(x)

    # x = Reshape((1, 24*48))(x)
    x = Flatten()(x)

    outputs = Dense(1, activation='linear')(x)
    # print(outputs.shape)
    network = Model(inputs, outputs)
    network.compile(optimizer='rmsprop',
                    loss='mean_squared_error')
    return network

# %%
def triOneHot(sequence):
    code = {"AAA": [0], "AAC": [1], "AAG": [2], "AAT": [3],
            "ACA": [4], "ACC": [5], "ACG": [6], "ACT": [7], 
            "AGA": [8], "AGC": [9], "AGG": [10], "AGT": [11], 
            "ATA": [12], "ATC": [13], "ATG": [14], "ATT": [15], 
            "CAA": [16], "CAC": [17], "CAG": [18], "CAT": [19], 
            "CCA": [20], "CCC": [21], "CCG": [22], "CCT": [23], 
            "CGA": [24], "CGC": [25], "CGG": [26], "CGT": [27], 
            "CTA": [28], "CTC": [29], "CTG": [30], "CTT": [31], 
            "GAA": [32], "GAC": [33], "GAG": [34], "GAT": [35],
            "GCA": [36], "GCC": [37], "GCG": [38], "GCT": [39], 
            "GGA": [40], "GGC": [41], "GGG": [42], "GGT": [43], 
            "GTA": [44], "GTC": [45], "GTG": [46], "GTT": [47], 
            "TAA": [48], "TAC": [49], "TAG": [50], "TAT": [51], 
            "TCA": [52], "TCC": [53], "TCG": [54], "TCT": [55], 
            "TGA": [56], "TGC": [57], "TGG": [58], "TGT": [59], 
            "TTA": [60], "TTC": [61], "TTG": [62], "TTT": [63],   "N": [64]}
    onehot_encoded_seq = []
    for i, _ in enumerate(sequence[:(len(sequence)-2)]):
        onehot_encoded = np.zeros(65)
        onehot_encoded[code[sequence[i:i+3]]] = 1
        onehot_encoded_seq.append(onehot_encoded[0:64])
    return onehot_encoded_seq

# %%
def display_fits(fits):
    print(f"Average correlation on tiling: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 5])}",
          f"\nAverage MSE on tiling: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 5])}",
          f"\nAverage correlation on random: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 3])}",
          f"\nAverage MSE on random: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 3])}",
          f"\nAverage correlation on ChrV: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 7])}",
          f"\nAverage MSE on ChrV: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 7])}",
          f"\nAverage correlation on CN: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 0])}",
          f"\nAverage MSE on CN: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 0])}")

# %%
def find_c0new(dat):
  mat = np.empty((3,3), float)
  k = 2*np.pi/10.4
  n = array([26, 29, 31])
  mat[0:3,0] = 1
  mat[0:3, 1] = np.sin(n*k)
  mat[0:3, 2] = np.cos(n*k)
  inv_mat = np.linalg.inv(mat)
  c0A1A2 = array(np.matmul(dat[["n=26", "n=29", "n=31"]], np.transpose(inv_mat)))
  c0Aphi = c0A1A2
  c0Aphi[:,0] = c0A1A2[:,0]
  c0Aphi[:,1] = np.sqrt(c0A1A2[:,1]**2 + c0A1A2[:,2]**2)
  c0Aphi[:,2] <- np.sign(c0A1A2[:,2]) * np.arccos(c0A1A2[:,1]/c0Aphi[:,1])
  return c0Aphi[:,0]

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.process_time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.process_time() - self.epoch_time_start)
        
#### preparing data ####

data_cerevisiae_nucle = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle1.txt",delimiter = ",")
X1 = []
for sequence_nt in data_cerevisiae_nucle["Sequence"]:
    X1.append(triOneHot(sequence_nt))
X1 = array(X1)
X1 = X1.reshape((X1.shape[0],48,64,1))
X1_reverse = np.flip(X1,[1,2])
# Y1 = data_cerevisiae_nucle["C0"].values.astype(float)
Y1 = find_c0new(data_cerevisiae_nucle).astype(float)

# %%
data_random_library = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle3.txt",delimiter = ",")
X3 = []
for sequence_nt in data_random_library["Sequence"]:
    X3.append(triOneHot(sequence_nt))
X3 = array(X3)
X3 = X3.reshape((X3.shape[0],48,64,1))
X3_reverse = np.flip(X3,[1,2])
# Y3 = data_random_library["C0"].values.astype(float)
Y3 = find_c0new(data_random_library).astype(float)

# %%
data_tiling = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle5.txt",delimiter = ",")
X5 = []
for sequence_nt in data_tiling["Sequence"]:
    X5.append(triOneHot(sequence_nt))
X5 = array(X5)
X5 = X5.reshape((X5.shape[0],48,64,1))
X5_reverse = np.flip(X5,[1,2])
# Y5 = data_tiling["C0"].values.astype(float)
Y5 = find_c0new(data_tiling).astype(float)

# %%
data_chr5 = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle6.txt",delimiter = ",")
X6 = []
for sequence_nt in data_chr5["Sequence"]:
    X6.append(triOneHot(sequence_nt))
X6 = array(X6)
X6 = X6.reshape((X6.shape[0],48,64,1))
X6_reverse = np.flip(X6,[1,2])
# Y6 = data_chr5["C0"].values.astype(float)
Y6 = find_c0new(data_chr5).astype(float)

# %%
#### tiling

VALIDATION_LOSS = []
fold_var = 1
n = Y5.shape[0]

fits = []
detrend = []
times = []
times2 = []

for train_index, val_index in kf.split(Y5):
    training_X = X5[train_index]
    training_X_reverse = X5_reverse[train_index]
    validation_X = X5[val_index]
    validation_X_reverse = X5_reverse[val_index]
    training_Y = Y5[train_index]
    validation_Y = Y5[val_index]
    # CREATE NEW MODEL
    model = model_cycle()
    # CREATE CALLBACKS
    checkpoint = callbacks.ModelCheckpoint(save_path + model_name+"_tiling_"+str(fold_var)+".h5",
                                                    monitor='val_loss', verbose=1,
                                                    save_best_only=True, mode='min')
    time_callback = TimeHistory()

    history = model.fit(training_X, training_Y,
                        epochs=num_epochs,
                        callbacks= [checkpoint, time_callback],
                        validation_data=(validation_X, validation_Y))
    model.load_weights(save_path + model_name+"_tiling_"+str(fold_var)+".h5")
    model.save(save_path+model_name+"_tiling_"+str(fold_var),save_traces=False)
    times.append(time_callback.times)

    pred_Y = model.predict(training_X)
    pred_Y = pred_Y.reshape(pred_Y.shape[0])
    pred_Y_reverse = model.predict(training_X_reverse)
    pred_Y_reverse = pred_Y_reverse.reshape(pred_Y_reverse.shape[0])
    pred_Y = (pred_Y+pred_Y_reverse)/2
    reg =  LinearRegression().fit(array(pred_Y).reshape(-1, 1), array(training_Y).reshape(-1, 1))
    
    detrend_int = reg.intercept_
    detrend_slope = reg.coef_
    detrend.append([float(detrend_int), float(detrend_slope)])

    start_time = time.process_time()
    fit = model.predict(X1)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X1_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X3)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X3_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(validation_X)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(validation_X_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X6)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X6_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    K.clear_session()
    fold_var += 1
    
detrend = array(detrend)
detrend = pd.DataFrame(detrend)
detrend.to_csv(save_path +model_name+"_detrend_tiling.txt", index = False)

fits = array(fits)
fits = pd.DataFrame((fits))
fits.to_csv(save_path +model_name+ "_fits_tiling.txt", index = False)

with open(save_path +model_name+"_time_tiling.txt", "w") as file:
    for row in times:
        s = " ".join(map(str, row))
        file.write(s+'\n')

with open(save_path +model_name+"_pred_time_tiling.txt", "w") as file:
    for row in times2:
        s = " ".join(map(str, row))
        file.write(s+'\n')
# Out:
# Epoch 1/10
# 2304/2317 [============================>.] - ETA: 0s - loss: 0.2939
# Epoch 1: val_loss improved from inf to 0.23675, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_1.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.2936 - val_loss: 0.2367
# Epoch 2/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.2303
# Epoch 2: val_loss improved from 0.23675 to 0.16678, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2300 - val_loss: 0.1668
# Epoch 3/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1733
# Epoch 3: val_loss improved from 0.16678 to 0.15195, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1734 - val_loss: 0.1520
# Epoch 4/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1664
# Epoch 4: val_loss improved from 0.15195 to 0.14559, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1664 - val_loss: 0.1456
# Epoch 5/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1630
# Epoch 5: val_loss improved from 0.14559 to 0.14490, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1630 - val_loss: 0.1449
# Epoch 6/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1622
# Epoch 6: val_loss improved from 0.14490 to 0.14392, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1623 - val_loss: 0.1439
# Epoch 7/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1603
# Epoch 7: val_loss improved from 0.14392 to 0.14196, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1603 - val_loss: 0.1420
# Epoch 8/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1604
# Epoch 8: val_loss improved from 0.14196 to 0.14193, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1604 - val_loss: 0.1419
# Epoch 9/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1596
# Epoch 9: val_loss improved from 0.14193 to 0.14130, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1596 - val_loss: 0.1413
# Epoch 10/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1599
# Epoch 10: val_loss did not improve from 0.14130
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1600 - val_loss: 0.1416
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_1/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_1/assets
# 2317/2317 [==============================] - 2s 1ms/step
# 2317/2317 [==============================] - 2s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 975us/step
# 390/390 [==============================] - 0s 937us/step
# 390/390 [==============================] - 0s 980us/step
# 258/258 [==============================] - 0s 922us/step
# 258/258 [==============================] - 0s 974us/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.2747
# Epoch 1: val_loss improved from inf to 0.24290, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2748 - val_loss: 0.2429
# Epoch 2/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.2176
# Epoch 2: val_loss improved from 0.24290 to 0.21066, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2177 - val_loss: 0.2107
# Epoch 3/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.2083
# Epoch 3: val_loss improved from 0.21066 to 0.20789, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2084 - val_loss: 0.2079
# Epoch 4/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.2063
# Epoch 4: val_loss improved from 0.20789 to 0.20486, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2065 - val_loss: 0.2049
# Epoch 5/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.2043
# Epoch 5: val_loss improved from 0.20486 to 0.20393, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2043 - val_loss: 0.2039
# Epoch 6/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1723
# Epoch 6: val_loss improved from 0.20393 to 0.14258, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1722 - val_loss: 0.1426
# Epoch 7/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1483
# Epoch 7: val_loss improved from 0.14258 to 0.13781, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1483 - val_loss: 0.1378
# Epoch 8/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1465
# Epoch 8: val_loss improved from 0.13781 to 0.13590, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1465 - val_loss: 0.1359
# Epoch 9/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1451
# Epoch 9: val_loss improved from 0.13590 to 0.13383, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1451 - val_loss: 0.1338
# Epoch 10/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1437
# Epoch 10: val_loss improved from 0.13383 to 0.13227, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2.h5
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1437 - val_loss: 0.1323
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_2/assets
# 2317/2317 [==============================] - 2s 965us/step
# 2317/2317 [==============================] - 2s 969us/step
# 623/623 [==============================] - 1s 930us/step
# 623/623 [==============================] - 1s 910us/step
# 390/390 [==============================] - 0s 888us/step
# 390/390 [==============================] - 0s 918us/step
# 258/258 [==============================] - 0s 816us/step
# 258/258 [==============================] - 0s 826us/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2809
# Epoch 1: val_loss improved from inf to 0.21076, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_3.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2808 - val_loss: 0.2108
# Epoch 2/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.2112
# Epoch 2: val_loss improved from 0.21076 to 0.20878, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_3.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.2110 - val_loss: 0.2088
# Epoch 3/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2095
# Epoch 3: val_loss improved from 0.20878 to 0.20833, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_3.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2096 - val_loss: 0.2083
# Epoch 4/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.2091
# Epoch 4: val_loss improved from 0.20833 to 0.20747, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_3.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.2091 - val_loss: 0.2075
# Epoch 5/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.2084
# Epoch 5: val_loss improved from 0.20747 to 0.20681, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_3.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2084 - val_loss: 0.2068
# Epoch 6/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2080
# Epoch 6: val_loss did not improve from 0.20681
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.2080 - val_loss: 0.2069
# Epoch 7/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.2078
# Epoch 7: val_loss did not improve from 0.20681
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.2078 - val_loss: 0.2072
# Epoch 8/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.2076
# Epoch 8: val_loss did not improve from 0.20681
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.2077 - val_loss: 0.2074
# Epoch 9/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.2072
# Epoch 9: val_loss improved from 0.20681 to 0.20589, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_3.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2072 - val_loss: 0.2059
# Epoch 10/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.2066
# Epoch 10: val_loss improved from 0.20589 to 0.20584, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_3.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2066 - val_loss: 0.2058
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_3/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_3/assets
# 2317/2317 [==============================] - 4s 2ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.2394
# Epoch 1: val_loss improved from inf to 0.15188, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2393 - val_loss: 0.1519
# Epoch 2/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1631
# Epoch 2: val_loss improved from 0.15188 to 0.14829, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1630 - val_loss: 0.1483
# Epoch 3/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1620
# Epoch 3: val_loss improved from 0.14829 to 0.14711, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1620 - val_loss: 0.1471
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1615
# Epoch 4: val_loss improved from 0.14711 to 0.14623, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1614 - val_loss: 0.1462
# Epoch 5/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1598
# Epoch 5: val_loss improved from 0.14623 to 0.14448, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4.h5
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1599 - val_loss: 0.1445
# Epoch 6/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1505
# Epoch 6: val_loss improved from 0.14448 to 0.12945, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1505 - val_loss: 0.1295
# Epoch 7/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1407
# Epoch 7: val_loss improved from 0.12945 to 0.12730, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1407 - val_loss: 0.1273
# Epoch 8/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1387
# Epoch 8: val_loss improved from 0.12730 to 0.12676, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1388 - val_loss: 0.1268
# Epoch 9/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1382
# Epoch 9: val_loss improved from 0.12676 to 0.12424, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1382 - val_loss: 0.1242
# Epoch 10/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1364
# Epoch 10: val_loss improved from 0.12424 to 0.12250, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1364 - val_loss: 0.1225
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_4/assets
# 2317/2317 [==============================] - 2s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 963us/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 4s 2ms/step
# 2576/2576 [==============================] - 4s 2ms/step
# Epoch 1/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.2709
# Epoch 1: val_loss improved from inf to 0.24562, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_5.h5
# 2317/2317 [==============================] - 16s 7ms/step - loss: 0.2709 - val_loss: 0.2456
# Epoch 2/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2421
# Epoch 2: val_loss improved from 0.24562 to 0.24476, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_5.h5
# 2317/2317 [==============================] - 15s 6ms/step - loss: 0.2422 - val_loss: 0.2448
# Epoch 3/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.2420
# Epoch 3: val_loss did not improve from 0.24476
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2421 - val_loss: 0.2448
# Epoch 4/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.2418
# Epoch 4: val_loss did not improve from 0.24476
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2418 - val_loss: 0.2456
# Epoch 5/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.2229
# Epoch 5: val_loss improved from 0.24476 to 0.21281, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_5.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2230 - val_loss: 0.2128
# Epoch 6/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.2112
# Epoch 6: val_loss improved from 0.21281 to 0.20954, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_5.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2112 - val_loss: 0.2095
# Epoch 7/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.2090
# Epoch 7: val_loss improved from 0.20954 to 0.20791, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_5.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2089 - val_loss: 0.2079
# Epoch 8/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.2079
# Epoch 8: val_loss improved from 0.20791 to 0.20626, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_5.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.2079 - val_loss: 0.2063
# Epoch 9/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.2066
# Epoch 9: val_loss did not improve from 0.20626
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2066 - val_loss: 0.2066
# Epoch 10/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.2054
# Epoch 10: val_loss improved from 0.20626 to 0.20531, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_5.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2055 - val_loss: 0.2053
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_5/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_5/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 944us/step
# 390/390 [==============================] - 0s 969us/step
# 258/258 [==============================] - 0s 949us/step
# 258/258 [==============================] - 0s 936us/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2773
# Epoch 1: val_loss improved from inf to 0.23654, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.2771 - val_loss: 0.2365
# Epoch 2/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.2176
# Epoch 2: val_loss improved from 0.23654 to 0.20716, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2176 - val_loss: 0.2072
# Epoch 3/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.2081
# Epoch 3: val_loss improved from 0.20716 to 0.20484, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2081 - val_loss: 0.2048
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2059
# Epoch 4: val_loss improved from 0.20484 to 0.20460, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.2060 - val_loss: 0.2046
# Epoch 5/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.2053
# Epoch 5: val_loss improved from 0.20460 to 0.20357, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2053 - val_loss: 0.2036
# Epoch 6/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2040
# Epoch 6: val_loss improved from 0.20357 to 0.20231, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6.h5
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.2039 - val_loss: 0.2023
# Epoch 7/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.2019
# Epoch 7: val_loss improved from 0.20231 to 0.20222, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.2019 - val_loss: 0.2022
# Epoch 8/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.2017
# Epoch 8: val_loss improved from 0.20222 to 0.20108, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6.h5
# 2317/2317 [==============================] - 15s 6ms/step - loss: 0.2018 - val_loss: 0.2011
# Epoch 9/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2014
# Epoch 9: val_loss improved from 0.20108 to 0.20085, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6.h5
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.2014 - val_loss: 0.2009
# Epoch 10/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.2008
# Epoch 10: val_loss improved from 0.20085 to 0.20010, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6.h5
# 2317/2317 [==============================] - 17s 8ms/step - loss: 0.2008 - val_loss: 0.2001
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_6/assets
# 2317/2317 [==============================] - 5s 2ms/step
# 2317/2317 [==============================] - 5s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 2576/2576 [==============================] - 6s 2ms/step
# 2576/2576 [==============================] - 6s 2ms/step
# Epoch 1/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.2508
# Epoch 1: val_loss improved from inf to 0.15712, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_7.h5
# 2317/2317 [==============================] - 19s 8ms/step - loss: 0.2507 - val_loss: 0.1571
# Epoch 2/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1665
# Epoch 2: val_loss improved from 0.15712 to 0.14745, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_7.h5
# 2317/2317 [==============================] - 18s 8ms/step - loss: 0.1665 - val_loss: 0.1474
# Epoch 3/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1620
# Epoch 3: val_loss improved from 0.14745 to 0.14706, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_7.h5
# 2317/2317 [==============================] - 17s 8ms/step - loss: 0.1620 - val_loss: 0.1471
# Epoch 4/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1611
# Epoch 4: val_loss improved from 0.14706 to 0.14536, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_7.h5
# 2317/2317 [==============================] - 17s 8ms/step - loss: 0.1611 - val_loss: 0.1454
# Epoch 5/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1613
# Epoch 5: val_loss did not improve from 0.14536
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.1612 - val_loss: 0.1468
# Epoch 6/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1606
# Epoch 6: val_loss did not improve from 0.14536
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1605 - val_loss: 0.1454
# Epoch 7/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1597
# Epoch 7: val_loss improved from 0.14536 to 0.14246, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_7.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1596 - val_loss: 0.1425
# Epoch 8/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1596
# Epoch 8: val_loss improved from 0.14246 to 0.14244, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_7.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1597 - val_loss: 0.1424
# Epoch 9/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1596
# Epoch 9: val_loss did not improve from 0.14244
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1595 - val_loss: 0.1434
# Epoch 10/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1585
# Epoch 10: val_loss did not improve from 0.14244
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1586 - val_loss: 0.1428
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_7/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_7/assets
# 2317/2317 [==============================] - 4s 2ms/step
# 2317/2317 [==============================] - 4s 2ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 4s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.2193
# Epoch 1: val_loss improved from inf to 0.14811, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_8.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.2193 - val_loss: 0.1481
# Epoch 2/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1630
# Epoch 2: val_loss improved from 0.14811 to 0.14438, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1630 - val_loss: 0.1444
# Epoch 3/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1600
# Epoch 3: val_loss improved from 0.14438 to 0.14351, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1600 - val_loss: 0.1435
# Epoch 4/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1574
# Epoch 4: val_loss improved from 0.14351 to 0.13997, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1574 - val_loss: 0.1400
# Epoch 5/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1545
# Epoch 5: val_loss improved from 0.13997 to 0.13850, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1545 - val_loss: 0.1385
# Epoch 6/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1524
# Epoch 6: val_loss improved from 0.13850 to 0.13694, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1524 - val_loss: 0.1369
# Epoch 7/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1511
# Epoch 7: val_loss improved from 0.13694 to 0.13287, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1511 - val_loss: 0.1329
# Epoch 8/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1491
# Epoch 8: val_loss improved from 0.13287 to 0.13229, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_8.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1491 - val_loss: 0.1323
# Epoch 9/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1485
# Epoch 9: val_loss improved from 0.13229 to 0.12992, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_8.h5
# 2317/2317 [==============================] - 15s 6ms/step - loss: 0.1485 - val_loss: 0.1299
# Epoch 10/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1481
# Epoch 10: val_loss did not improve from 0.12992
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.1481 - val_loss: 0.1300
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_8/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_8/assets
# 2317/2317 [==============================] - 4s 2ms/step
# 2317/2317 [==============================] - 4s 2ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 4s 2ms/step
# 2576/2576 [==============================] - 4s 1ms/step
# Epoch 1/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.2347
# Epoch 1: val_loss improved from inf to 0.15172, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_9.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.2345 - val_loss: 0.1517
# Epoch 2/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1637
# Epoch 2: val_loss improved from 0.15172 to 0.14463, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_9.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1637 - val_loss: 0.1446
# Epoch 3/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1598
# Epoch 3: val_loss did not improve from 0.14463
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1598 - val_loss: 0.1451
# Epoch 4/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1577
# Epoch 4: val_loss improved from 0.14463 to 0.14263, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_9.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1577 - val_loss: 0.1426
# Epoch 5/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1563
# Epoch 5: val_loss did not improve from 0.14263
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1564 - val_loss: 0.1431
# Epoch 6/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1562
# Epoch 6: val_loss improved from 0.14263 to 0.14136, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_9.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1562 - val_loss: 0.1414
# Epoch 7/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1557
# Epoch 7: val_loss improved from 0.14136 to 0.14043, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_9.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1557 - val_loss: 0.1404
# Epoch 8/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1554
# Epoch 8: val_loss did not improve from 0.14043
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1554 - val_loss: 0.1408
# Epoch 9/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1547
# Epoch 9: val_loss improved from 0.14043 to 0.14021, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_9.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1547 - val_loss: 0.1402
# Epoch 10/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1552
# Epoch 10: val_loss improved from 0.14021 to 0.13981, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_9.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1552 - val_loss: 0.1398
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_9/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_9/assets
# 2317/2317 [==============================] - 4s 2ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 4s 2ms/step
# 2576/2576 [==============================] - 4s 2ms/step
# Epoch 1/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.2992
# Epoch 1: val_loss improved from inf to 0.22780, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_10.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.2992 - val_loss: 0.2278
# Epoch 2/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.2153
# Epoch 2: val_loss improved from 0.22780 to 0.20304, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_10.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2153 - val_loss: 0.2030
# Epoch 3/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.2079
# Epoch 3: val_loss improved from 0.20304 to 0.20005, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_10.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2079 - val_loss: 0.2000
# Epoch 4/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.2064
# Epoch 4: val_loss improved from 0.20005 to 0.19896, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_10.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2064 - val_loss: 0.1990
# Epoch 5/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.2048
# Epoch 5: val_loss improved from 0.19896 to 0.19888, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_10.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2048 - val_loss: 0.1989
# Epoch 6/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.2041
# Epoch 6: val_loss improved from 0.19888 to 0.19732, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_10.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2041 - val_loss: 0.1973
# Epoch 7/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.2040
# Epoch 7: val_loss did not improve from 0.19732
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2040 - val_loss: 0.1981
# Epoch 8/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.2033
# Epoch 8: val_loss did not improve from 0.19732
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2032 - val_loss: 0.1978
# Epoch 9/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.2029
# Epoch 9: val_loss did not improve from 0.19732
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2029 - val_loss: 0.1974
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.2027
# Epoch 10: val_loss improved from 0.19732 to 0.19630, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_10.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2027 - val_loss: 0.1963
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_10/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_4_tiling_10/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 4s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 4s 2ms/step
# 2576/2576 [==============================] - 4s 1ms/step

# %%
display_fits(fits)
# Out:
# Average correlation on tiling: 0.49614366984544017
# Average MSE on tiling: 0.1778814229669506
# Average correlation on random: 0.4662295659596296
# Average MSE on random: 0.111758420869188
# Average correlation on ChrV: 0.4003733772545225
# Average MSE on ChrV: 0.24019602062408169
# Average correlation on CN: 0.4384643603694003
# Average MSE on CN: 0.18043639550955398

# %%
first_conv_model = Model(inputs = model.input, outputs = model.layers[1].output)
first_conv_output = first_conv_model.predict(X5)
pd.DataFrame(first_conv_output.reshape(first_conv_output.shape[0], -1)).to_csv(save_path + model_name+"_tiling_tiling_first_conv_output")
first_conv_output_random = first_conv_model.predict(X3)
pd.DataFrame(first_conv_output_random.reshape(first_conv_output_random.shape[0], -1)).to_csv(save_path + model_name+"_tiling_random_first_conv_output")
# Out:
# 2574/2574 [==============================] - 5s 2ms/step
# 390/390 [==============================] - 1s 1ms/step

# %%
first_conv_weights = model.layers[1].weights[0]
first_conv_biases = model.layers[1].weights[1]
# Format: [Position 0: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT  Position 1: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT,
# ..., Position 20: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT]
pd.DataFrame(array(first_conv_weights).transpose((3,2,0,1)).reshape(first_conv_weights.shape[-1], -1)).to_csv(save_path + model_name+"_tiling_first_conv_kernels")
pd.DataFrame(first_conv_biases).to_csv(save_path + model_name+"_tiling_first_conv_biases")
