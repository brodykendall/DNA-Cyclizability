# %%
import time
import keras

from keras.models import Model
from keras.layers import Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Add, Concatenate
from keras.layers import Dense, Conv2D, MaxPooling2D, LSTM, TimeDistributed, Reshape
import keras.backend as K
import keras.callbacks as callbacks

import pandas as pd
import numpy as np
from numpy import array
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
# Out:
# 2023-04-26 09:05:15.055639: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
save_path = "/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/"
model_name = "conv_only_tri_6"
kf = KFold(n_splits = 10, shuffle =True)
num_epochs = 10

#### define functions ####

def model_cycle():
    inputs = Input(shape=(48, 64, 1))
        
    x = Conv2D(16, kernel_size=(21,64),
                   activation='relu',
                   padding='valid')(inputs)
    x = MaxPooling2D((2,1),padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # print(f"After first convolutional layer: x.shape = {x.shape}")

    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = Conv1D(48, kernel_size=(11),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After second convolutional layer: x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((24,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After third convolutional layer, x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((12,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # # parallel line 1
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(fx1)
    # fx1 = MaxPooling2D((2,1),padding='same')(fx1)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    
    # # parallel line 2
    # fx2 = Conv2D(48, kernel_size=(11,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    # fx2 = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(fx2)
    # fx2 = MaxPooling2D((2,1),padding='same')(fx2)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    
    # # # Add
    # x1 = Concatenate(axis=-3)([fx1, fx2])
    # x = Add()([x, x1])
    # x = MaxPooling2D((2,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    
    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = LSTM(20, return_sequences=False)(x)
    # x = Dropout(0.2)(x)

    # x = Reshape((1, 24*48))(x)
    x = Flatten()(x)

    outputs = Dense(1, activation='linear')(x)
    # print(outputs.shape)
    network = Model(inputs, outputs)
    network.compile(optimizer='rmsprop',
                    loss='mean_squared_error')
    return network

# %%
def triOneHot(sequence):
    code = {"AAA": [0], "AAC": [1], "AAG": [2], "AAT": [3],
            "ACA": [4], "ACC": [5], "ACG": [6], "ACT": [7], 
            "AGA": [8], "AGC": [9], "AGG": [10], "AGT": [11], 
            "ATA": [12], "ATC": [13], "ATG": [14], "ATT": [15], 
            "CAA": [16], "CAC": [17], "CAG": [18], "CAT": [19], 
            "CCA": [20], "CCC": [21], "CCG": [22], "CCT": [23], 
            "CGA": [24], "CGC": [25], "CGG": [26], "CGT": [27], 
            "CTA": [28], "CTC": [29], "CTG": [30], "CTT": [31], 
            "GAA": [32], "GAC": [33], "GAG": [34], "GAT": [35],
            "GCA": [36], "GCC": [37], "GCG": [38], "GCT": [39], 
            "GGA": [40], "GGC": [41], "GGG": [42], "GGT": [43], 
            "GTA": [44], "GTC": [45], "GTG": [46], "GTT": [47], 
            "TAA": [48], "TAC": [49], "TAG": [50], "TAT": [51], 
            "TCA": [52], "TCC": [53], "TCG": [54], "TCT": [55], 
            "TGA": [56], "TGC": [57], "TGG": [58], "TGT": [59], 
            "TTA": [60], "TTC": [61], "TTG": [62], "TTT": [63],   "N": [64]}
    onehot_encoded_seq = []
    for i, _ in enumerate(sequence[:(len(sequence)-2)]):
        onehot_encoded = np.zeros(65)
        onehot_encoded[code[sequence[i:i+3]]] = 1
        onehot_encoded_seq.append(onehot_encoded[0:64])
    return onehot_encoded_seq

# %%
def display_fits(fits):
    print(f"Average correlation on tiling: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 5])}",
          f"\nAverage MSE on tiling: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 5])}",
          f"\nAverage correlation on random: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 3])}",
          f"\nAverage MSE on random: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 3])}",
          f"\nAverage correlation on ChrV: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 7])}",
          f"\nAverage MSE on ChrV: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 7])}",
          f"\nAverage correlation on CN: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 0])}",
          f"\nAverage MSE on CN: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 0])}")

# %%
def find_c0new(dat):
  mat = np.empty((3,3), float)
  k = 2*np.pi/10.4
  n = array([26, 29, 31])
  mat[0:3,0] = 1
  mat[0:3, 1] = np.sin(n*k)
  mat[0:3, 2] = np.cos(n*k)
  inv_mat = np.linalg.inv(mat)
  c0A1A2 = array(np.matmul(dat[["n=26", "n=29", "n=31"]], np.transpose(inv_mat)))
  c0Aphi = c0A1A2
  c0Aphi[:,0] = c0A1A2[:,0]
  c0Aphi[:,1] = np.sqrt(c0A1A2[:,1]**2 + c0A1A2[:,2]**2)
  c0Aphi[:,2] <- np.sign(c0A1A2[:,2]) * np.arccos(c0A1A2[:,1]/c0Aphi[:,1])
  return c0Aphi[:,0]

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.process_time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.process_time() - self.epoch_time_start)
        
#### preparing data ####

data_cerevisiae_nucle = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle1.txt",delimiter = ",")
X1 = []
for sequence_nt in data_cerevisiae_nucle["Sequence"]:
    X1.append(triOneHot(sequence_nt))
X1 = array(X1)
X1 = X1.reshape((X1.shape[0],48,64,1))
X1_reverse = np.flip(X1,[1,2])
# Y1 = data_cerevisiae_nucle["C0"].values.astype(float)
Y1 = find_c0new(data_cerevisiae_nucle).astype(float)

# %%
data_random_library = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle3.txt",delimiter = ",")
X3 = []
for sequence_nt in data_random_library["Sequence"]:
    X3.append(triOneHot(sequence_nt))
X3 = array(X3)
X3 = X3.reshape((X3.shape[0],48,64,1))
X3_reverse = np.flip(X3,[1,2])
# Y3 = data_random_library["C0"].values.astype(float)
Y3 = find_c0new(data_random_library).astype(float)

# %%
data_tiling = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle5.txt",delimiter = ",")
X5 = []
for sequence_nt in data_tiling["Sequence"]:
    X5.append(triOneHot(sequence_nt))
X5 = array(X5)
X5 = X5.reshape((X5.shape[0],48,64,1))
X5_reverse = np.flip(X5,[1,2])
# Y5 = data_tiling["C0"].values.astype(float)
Y5 = find_c0new(data_tiling).astype(float)

# %%
data_chr5 = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle6.txt",delimiter = ",")
X6 = []
for sequence_nt in data_chr5["Sequence"]:
    X6.append(triOneHot(sequence_nt))
X6 = array(X6)
X6 = X6.reshape((X6.shape[0],48,64,1))
X6_reverse = np.flip(X6,[1,2])
# Y6 = data_chr5["C0"].values.astype(float)
Y6 = find_c0new(data_chr5).astype(float)

# %%
#### tiling

VALIDATION_LOSS = []
fold_var = 1
n = Y5.shape[0]

fits = []
detrend = []
times = []
times2 = []

for train_index, val_index in kf.split(Y5):
    training_X = X5[train_index]
    training_X_reverse = X5_reverse[train_index]
    validation_X = X5[val_index]
    validation_X_reverse = X5_reverse[val_index]
    training_Y = Y5[train_index]
    validation_Y = Y5[val_index]
    # CREATE NEW MODEL
    model = model_cycle()
    # CREATE CALLBACKS
    checkpoint = callbacks.ModelCheckpoint(save_path + model_name+"_tiling_"+str(fold_var)+".h5",
                                                    monitor='val_loss', verbose=1,
                                                    save_best_only=True, mode='min')
    time_callback = TimeHistory()

    history = model.fit(training_X, training_Y,
                        epochs=num_epochs,
                        callbacks= [checkpoint, time_callback],
                        validation_data=(validation_X, validation_Y))
    model.load_weights(save_path + model_name+"_tiling_"+str(fold_var)+".h5")
    model.save(save_path+model_name+"_tiling_"+str(fold_var),save_traces=False)
    times.append(time_callback.times)

    pred_Y = model.predict(training_X)
    pred_Y = pred_Y.reshape(pred_Y.shape[0])
    pred_Y_reverse = model.predict(training_X_reverse)
    pred_Y_reverse = pred_Y_reverse.reshape(pred_Y_reverse.shape[0])
    pred_Y = (pred_Y+pred_Y_reverse)/2
    reg =  LinearRegression().fit(array(pred_Y).reshape(-1, 1), array(training_Y).reshape(-1, 1))
    
    detrend_int = reg.intercept_
    detrend_slope = reg.coef_
    detrend.append([float(detrend_int), float(detrend_slope)])

    start_time = time.process_time()
    fit = model.predict(X1)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X1_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X3)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X3_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(validation_X)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(validation_X_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X6)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X6_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    K.clear_session()
    fold_var += 1
    
detrend = array(detrend)
detrend = pd.DataFrame(detrend)
detrend.to_csv(save_path +model_name+"_detrend_tiling.txt", index = False)

fits = array(fits)
fits = pd.DataFrame((fits))
fits.to_csv(save_path +model_name+ "_fits_tiling.txt", index = False)

with open(save_path +model_name+"_time_tiling.txt", "w") as file:
    for row in times:
        s = " ".join(map(str, row))
        file.write(s+'\n')

with open(save_path +model_name+"_pred_time_tiling.txt", "w") as file:
    for row in times2:
        s = " ".join(map(str, row))
        file.write(s+'\n')
# Out:
# 2023-04-26 09:06:41.829758: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.2023
# Epoch 1: val_loss improved from inf to 0.14020, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_1.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2023 - val_loss: 0.1402
# Epoch 2/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1493
# Epoch 2: val_loss improved from 0.14020 to 0.13068, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_1.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1493 - val_loss: 0.1307
# Epoch 3/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1426
# Epoch 3: val_loss improved from 0.13068 to 0.12488, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1426 - val_loss: 0.1249
# Epoch 4/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1390
# Epoch 4: val_loss improved from 0.12488 to 0.12457, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1390 - val_loss: 0.1246
# Epoch 5/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1358
# Epoch 5: val_loss improved from 0.12457 to 0.12167, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1358 - val_loss: 0.1217
# Epoch 6/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1346
# Epoch 6: val_loss improved from 0.12167 to 0.12127, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_1.h5
# 2317/2317 [==============================] - 15s 7ms/step - loss: 0.1346 - val_loss: 0.1213
# Epoch 7/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1319
# Epoch 7: val_loss improved from 0.12127 to 0.11859, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_1.h5
# 2317/2317 [==============================] - 16s 7ms/step - loss: 0.1319 - val_loss: 0.1186
# Epoch 8/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1303
# Epoch 8: val_loss did not improve from 0.11859
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1303 - val_loss: 0.1199
# Epoch 9/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1282
# Epoch 9: val_loss improved from 0.11859 to 0.11760, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_1.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1283 - val_loss: 0.1176
# Epoch 10/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1274
# Epoch 10: val_loss did not improve from 0.11760
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1274 - val_loss: 0.1183
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_1/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_1/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.2343
# Epoch 1: val_loss improved from inf to 0.19266, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_2.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2342 - val_loss: 0.1927
# Epoch 2/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1711
# Epoch 2: val_loss improved from 0.19266 to 0.13832, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_2.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1711 - val_loss: 0.1383
# Epoch 3/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1497
# Epoch 3: val_loss improved from 0.13832 to 0.12956, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1497 - val_loss: 0.1296
# Epoch 4/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1450
# Epoch 4: val_loss improved from 0.12956 to 0.12846, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1452 - val_loss: 0.1285
# Epoch 5/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1424
# Epoch 5: val_loss improved from 0.12846 to 0.12469, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_2.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1424 - val_loss: 0.1247
# Epoch 6/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1394
# Epoch 6: val_loss improved from 0.12469 to 0.12396, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1394 - val_loss: 0.1240
# Epoch 7/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1374
# Epoch 7: val_loss improved from 0.12396 to 0.12174, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1375 - val_loss: 0.1217
# Epoch 8/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1348
# Epoch 8: val_loss did not improve from 0.12174
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1348 - val_loss: 0.1231
# Epoch 9/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1346
# Epoch 9: val_loss improved from 0.12174 to 0.12152, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1346 - val_loss: 0.1215
# Epoch 10/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1341
# Epoch 10: val_loss improved from 0.12152 to 0.11974, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1341 - val_loss: 0.1197
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_2/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_2/assets
# 2317/2317 [==============================] - 4s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1939
# Epoch 1: val_loss improved from inf to 0.14611, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_3.h5
# 2317/2317 [==============================] - 11s 4ms/step - loss: 0.1938 - val_loss: 0.1461
# Epoch 2/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1482
# Epoch 2: val_loss improved from 0.14611 to 0.13233, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_3.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1481 - val_loss: 0.1323
# Epoch 3/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1372
# Epoch 3: val_loss improved from 0.13233 to 0.12765, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1373 - val_loss: 0.1277
# Epoch 4/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1337
# Epoch 4: val_loss improved from 0.12765 to 0.12469, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1337 - val_loss: 0.1247
# Epoch 5/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1307
# Epoch 5: val_loss improved from 0.12469 to 0.12443, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_3.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1307 - val_loss: 0.1244
# Epoch 6/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1291
# Epoch 6: val_loss improved from 0.12443 to 0.12209, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_3.h5
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1291 - val_loss: 0.1221
# Epoch 7/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1271
# Epoch 7: val_loss improved from 0.12209 to 0.12134, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1271 - val_loss: 0.1213
# Epoch 8/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1254
# Epoch 8: val_loss did not improve from 0.12134
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1254 - val_loss: 0.1236
# Epoch 9/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1242
# Epoch 9: val_loss improved from 0.12134 to 0.12030, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1241 - val_loss: 0.1203
# Epoch 10/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1236
# Epoch 10: val_loss improved from 0.12030 to 0.11990, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1236 - val_loss: 0.1199
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_3/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_3/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.2277
# Epoch 1: val_loss improved from inf to 0.15354, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_4.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2275 - val_loss: 0.1535
# Epoch 2/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1532
# Epoch 2: val_loss improved from 0.15354 to 0.13437, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1532 - val_loss: 0.1344
# Epoch 3/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1449
# Epoch 3: val_loss improved from 0.13437 to 0.12772, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1449 - val_loss: 0.1277
# Epoch 4/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1414
# Epoch 4: val_loss improved from 0.12772 to 0.12756, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1414 - val_loss: 0.1276
# Epoch 5/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1398
# Epoch 5: val_loss did not improve from 0.12756
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1398 - val_loss: 0.1278
# Epoch 6/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1375
# Epoch 6: val_loss improved from 0.12756 to 0.12654, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1375 - val_loss: 0.1265
# Epoch 7/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1364
# Epoch 7: val_loss improved from 0.12654 to 0.12403, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1365 - val_loss: 0.1240
# Epoch 8/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1357
# Epoch 8: val_loss did not improve from 0.12403
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1357 - val_loss: 0.1241
# Epoch 9/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1337
# Epoch 9: val_loss improved from 0.12403 to 0.12329, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_4.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1335 - val_loss: 0.1233
# Epoch 10/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1322
# Epoch 10: val_loss improved from 0.12329 to 0.12290, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_4.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1321 - val_loss: 0.1229
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_4/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_4/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 2ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1898
# Epoch 1: val_loss improved from inf to 0.13490, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_5.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1897 - val_loss: 0.1349
# Epoch 2/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1441
# Epoch 2: val_loss improved from 0.13490 to 0.12410, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1440 - val_loss: 0.1241
# Epoch 3/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1371
# Epoch 3: val_loss did not improve from 0.12410
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1370 - val_loss: 0.1246
# Epoch 4/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1331
# Epoch 4: val_loss improved from 0.12410 to 0.12251, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1331 - val_loss: 0.1225
# Epoch 5/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1320
# Epoch 5: val_loss improved from 0.12251 to 0.12140, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1319 - val_loss: 0.1214
# Epoch 6/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1305
# Epoch 6: val_loss did not improve from 0.12140
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1305 - val_loss: 0.1222
# Epoch 7/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1293
# Epoch 7: val_loss improved from 0.12140 to 0.12087, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1294 - val_loss: 0.1209
# Epoch 8/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1284
# Epoch 8: val_loss did not improve from 0.12087
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1285 - val_loss: 0.1212
# Epoch 9/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1275
# Epoch 9: val_loss improved from 0.12087 to 0.12082, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_5.h5
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1276 - val_loss: 0.1208
# Epoch 10/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1268
# Epoch 10: val_loss did not improve from 0.12082
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1268 - val_loss: 0.1211
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_5/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_5/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 2ms/step
# 2576/2576 [==============================] - 4s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1999
# Epoch 1: val_loss improved from inf to 0.15564, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_6.h5
# 2317/2317 [==============================] - 11s 4ms/step - loss: 0.1999 - val_loss: 0.1556
# Epoch 2/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1631
# Epoch 2: val_loss improved from 0.15564 to 0.14462, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1632 - val_loss: 0.1446
# Epoch 3/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1559
# Epoch 3: val_loss improved from 0.14462 to 0.13566, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1558 - val_loss: 0.1357
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1505
# Epoch 4: val_loss improved from 0.13566 to 0.13309, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1505 - val_loss: 0.1331
# Epoch 5/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1457
# Epoch 5: val_loss improved from 0.13309 to 0.13006, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1457 - val_loss: 0.1301
# Epoch 6/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1427
# Epoch 6: val_loss improved from 0.13006 to 0.12696, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1427 - val_loss: 0.1270
# Epoch 7/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1402
# Epoch 7: val_loss improved from 0.12696 to 0.12679, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1401 - val_loss: 0.1268
# Epoch 8/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1384
# Epoch 8: val_loss improved from 0.12679 to 0.12510, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_6.h5
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1383 - val_loss: 0.1251
# Epoch 9/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1376
# Epoch 9: val_loss did not improve from 0.12510
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1376 - val_loss: 0.1261
# Epoch 10/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1365
# Epoch 10: val_loss improved from 0.12510 to 0.12500, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_6.h5
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1365 - val_loss: 0.1250
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_6/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_6/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.2113
# Epoch 1: val_loss improved from inf to 0.13606, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_7.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2112 - val_loss: 0.1361
# Epoch 2/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1405
# Epoch 2: val_loss improved from 0.13606 to 0.12273, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_7.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1405 - val_loss: 0.1227
# Epoch 3/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1340
# Epoch 3: val_loss improved from 0.12273 to 0.12090, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_7.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1340 - val_loss: 0.1209
# Epoch 4/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1305
# Epoch 4: val_loss improved from 0.12090 to 0.11831, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_7.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1304 - val_loss: 0.1183
# Epoch 5/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1275
# Epoch 5: val_loss improved from 0.11831 to 0.11655, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_7.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1275 - val_loss: 0.1166
# Epoch 6/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1265
# Epoch 6: val_loss did not improve from 0.11655
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1265 - val_loss: 0.1176
# Epoch 7/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1248
# Epoch 7: val_loss improved from 0.11655 to 0.11570, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_7.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1248 - val_loss: 0.1157
# Epoch 8/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1239
# Epoch 8: val_loss did not improve from 0.11570
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1239 - val_loss: 0.1174
# Epoch 9/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1227
# Epoch 9: val_loss improved from 0.11570 to 0.11548, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_7.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1227 - val_loss: 0.1155
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1220
# Epoch 10: val_loss improved from 0.11548 to 0.11409, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_7.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1220 - val_loss: 0.1141
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_7/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_7/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.2024
# Epoch 1: val_loss improved from inf to 0.12819, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2024 - val_loss: 0.1282
# Epoch 2/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1364
# Epoch 2: val_loss improved from 0.12819 to 0.12204, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_8.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1365 - val_loss: 0.1220
# Epoch 3/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1325
# Epoch 3: val_loss did not improve from 0.12204
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1325 - val_loss: 0.1231
# Epoch 4/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1289
# Epoch 4: val_loss improved from 0.12204 to 0.11870, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_8.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1289 - val_loss: 0.1187
# Epoch 5/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1287
# Epoch 5: val_loss improved from 0.11870 to 0.11798, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_8.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1287 - val_loss: 0.1180
# Epoch 6/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1279
# Epoch 6: val_loss improved from 0.11798 to 0.11755, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_8.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1278 - val_loss: 0.1176
# Epoch 7/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1264
# Epoch 7: val_loss did not improve from 0.11755
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1264 - val_loss: 0.1196
# Epoch 8/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1255
# Epoch 8: val_loss improved from 0.11755 to 0.11649, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_8.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1255 - val_loss: 0.1165
# Epoch 9/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1243
# Epoch 9: val_loss did not improve from 0.11649
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1243 - val_loss: 0.1174
# Epoch 10/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1240
# Epoch 10: val_loss did not improve from 0.11649
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1240 - val_loss: 0.1174
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_8/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_8/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.2014
# Epoch 1: val_loss improved from inf to 0.13864, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_9.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.2014 - val_loss: 0.1386
# Epoch 2/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1457
# Epoch 2: val_loss improved from 0.13864 to 0.13126, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_9.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1457 - val_loss: 0.1313
# Epoch 3/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1421
# Epoch 3: val_loss improved from 0.13126 to 0.12839, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_9.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1421 - val_loss: 0.1284
# Epoch 4/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1390
# Epoch 4: val_loss did not improve from 0.12839
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1391 - val_loss: 0.1290
# Epoch 5/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1376
# Epoch 5: val_loss improved from 0.12839 to 0.12541, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_9.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1376 - val_loss: 0.1254
# Epoch 6/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1365
# Epoch 6: val_loss did not improve from 0.12541
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1365 - val_loss: 0.1261
# Epoch 7/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1357
# Epoch 7: val_loss did not improve from 0.12541
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1356 - val_loss: 0.1255
# Epoch 8/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1346
# Epoch 8: val_loss improved from 0.12541 to 0.12411, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_9.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1346 - val_loss: 0.1241
# Epoch 9/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1343
# Epoch 9: val_loss improved from 0.12411 to 0.12322, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_9.h5
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1344 - val_loss: 0.1232
# Epoch 10/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1335
# Epoch 10: val_loss did not improve from 0.12322
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1334 - val_loss: 0.1232
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_9/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_9/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1896
# Epoch 1: val_loss improved from inf to 0.12906, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_10.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1894 - val_loss: 0.1291
# Epoch 2/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1438
# Epoch 2: val_loss improved from 0.12906 to 0.12412, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1438 - val_loss: 0.1241
# Epoch 3/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1392
# Epoch 3: val_loss improved from 0.12412 to 0.12311, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1392 - val_loss: 0.1231
# Epoch 4/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1366
# Epoch 4: val_loss improved from 0.12311 to 0.12100, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1366 - val_loss: 0.1210
# Epoch 5/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1357
# Epoch 5: val_loss did not improve from 0.12100
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1358 - val_loss: 0.1216
# Epoch 6/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1350
# Epoch 6: val_loss improved from 0.12100 to 0.12041, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_10.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1349 - val_loss: 0.1204
# Epoch 7/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1333
# Epoch 7: val_loss improved from 0.12041 to 0.12011, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1332 - val_loss: 0.1201
# Epoch 8/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1323
# Epoch 8: val_loss improved from 0.12011 to 0.11916, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1323 - val_loss: 0.1192
# Epoch 9/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1314
# Epoch 9: val_loss improved from 0.11916 to 0.11898, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1313 - val_loss: 0.1190
# Epoch 10/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1295
# Epoch 10: val_loss improved from 0.11898 to 0.11613, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_10.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1295 - val_loss: 0.1161
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_10/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_6_tiling_10/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step

# %%
display_fits(fits)
# Out:
# Average correlation on tiling: 0.656213395193182
# Average MSE on tiling: 0.13801191673386093
# Average correlation on random: 0.6148232899616974
# Average MSE on random: 0.09102274638607497
# Average correlation on ChrV: 0.5299032367499538
# Average MSE on ChrV: 0.20967358119779958
# Average correlation on CN: 0.5901725090009999
# Average MSE on CN: 0.15402092420557673
