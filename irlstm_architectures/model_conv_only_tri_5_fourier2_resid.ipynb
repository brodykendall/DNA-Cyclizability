# %%
import time
import keras

from keras.models import Model
from keras.layers import Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Add, Concatenate
from keras.layers import Dense, Conv2D, MaxPooling2D, LSTM, TimeDistributed, Reshape
import keras.backend as K
import keras.callbacks as callbacks

import pandas as pd
import numpy as np
from numpy import array
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
# Out:
# 2023-05-03 11:41:47.818751: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
save_path = "/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/"
model_name = "conv_only_tri_5_fourier2_resid"
kf = KFold(n_splits = 10, shuffle =True)
num_epochs = 10

#### define functions ####

def model_cycle():
    inputs = Input(shape=(48, 64, 1))
        
    x = Conv2D(8, kernel_size=(21,64),
                   activation='relu',
                   padding='valid')(inputs)
    x = MaxPooling2D((2,1),padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # print(f"After first convolutional layer: x.shape = {x.shape}")

    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = Conv1D(48, kernel_size=(11),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After second convolutional layer: x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((24,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After third convolutional layer, x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((12,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # # parallel line 1
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(fx1)
    # fx1 = MaxPooling2D((2,1),padding='same')(fx1)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    
    # # parallel line 2
    # fx2 = Conv2D(48, kernel_size=(11,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    # fx2 = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(fx2)
    # fx2 = MaxPooling2D((2,1),padding='same')(fx2)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    
    # # # Add
    # x1 = Concatenate(axis=-3)([fx1, fx2])
    # x = Add()([x, x1])
    # x = MaxPooling2D((2,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    
    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = LSTM(20, return_sequences=False)(x)
    # x = Dropout(0.2)(x)

    # x = Reshape((1, 24*48))(x)
    x = Flatten()(x)

    outputs = Dense(1, activation='linear')(x)
    # print(outputs.shape)
    network = Model(inputs, outputs)
    network.compile(optimizer='rmsprop',
                    loss='mean_squared_error')
    return network

# %%
def triOneHot(sequence):
    code = {"AAA": [0], "AAC": [1], "AAG": [2], "AAT": [3],
            "ACA": [4], "ACC": [5], "ACG": [6], "ACT": [7], 
            "AGA": [8], "AGC": [9], "AGG": [10], "AGT": [11], 
            "ATA": [12], "ATC": [13], "ATG": [14], "ATT": [15], 
            "CAA": [16], "CAC": [17], "CAG": [18], "CAT": [19], 
            "CCA": [20], "CCC": [21], "CCG": [22], "CCT": [23], 
            "CGA": [24], "CGC": [25], "CGG": [26], "CGT": [27], 
            "CTA": [28], "CTC": [29], "CTG": [30], "CTT": [31], 
            "GAA": [32], "GAC": [33], "GAG": [34], "GAT": [35],
            "GCA": [36], "GCC": [37], "GCG": [38], "GCT": [39], 
            "GGA": [40], "GGC": [41], "GGG": [42], "GGT": [43], 
            "GTA": [44], "GTC": [45], "GTG": [46], "GTT": [47], 
            "TAA": [48], "TAC": [49], "TAG": [50], "TAT": [51], 
            "TCA": [52], "TCC": [53], "TCG": [54], "TCT": [55], 
            "TGA": [56], "TGC": [57], "TGG": [58], "TGT": [59], 
            "TTA": [60], "TTC": [61], "TTG": [62], "TTT": [63],   "N": [64]}
    onehot_encoded_seq = []
    for i, _ in enumerate(sequence[:(len(sequence)-2)]):
        onehot_encoded = np.zeros(65)
        onehot_encoded[code[sequence[i:i+3]]] = 1
        onehot_encoded_seq.append(onehot_encoded[0:64])
    return onehot_encoded_seq

# %%
def display_fits(fits):
    print(f"Average correlation on tiling: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 5])}",
          f"\nAverage MSE on tiling: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 5])}",
          f"\nAverage correlation on random: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 3])}",
          f"\nAverage MSE on random: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 3])}",
          f"\nAverage correlation on ChrV: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 7])}",
          f"\nAverage MSE on ChrV: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 7])}",
          f"\nAverage correlation on CN: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 0])}",
          f"\nAverage MSE on CN: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 0])}")

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.process_time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.process_time() - self.epoch_time_start)
        
#### preparing data ####

data_cerevisiae_nucle = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/data/Created/yeast_all_fourier_6_mod3_resids.csv")
X1 = []
for sequence_nt in data_cerevisiae_nucle["x50mer"]:
    X1.append(triOneHot(sequence_nt))
X1 = array(X1)
X1 = X1.reshape((X1.shape[0],48,64,1))
X1_reverse = np.flip(X1,[1,2])
Y1 = data_cerevisiae_nucle["residuals"].values.astype(float)

# %%
data_random_library = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/data/Created/random_all_fourier_6_mod3_resids.csv")
X3 = []
for sequence_nt in data_random_library["x50mer"]:
    X3.append(triOneHot(sequence_nt))
X3 = array(X3)
X3 = X3.reshape((X3.shape[0],48,64,1))
X3_reverse = np.flip(X3,[1,2])
Y3 = data_random_library["residuals"].values.astype(float)

# %%
data_tiling = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/data/Created/tiling_all_fourier_6_mod3_resids.csv")
X5 = []
for sequence_nt in data_tiling["x50mer"]:
    X5.append(triOneHot(sequence_nt))
X5 = array(X5)
X5 = X5.reshape((X5.shape[0],48,64,1))
X5_reverse = np.flip(X5,[1,2])
Y5 = data_tiling["residuals"].values.astype(float)

# %%
data_chr5 = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/data/Created/chrV_all_fourier_6_mod3_resids.csv")
X6 = []
for sequence_nt in data_chr5["x50mer"]:
    X6.append(triOneHot(sequence_nt))
X6 = array(X6)
X6 = X6.reshape((X6.shape[0],48,64,1))
X6_reverse = np.flip(X6,[1,2])
Y6 = data_chr5["residuals"].values.astype(float)

# %%
#### tiling

VALIDATION_LOSS = []
fold_var = 1
n = Y5.shape[0]

fits = []
detrend = []
times = []
times2 = []

for train_index, val_index in kf.split(Y5):
    training_X = X5[train_index]
    training_X_reverse = X5_reverse[train_index]
    validation_X = X5[val_index]
    validation_X_reverse = X5_reverse[val_index]
    training_Y = Y5[train_index]
    validation_Y = Y5[val_index]
    # CREATE NEW MODEL
    model = model_cycle()
    # CREATE CALLBACKS
    checkpoint = callbacks.ModelCheckpoint(save_path + model_name+"_tiling_"+str(fold_var)+".h5",
                                                    monitor='val_loss', verbose=1,
                                                    save_best_only=True, mode='min')
    time_callback = TimeHistory()

    history = model.fit(training_X, training_Y,
                        epochs=num_epochs,
                        callbacks= [checkpoint, time_callback],
                        validation_data=(validation_X, validation_Y))
    model.load_weights(save_path + model_name+"_tiling_"+str(fold_var)+".h5")
    model.save(save_path+model_name+"_tiling_"+str(fold_var),save_traces=False)
    times.append(time_callback.times)

    pred_Y = model.predict(training_X)
    pred_Y = pred_Y.reshape(pred_Y.shape[0])
    pred_Y_reverse = model.predict(training_X_reverse)
    pred_Y_reverse = pred_Y_reverse.reshape(pred_Y_reverse.shape[0])
    pred_Y = (pred_Y+pred_Y_reverse)/2
    reg =  LinearRegression().fit(array(pred_Y).reshape(-1, 1), array(training_Y).reshape(-1, 1))
    
    detrend_int = reg.intercept_
    detrend_slope = reg.coef_
    detrend.append([float(detrend_int), float(detrend_slope)])

    start_time = time.process_time()
    fit = model.predict(X1)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X1_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X3)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X3_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(validation_X)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(validation_X_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X6)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X6_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    K.clear_session()
    fold_var += 1
    
detrend = array(detrend)
detrend = pd.DataFrame(detrend)
detrend.to_csv(save_path +model_name+"_detrend_tiling.txt", index = False)

fits = array(fits)
fits = pd.DataFrame((fits))
fits.to_csv(save_path +model_name+ "_fits_tiling.txt", index = False)

with open(save_path +model_name+"_time_tiling.txt", "w") as file:
    for row in times:
        s = " ".join(map(str, row))
        file.write(s+'\n')

with open(save_path +model_name+"_pred_time_tiling.txt", "w") as file:
    for row in times2:
        s = " ".join(map(str, row))
        file.write(s+'\n')
# Out:
# 2023-05-03 11:43:28.003484: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1838
# Epoch 1: val_loss improved from inf to 0.16052, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_1.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1837 - val_loss: 0.1605
# Epoch 2/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1565
# Epoch 2: val_loss did not improve from 0.16052
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1565 - val_loss: 0.1607
# Epoch 3/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1565
# Epoch 3: val_loss did not improve from 0.16052
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1565 - val_loss: 0.1606
# Epoch 4/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1566
# Epoch 4: val_loss did not improve from 0.16052
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1565 - val_loss: 0.1608
# Epoch 5/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1564
# Epoch 5: val_loss improved from 0.16052 to 0.16042, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_1.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1564 - val_loss: 0.1604
# Epoch 6/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1563
# Epoch 6: val_loss did not improve from 0.16042
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1563 - val_loss: 0.1606
# Epoch 7/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1563
# Epoch 7: val_loss did not improve from 0.16042
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1563 - val_loss: 0.1608
# Epoch 8/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1564
# Epoch 8: val_loss did not improve from 0.16042
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1563 - val_loss: 0.1608
# Epoch 9/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1563
# Epoch 9: val_loss did not improve from 0.16042
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1563 - val_loss: 0.1609
# Epoch 10/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1564
# Epoch 10: val_loss did not improve from 0.16042
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1564 - val_loss: 0.1607
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_1/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_1/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
#   1/258 [..............................] - ETA: 4s
# /Users/Brody1/anaconda3/envs/myenv/lib/python3.7/site-packages/numpy/lib/function_base.py:2691: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /Users/Brody1/anaconda3/envs/myenv/lib/python3.7/site-packages/numpy/lib/function_base.py:2692: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1797
# Epoch 1: val_loss improved from inf to 0.15823, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_2.h5
# 2317/2317 [==============================] - 11s 4ms/step - loss: 0.1796 - val_loss: 0.1582
# Epoch 2/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1567
# Epoch 2: val_loss improved from 0.15823 to 0.15795, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1567 - val_loss: 0.1580
# Epoch 3/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1563
# Epoch 3: val_loss did not improve from 0.15795
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1564 - val_loss: 0.1580
# Epoch 4/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1562
# Epoch 4: val_loss improved from 0.15795 to 0.15789, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1560 - val_loss: 0.1579
# Epoch 5/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1535
# Epoch 5: val_loss improved from 0.15789 to 0.14463, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1536 - val_loss: 0.1446
# Epoch 6/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1397
# Epoch 6: val_loss improved from 0.14463 to 0.13488, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1397 - val_loss: 0.1349
# Epoch 7/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1350
# Epoch 7: val_loss improved from 0.13488 to 0.13248, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1350 - val_loss: 0.1325
# Epoch 8/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1332
# Epoch 8: val_loss improved from 0.13248 to 0.13057, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1332 - val_loss: 0.1306
# Epoch 9/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1318
# Epoch 9: val_loss improved from 0.13057 to 0.12847, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1318 - val_loss: 0.1285
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1294
# Epoch 10: val_loss improved from 0.12847 to 0.12725, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_2.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1294 - val_loss: 0.1273
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_2/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_2/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 2s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1801
# Epoch 1: val_loss improved from inf to 0.15830, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_3.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1801 - val_loss: 0.1583
# Epoch 2/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1568
# Epoch 2: val_loss did not improve from 0.15830
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1568 - val_loss: 0.1583
# Epoch 3/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1567
# Epoch 3: val_loss did not improve from 0.15830
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1567 - val_loss: 0.1584
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1567
# Epoch 4: val_loss improved from 0.15830 to 0.15825, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1566 - val_loss: 0.1582
# Epoch 5/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1566
# Epoch 5: val_loss did not improve from 0.15825
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.1566 - val_loss: 0.1583
# Epoch 6/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1564
# Epoch 6: val_loss improved from 0.15825 to 0.15821, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_3.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1565 - val_loss: 0.1582
# Epoch 7/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1564
# Epoch 7: val_loss improved from 0.15821 to 0.15808, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1564 - val_loss: 0.1581
# Epoch 8/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1563
# Epoch 8: val_loss did not improve from 0.15808
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1563 - val_loss: 0.1585
# Epoch 9/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1558
# Epoch 9: val_loss did not improve from 0.15808
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1557 - val_loss: 0.1583
# Epoch 10/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1555
# Epoch 10: val_loss did not improve from 0.15808
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1556 - val_loss: 0.1582
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_3/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_3/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1878
# Epoch 1: val_loss improved from inf to 0.15144, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_4.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1878 - val_loss: 0.1514
# Epoch 2/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1574
# Epoch 2: val_loss did not improve from 0.15144
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1575 - val_loss: 0.1518
# Epoch 3/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1574
# Epoch 3: val_loss did not improve from 0.15144
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1574 - val_loss: 0.1516
# Epoch 4/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1572
# Epoch 4: val_loss did not improve from 0.15144
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1574 - val_loss: 0.1520
# Epoch 5/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1574
# Epoch 5: val_loss did not improve from 0.15144
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1574 - val_loss: 0.1517
# Epoch 6/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1573
# Epoch 6: val_loss did not improve from 0.15144
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1573 - val_loss: 0.1515
# Epoch 7/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1570
# Epoch 7: val_loss did not improve from 0.15144
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1571 - val_loss: 0.1517
# Epoch 8/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1569
# Epoch 8: val_loss improved from 0.15144 to 0.15143, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1569 - val_loss: 0.1514
# Epoch 9/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1568
# Epoch 9: val_loss did not improve from 0.15143
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1567 - val_loss: 0.1516
# Epoch 10/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1565
# Epoch 10: val_loss did not improve from 0.15143
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1565 - val_loss: 0.1523
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_4/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_4/assets
# 2317/2317 [==============================] - 2s 1ms/step
# 2317/2317 [==============================] - 2s 1ms/step
# 623/623 [==============================] - 1s 995us/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 978us/step
# 390/390 [==============================] - 0s 998us/step
# 258/258 [==============================] - 0s 974us/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1747
# Epoch 1: val_loss improved from inf to 0.13500, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1747 - val_loss: 0.1350
# Epoch 2/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1370
# Epoch 2: val_loss improved from 0.13500 to 0.13188, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_5.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1371 - val_loss: 0.1319
# Epoch 3/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1352
# Epoch 3: val_loss improved from 0.13188 to 0.13028, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1351 - val_loss: 0.1303
# Epoch 4/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1345
# Epoch 4: val_loss did not improve from 0.13028
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1345 - val_loss: 0.1314
# Epoch 5/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1339
# Epoch 5: val_loss improved from 0.13028 to 0.13023, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_5.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1338 - val_loss: 0.1302
# Epoch 6/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1334
# Epoch 6: val_loss did not improve from 0.13023
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1334 - val_loss: 0.1306
# Epoch 7/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1332
# Epoch 7: val_loss improved from 0.13023 to 0.13022, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1332 - val_loss: 0.1302
# Epoch 8/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1330
# Epoch 8: val_loss improved from 0.13022 to 0.12990, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1330 - val_loss: 0.1299
# Epoch 9/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1325
# Epoch 9: val_loss improved from 0.12990 to 0.12975, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1325 - val_loss: 0.1297
# Epoch 10/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1324
# Epoch 10: val_loss improved from 0.12975 to 0.12955, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1323 - val_loss: 0.1296
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_5/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_5/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 999us/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 986us/step
# 258/258 [==============================] - 0s 978us/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1796
# Epoch 1: val_loss improved from inf to 0.15671, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1796 - val_loss: 0.1567
# Epoch 2/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1569
# Epoch 2: val_loss improved from 0.15671 to 0.15653, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1569 - val_loss: 0.1565
# Epoch 3/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1569
# Epoch 3: val_loss did not improve from 0.15653
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1569 - val_loss: 0.1566
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1568
# Epoch 4: val_loss did not improve from 0.15653
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1568 - val_loss: 0.1568
# Epoch 5/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1566
# Epoch 5: val_loss did not improve from 0.15653
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1566 - val_loss: 0.1566
# Epoch 6/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1564
# Epoch 6: val_loss improved from 0.15653 to 0.15631, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1564 - val_loss: 0.1563
# Epoch 7/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1560
# Epoch 7: val_loss did not improve from 0.15631
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1560 - val_loss: 0.1568
# Epoch 8/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1556
# Epoch 8: val_loss improved from 0.15631 to 0.15602, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_6.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1557 - val_loss: 0.1560
# Epoch 9/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1552
# Epoch 9: val_loss improved from 0.15602 to 0.15549, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_6.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1552 - val_loss: 0.1555
# Epoch 10/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1547
# Epoch 10: val_loss did not improve from 0.15549
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1547 - val_loss: 0.1563
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_6/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_6/assets
# 2317/2317 [==============================] - 2s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 998us/step
# 390/390 [==============================] - 0s 979us/step
# 390/390 [==============================] - 0s 997us/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 959us/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1780
# Epoch 1: val_loss improved from inf to 0.15844, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_7.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1780 - val_loss: 0.1584
# Epoch 2/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1567
# Epoch 2: val_loss did not improve from 0.15844
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1567 - val_loss: 0.1588
# Epoch 3/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1566
# Epoch 3: val_loss did not improve from 0.15844
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1566 - val_loss: 0.1587
# Epoch 4/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1567
# Epoch 4: val_loss did not improve from 0.15844
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1566 - val_loss: 0.1585
# Epoch 5/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1565
# Epoch 5: val_loss improved from 0.15844 to 0.15840, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_7.h5
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1565 - val_loss: 0.1584
# Epoch 6/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1563
# Epoch 6: val_loss did not improve from 0.15840
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1562 - val_loss: 0.1587
# Epoch 7/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1557
# Epoch 7: val_loss did not improve from 0.15840
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1559 - val_loss: 0.1585
# Epoch 8/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1556
# Epoch 8: val_loss improved from 0.15840 to 0.15800, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_7.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1556 - val_loss: 0.1580
# Epoch 9/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1545
# Epoch 9: val_loss improved from 0.15800 to 0.15655, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_7.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1545 - val_loss: 0.1566
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1521
# Epoch 10: val_loss improved from 0.15655 to 0.15492, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_7.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1522 - val_loss: 0.1549
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_7/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_7/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1833
# Epoch 1: val_loss improved from inf to 0.15310, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_8.h5
# 2317/2317 [==============================] - 11s 4ms/step - loss: 0.1832 - val_loss: 0.1531
# Epoch 2/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1573
# Epoch 2: val_loss improved from 0.15310 to 0.15302, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_8.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1573 - val_loss: 0.1530
# Epoch 3/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1574
# Epoch 3: val_loss did not improve from 0.15302
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1574 - val_loss: 0.1531
# Epoch 4/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1572
# Epoch 4: val_loss did not improve from 0.15302
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1573 - val_loss: 0.1531
# Epoch 5/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1573
# Epoch 5: val_loss did not improve from 0.15302
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1573 - val_loss: 0.1532
# Epoch 6/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1573
# Epoch 6: val_loss did not improve from 0.15302
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1573 - val_loss: 0.1533
# Epoch 7/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1572
# Epoch 7: val_loss did not improve from 0.15302
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1573 - val_loss: 0.1531
# Epoch 8/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1572
# Epoch 8: val_loss did not improve from 0.15302
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1572 - val_loss: 0.1533
# Epoch 9/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1572
# Epoch 9: val_loss did not improve from 0.15302
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1573 - val_loss: 0.1534
# Epoch 10/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1573
# Epoch 10: val_loss did not improve from 0.15302
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1573 - val_loss: 0.1535
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_8/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_8/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 2s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 977us/step
# 390/390 [==============================] - 0s 984us/step
# 390/390 [==============================] - 0s 981us/step
# 258/258 [==============================] - 0s 985us/step
# 258/258 [==============================] - 0s 987us/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1788
# Epoch 1: val_loss improved from inf to 0.15902, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_9.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1787 - val_loss: 0.1590
# Epoch 2/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1565
# Epoch 2: val_loss improved from 0.15902 to 0.15896, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_9.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1565 - val_loss: 0.1590
# Epoch 3/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1564
# Epoch 3: val_loss did not improve from 0.15896
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1565 - val_loss: 0.1590
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1563
# Epoch 4: val_loss did not improve from 0.15896
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1564 - val_loss: 0.1590
# Epoch 5/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1563
# Epoch 5: val_loss did not improve from 0.15896
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1563 - val_loss: 0.1592
# Epoch 6/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1561
# Epoch 6: val_loss did not improve from 0.15896
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1561 - val_loss: 0.1595
# Epoch 7/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1559
# Epoch 7: val_loss did not improve from 0.15896
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1559 - val_loss: 0.1595
# Epoch 8/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1558
# Epoch 8: val_loss did not improve from 0.15896
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1558 - val_loss: 0.1604
# Epoch 9/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1557
# Epoch 9: val_loss did not improve from 0.15896
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1557 - val_loss: 0.1597
# Epoch 10/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1553
# Epoch 10: val_loss did not improve from 0.15896
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1553 - val_loss: 0.1604
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_9/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_9/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1805
# Epoch 1: val_loss improved from inf to 0.13162, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_10.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1803 - val_loss: 0.1316
# Epoch 2/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1359
# Epoch 2: val_loss improved from 0.13162 to 0.12853, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_10.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1360 - val_loss: 0.1285
# Epoch 3/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1345
# Epoch 3: val_loss improved from 0.12853 to 0.12821, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_10.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1345 - val_loss: 0.1282
# Epoch 4/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1337
# Epoch 4: val_loss improved from 0.12821 to 0.12686, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_10.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1338 - val_loss: 0.1269
# Epoch 5/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1331
# Epoch 5: val_loss did not improve from 0.12686
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1330 - val_loss: 0.1279
# Epoch 6/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1328
# Epoch 6: val_loss did not improve from 0.12686
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1327 - val_loss: 0.1270
# Epoch 7/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1327
# Epoch 7: val_loss improved from 0.12686 to 0.12665, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_10.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.1327 - val_loss: 0.1267
# Epoch 8/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1317
# Epoch 8: val_loss did not improve from 0.12665
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1318 - val_loss: 0.1284
# Epoch 9/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1319
# Epoch 9: val_loss improved from 0.12665 to 0.12640, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_10.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1319 - val_loss: 0.1264
# Epoch 10/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1317
# Epoch 10: val_loss improved from 0.12640 to 0.12627, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_10.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1316 - val_loss: 0.1263
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_10/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_fourier2_resid_tiling_10/assets
# 2317/2317 [==============================] - 4s 2ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 4s 1ms/step
# 2576/2576 [==============================] - 4s 1ms/step

# %%
display_fits(fits)
# Out:
# Average correlation on tiling: 0.1442719233356266
# Average MSE on tiling: 0.1496146077347319
# Average correlation on random: 0.11702912927217277
# Average MSE on random: 0.09752665826678002
# Average correlation on ChrV: 0.09638732977940985
# Average MSE on ChrV: 0.22342024332754304
# Average correlation on CN: 0.11378040457757543
# Average MSE on CN: 0.15188073617755166
