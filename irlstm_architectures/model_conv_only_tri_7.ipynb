# %%
import time
import keras

from keras.models import Model
from keras.layers import Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Add, Concatenate
from keras.layers import Dense, Conv2D, MaxPooling2D, LSTM, TimeDistributed, Reshape
import keras.backend as K
import keras.callbacks as callbacks

import pandas as pd
import numpy as np
from numpy import array
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
# Out:
# 2023-04-26 11:44:54.582277: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
save_path = "/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/"
model_name = "conv_only_tri_5"
kf = KFold(n_splits = 10, shuffle =True)
num_epochs = 10

#### define functions ####

def model_cycle():
    inputs = Input(shape=(48, 64, 1))
        
    x = Conv2D(8, kernel_size=(31,64),
                   activation='relu',
                   padding='valid')(inputs)
    x = MaxPooling2D((2,1),padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # print(f"After first convolutional layer: x.shape = {x.shape}")

    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = Conv1D(48, kernel_size=(11),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After second convolutional layer: x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((24,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After third convolutional layer, x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((12,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # # parallel line 1
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(fx1)
    # fx1 = MaxPooling2D((2,1),padding='same')(fx1)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    
    # # parallel line 2
    # fx2 = Conv2D(48, kernel_size=(11,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    # fx2 = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(fx2)
    # fx2 = MaxPooling2D((2,1),padding='same')(fx2)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    
    # # # Add
    # x1 = Concatenate(axis=-3)([fx1, fx2])
    # x = Add()([x, x1])
    # x = MaxPooling2D((2,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    
    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = LSTM(20, return_sequences=False)(x)
    # x = Dropout(0.2)(x)

    # x = Reshape((1, 24*48))(x)
    x = Flatten()(x)

    outputs = Dense(1, activation='linear')(x)
    # print(outputs.shape)
    network = Model(inputs, outputs)
    network.compile(optimizer='rmsprop',
                    loss='mean_squared_error')
    return network

# %%
def triOneHot(sequence):
    code = {"AAA": [0], "AAC": [1], "AAG": [2], "AAT": [3],
            "ACA": [4], "ACC": [5], "ACG": [6], "ACT": [7], 
            "AGA": [8], "AGC": [9], "AGG": [10], "AGT": [11], 
            "ATA": [12], "ATC": [13], "ATG": [14], "ATT": [15], 
            "CAA": [16], "CAC": [17], "CAG": [18], "CAT": [19], 
            "CCA": [20], "CCC": [21], "CCG": [22], "CCT": [23], 
            "CGA": [24], "CGC": [25], "CGG": [26], "CGT": [27], 
            "CTA": [28], "CTC": [29], "CTG": [30], "CTT": [31], 
            "GAA": [32], "GAC": [33], "GAG": [34], "GAT": [35],
            "GCA": [36], "GCC": [37], "GCG": [38], "GCT": [39], 
            "GGA": [40], "GGC": [41], "GGG": [42], "GGT": [43], 
            "GTA": [44], "GTC": [45], "GTG": [46], "GTT": [47], 
            "TAA": [48], "TAC": [49], "TAG": [50], "TAT": [51], 
            "TCA": [52], "TCC": [53], "TCG": [54], "TCT": [55], 
            "TGA": [56], "TGC": [57], "TGG": [58], "TGT": [59], 
            "TTA": [60], "TTC": [61], "TTG": [62], "TTT": [63],   "N": [64]}
    onehot_encoded_seq = []
    for i, _ in enumerate(sequence[:(len(sequence)-2)]):
        onehot_encoded = np.zeros(65)
        onehot_encoded[code[sequence[i:i+3]]] = 1
        onehot_encoded_seq.append(onehot_encoded[0:64])
    return onehot_encoded_seq

# %%
def display_fits(fits):
    print(f"Average correlation on tiling: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 5])}",
          f"\nAverage MSE on tiling: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 5])}",
          f"\nAverage correlation on random: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 3])}",
          f"\nAverage MSE on random: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 3])}",
          f"\nAverage correlation on ChrV: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 7])}",
          f"\nAverage MSE on ChrV: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 7])}",
          f"\nAverage correlation on CN: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 0])}",
          f"\nAverage MSE on CN: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 0])}")

# %%
def find_c0new(dat):
  mat = np.empty((3,3), float)
  k = 2*np.pi/10.4
  n = array([26, 29, 31])
  mat[0:3,0] = 1
  mat[0:3, 1] = np.sin(n*k)
  mat[0:3, 2] = np.cos(n*k)
  inv_mat = np.linalg.inv(mat)
  c0A1A2 = array(np.matmul(dat[["n=26", "n=29", "n=31"]], np.transpose(inv_mat)))
  c0Aphi = c0A1A2
  c0Aphi[:,0] = c0A1A2[:,0]
  c0Aphi[:,1] = np.sqrt(c0A1A2[:,1]**2 + c0A1A2[:,2]**2)
  c0Aphi[:,2] <- np.sign(c0A1A2[:,2]) * np.arccos(c0A1A2[:,1]/c0Aphi[:,1])
  return c0Aphi[:,0]

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.process_time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.process_time() - self.epoch_time_start)
        
#### preparing data ####

data_cerevisiae_nucle = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle1.txt",delimiter = ",")
X1 = []
for sequence_nt in data_cerevisiae_nucle["Sequence"]:
    X1.append(triOneHot(sequence_nt))
X1 = array(X1)
X1 = X1.reshape((X1.shape[0],48,64,1))
X1_reverse = np.flip(X1,[1,2])
# Y1 = data_cerevisiae_nucle["C0"].values.astype(float)
Y1 = find_c0new(data_cerevisiae_nucle).astype(float)

# %%
data_random_library = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle3.txt",delimiter = ",")
X3 = []
for sequence_nt in data_random_library["Sequence"]:
    X3.append(triOneHot(sequence_nt))
X3 = array(X3)
X3 = X3.reshape((X3.shape[0],48,64,1))
X3_reverse = np.flip(X3,[1,2])
# Y3 = data_random_library["C0"].values.astype(float)
Y3 = find_c0new(data_random_library).astype(float)

# %%
data_tiling = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle5.txt",delimiter = ",")
X5 = []
for sequence_nt in data_tiling["Sequence"]:
    X5.append(triOneHot(sequence_nt))
X5 = array(X5)
X5 = X5.reshape((X5.shape[0],48,64,1))
X5_reverse = np.flip(X5,[1,2])
# Y5 = data_tiling["C0"].values.astype(float)
Y5 = find_c0new(data_tiling).astype(float)

# %%
data_chr5 = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle6.txt",delimiter = ",")
X6 = []
for sequence_nt in data_chr5["Sequence"]:
    X6.append(triOneHot(sequence_nt))
X6 = array(X6)
X6 = X6.reshape((X6.shape[0],48,64,1))
X6_reverse = np.flip(X6,[1,2])
# Y6 = data_chr5["C0"].values.astype(float)
Y6 = find_c0new(data_chr5).astype(float)

# %%
#### tiling

VALIDATION_LOSS = []
fold_var = 1
n = Y5.shape[0]

fits = []
detrend = []
times = []
times2 = []

for train_index, val_index in kf.split(Y5):
    training_X = X5[train_index]
    training_X_reverse = X5_reverse[train_index]
    validation_X = X5[val_index]
    validation_X_reverse = X5_reverse[val_index]
    training_Y = Y5[train_index]
    validation_Y = Y5[val_index]
    # CREATE NEW MODEL
    model = model_cycle()
    # CREATE CALLBACKS
    checkpoint = callbacks.ModelCheckpoint(save_path + model_name+"_tiling_"+str(fold_var)+".h5",
                                                    monitor='val_loss', verbose=1,
                                                    save_best_only=True, mode='min')
    time_callback = TimeHistory()

    history = model.fit(training_X, training_Y,
                        epochs=num_epochs,
                        callbacks= [checkpoint, time_callback],
                        validation_data=(validation_X, validation_Y))
    model.load_weights(save_path + model_name+"_tiling_"+str(fold_var)+".h5")
    model.save(save_path+model_name+"_tiling_"+str(fold_var),save_traces=False)
    times.append(time_callback.times)

    pred_Y = model.predict(training_X)
    pred_Y = pred_Y.reshape(pred_Y.shape[0])
    pred_Y_reverse = model.predict(training_X_reverse)
    pred_Y_reverse = pred_Y_reverse.reshape(pred_Y_reverse.shape[0])
    pred_Y = (pred_Y+pred_Y_reverse)/2
    reg =  LinearRegression().fit(array(pred_Y).reshape(-1, 1), array(training_Y).reshape(-1, 1))
    
    detrend_int = reg.intercept_
    detrend_slope = reg.coef_
    detrend.append([float(detrend_int), float(detrend_slope)])

    start_time = time.process_time()
    fit = model.predict(X1)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X1_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X3)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X3_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(validation_X)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(validation_X_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X6)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X6_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    K.clear_session()
    fold_var += 1
    
detrend = array(detrend)
detrend = pd.DataFrame(detrend)
detrend.to_csv(save_path +model_name+"_detrend_tiling.txt", index = False)

fits = array(fits)
fits = pd.DataFrame((fits))
fits.to_csv(save_path +model_name+ "_fits_tiling.txt", index = False)

with open(save_path +model_name+"_time_tiling.txt", "w") as file:
    for row in times:
        s = " ".join(map(str, row))
        file.write(s+'\n')

with open(save_path +model_name+"_pred_time_tiling.txt", "w") as file:
    for row in times2:
        s = " ".join(map(str, row))
        file.write(s+'\n')
# Out:
# 2023-04-26 11:46:29.739688: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1906
# Epoch 1: val_loss improved from inf to 0.11975, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1905 - val_loss: 0.1198
# Epoch 2/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1320
# Epoch 2: val_loss improved from 0.11975 to 0.11531, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1320 - val_loss: 0.1153
# Epoch 3/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1279
# Epoch 3: val_loss improved from 0.11531 to 0.11174, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1280 - val_loss: 0.1117
# Epoch 4/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1258
# Epoch 4: val_loss improved from 0.11174 to 0.11113, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1259 - val_loss: 0.1111
# Epoch 5/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1247
# Epoch 5: val_loss improved from 0.11113 to 0.10929, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1247 - val_loss: 0.1093
# Epoch 6/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1233
# Epoch 6: val_loss did not improve from 0.10929
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1233 - val_loss: 0.1106
# Epoch 7/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1237
# Epoch 7: val_loss improved from 0.10929 to 0.10841, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1236 - val_loss: 0.1084
# Epoch 8/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1225
# Epoch 8: val_loss did not improve from 0.10841
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1226 - val_loss: 0.1103
# Epoch 9/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1224
# Epoch 9: val_loss did not improve from 0.10841
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1224 - val_loss: 0.1100
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1220
# Epoch 10: val_loss did not improve from 0.10841
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1220 - val_loss: 0.1096
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_1/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 4s 2ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# Epoch 1/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1828
# Epoch 1: val_loss improved from inf to 0.12469, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.1828 - val_loss: 0.1247
# Epoch 2/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1414
# Epoch 2: val_loss did not improve from 0.12469
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1414 - val_loss: 0.1258
# Epoch 3/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1351
# Epoch 3: val_loss improved from 0.12469 to 0.11404, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1350 - val_loss: 0.1140
# Epoch 4/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1303
# Epoch 4: val_loss improved from 0.11404 to 0.11115, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1303 - val_loss: 0.1112
# Epoch 5/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1281
# Epoch 5: val_loss did not improve from 0.11115
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1281 - val_loss: 0.1118
# Epoch 6/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1269
# Epoch 6: val_loss did not improve from 0.11115
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1270 - val_loss: 0.1131
# Epoch 7/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1265
# Epoch 7: val_loss improved from 0.11115 to 0.10861, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1265 - val_loss: 0.1086
# Epoch 8/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1255
# Epoch 8: val_loss did not improve from 0.10861
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1255 - val_loss: 0.1096
# Epoch 9/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1261
# Epoch 9: val_loss improved from 0.10861 to 0.10783, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1261 - val_loss: 0.1078
# Epoch 10/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1255
# Epoch 10: val_loss did not improve from 0.10783
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1255 - val_loss: 0.1091
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_2/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1913
# Epoch 1: val_loss improved from inf to 0.12577, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 11s 4ms/step - loss: 0.1912 - val_loss: 0.1258
# Epoch 2/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1424
# Epoch 2: val_loss improved from 0.12577 to 0.12362, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1423 - val_loss: 0.1236
# Epoch 3/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1394
# Epoch 3: val_loss improved from 0.12362 to 0.12118, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1393 - val_loss: 0.1212
# Epoch 4/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1398
# Epoch 4: val_loss improved from 0.12118 to 0.11978, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1398 - val_loss: 0.1198
# Epoch 5/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1383
# Epoch 5: val_loss did not improve from 0.11978
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1383 - val_loss: 0.1211
# Epoch 6/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1377
# Epoch 6: val_loss did not improve from 0.11978
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1377 - val_loss: 0.1206
# Epoch 7/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1377
# Epoch 7: val_loss improved from 0.11978 to 0.11903, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1376 - val_loss: 0.1190
# Epoch 8/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1371
# Epoch 8: val_loss did not improve from 0.11903
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1371 - val_loss: 0.1198
# Epoch 9/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1367
# Epoch 9: val_loss improved from 0.11903 to 0.11849, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1368 - val_loss: 0.1185
# Epoch 10/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1369
# Epoch 10: val_loss improved from 0.11849 to 0.11801, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1370 - val_loss: 0.1180
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_3/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 1s 3ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# 2576/2576 [==============================] - 6s 2ms/step
# Epoch 1/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.2350
# Epoch 1: val_loss improved from inf to 0.12784, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2345 - val_loss: 0.1278
# Epoch 2/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1452
# Epoch 2: val_loss improved from 0.12784 to 0.11887, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1452 - val_loss: 0.1189
# Epoch 3/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1412
# Epoch 3: val_loss did not improve from 0.11887
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1412 - val_loss: 0.1196
# Epoch 4/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1398
# Epoch 4: val_loss did not improve from 0.11887
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1397 - val_loss: 0.1213
# Epoch 5/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1379
# Epoch 5: val_loss improved from 0.11887 to 0.11674, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1380 - val_loss: 0.1167
# Epoch 6/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1377
# Epoch 6: val_loss improved from 0.11674 to 0.11529, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1376 - val_loss: 0.1153
# Epoch 7/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1386
# Epoch 7: val_loss improved from 0.11529 to 0.11498, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1386 - val_loss: 0.1150
# Epoch 8/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1375
# Epoch 8: val_loss did not improve from 0.11498
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1374 - val_loss: 0.1153
# Epoch 9/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1381
# Epoch 9: val_loss did not improve from 0.11498
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1381 - val_loss: 0.1151
# Epoch 10/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1363
# Epoch 10: val_loss improved from 0.11498 to 0.11425, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1364 - val_loss: 0.1142
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_4/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 987us/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 981us/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 959us/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1962
# Epoch 1: val_loss improved from inf to 0.14187, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1961 - val_loss: 0.1419
# Epoch 2/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1481
# Epoch 2: val_loss improved from 0.14187 to 0.13036, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1480 - val_loss: 0.1304
# Epoch 3/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1383
# Epoch 3: val_loss improved from 0.13036 to 0.12376, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1382 - val_loss: 0.1238
# Epoch 4/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1330
# Epoch 4: val_loss improved from 0.12376 to 0.12111, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1330 - val_loss: 0.1211
# Epoch 5/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1301
# Epoch 5: val_loss improved from 0.12111 to 0.12055, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1302 - val_loss: 0.1206
# Epoch 6/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1287
# Epoch 6: val_loss improved from 0.12055 to 0.11794, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1287 - val_loss: 0.1179
# Epoch 7/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1267
# Epoch 7: val_loss did not improve from 0.11794
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1267 - val_loss: 0.1185
# Epoch 8/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1265
# Epoch 8: val_loss improved from 0.11794 to 0.11597, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1265 - val_loss: 0.1160
# Epoch 9/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1260
# Epoch 9: val_loss improved from 0.11597 to 0.11574, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1260 - val_loss: 0.1157
# Epoch 10/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1255
# Epoch 10: val_loss improved from 0.11574 to 0.11561, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1255 - val_loss: 0.1156
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_5/assets
# 2317/2317 [==============================] - 2s 1ms/step
# 2317/2317 [==============================] - 2s 998us/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 948us/step
# 390/390 [==============================] - 0s 938us/step
# 390/390 [==============================] - 0s 998us/step
# 258/258 [==============================] - 0s 966us/step
# 258/258 [==============================] - 0s 983us/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.2140
# Epoch 1: val_loss improved from inf to 0.12544, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.2137 - val_loss: 0.1254
# Epoch 2/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1438
# Epoch 2: val_loss improved from 0.12544 to 0.12096, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1438 - val_loss: 0.1210
# Epoch 3/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1416
# Epoch 3: val_loss improved from 0.12096 to 0.12034, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1417 - val_loss: 0.1203
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1407
# Epoch 4: val_loss did not improve from 0.12034
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1407 - val_loss: 0.1208
# Epoch 5/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1405
# Epoch 5: val_loss improved from 0.12034 to 0.11780, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1404 - val_loss: 0.1178
# Epoch 6/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1397
# Epoch 6: val_loss did not improve from 0.11780
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1397 - val_loss: 0.1188
# Epoch 7/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1397
# Epoch 7: val_loss did not improve from 0.11780
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1397 - val_loss: 0.1190
# Epoch 8/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1393
# Epoch 8: val_loss did not improve from 0.11780
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1393 - val_loss: 0.1193
# Epoch 9/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1388
# Epoch 9: val_loss did not improve from 0.11780
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1388 - val_loss: 0.1198
# Epoch 10/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1390
# Epoch 10: val_loss did not improve from 0.11780
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1390 - val_loss: 0.1182
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_6/assets
# 2317/2317 [==============================] - 2s 1ms/step
# 2317/2317 [==============================] - 2s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 953us/step
# 390/390 [==============================] - 0s 936us/step
# 390/390 [==============================] - 0s 969us/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 1s 2ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.2008
# Epoch 1: val_loss improved from inf to 0.11649, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2005 - val_loss: 0.1165
# Epoch 2/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1370
# Epoch 2: val_loss improved from 0.11649 to 0.11626, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1370 - val_loss: 0.1163
# Epoch 3/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1334
# Epoch 3: val_loss improved from 0.11626 to 0.10704, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1334 - val_loss: 0.1070
# Epoch 4/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1309
# Epoch 4: val_loss improved from 0.10704 to 0.10567, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1309 - val_loss: 0.1057
# Epoch 5/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1302
# Epoch 5: val_loss improved from 0.10567 to 0.10547, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1301 - val_loss: 0.1055
# Epoch 6/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1284
# Epoch 6: val_loss improved from 0.10547 to 0.10455, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1284 - val_loss: 0.1045
# Epoch 7/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1279
# Epoch 7: val_loss did not improve from 0.10455
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1278 - val_loss: 0.1064
# Epoch 8/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1271
# Epoch 8: val_loss did not improve from 0.10455
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1271 - val_loss: 0.1052
# Epoch 9/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1277
# Epoch 9: val_loss improved from 0.10455 to 0.10351, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1277 - val_loss: 0.1035
# Epoch 10/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1266
# Epoch 10: val_loss improved from 0.10351 to 0.10324, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1266 - val_loss: 0.1032
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_7/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.2305
# Epoch 1: val_loss improved from inf to 0.13509, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2304 - val_loss: 0.1351
# Epoch 2/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1471
# Epoch 2: val_loss improved from 0.13509 to 0.12738, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1470 - val_loss: 0.1274
# Epoch 3/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1266
# Epoch 3: val_loss improved from 0.12738 to 0.10540, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1265 - val_loss: 0.1054
# Epoch 4/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1202
# Epoch 4: val_loss improved from 0.10540 to 0.10303, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 10s 5ms/step - loss: 0.1202 - val_loss: 0.1030
# Epoch 5/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1178
# Epoch 5: val_loss improved from 0.10303 to 0.10262, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1177 - val_loss: 0.1026
# Epoch 6/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1166
# Epoch 6: val_loss improved from 0.10262 to 0.10241, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1166 - val_loss: 0.1024
# Epoch 7/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1164
# Epoch 7: val_loss improved from 0.10241 to 0.10189, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1164 - val_loss: 0.1019
# Epoch 8/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1154
# Epoch 8: val_loss did not improve from 0.10189
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1154 - val_loss: 0.1025
# Epoch 9/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1154
# Epoch 9: val_loss did not improve from 0.10189
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1154 - val_loss: 0.1040
# Epoch 10/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1150
# Epoch 10: val_loss improved from 0.10189 to 0.10135, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1150 - val_loss: 0.1013
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_8/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 4s 2ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.2736
# Epoch 1: val_loss improved from inf to 0.24359, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2734 - val_loss: 0.2436
# Epoch 2/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.2420
# Epoch 2: val_loss improved from 0.24359 to 0.23997, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2420 - val_loss: 0.2400
# Epoch 3/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1624
# Epoch 3: val_loss improved from 0.23997 to 0.13171, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1625 - val_loss: 0.1317
# Epoch 4/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1449
# Epoch 4: val_loss improved from 0.13171 to 0.12678, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1449 - val_loss: 0.1268
# Epoch 5/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1414
# Epoch 5: val_loss improved from 0.12678 to 0.12282, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1414 - val_loss: 0.1228
# Epoch 6/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1394
# Epoch 6: val_loss did not improve from 0.12282
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1395 - val_loss: 0.1249
# Epoch 7/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1385
# Epoch 7: val_loss did not improve from 0.12282
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1385 - val_loss: 0.1248
# Epoch 8/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1378
# Epoch 8: val_loss did not improve from 0.12282
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1378 - val_loss: 0.1234
# Epoch 9/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1372
# Epoch 9: val_loss improved from 0.12282 to 0.12271, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1372 - val_loss: 0.1227
# Epoch 10/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1367
# Epoch 10: val_loss improved from 0.12271 to 0.12169, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1367 - val_loss: 0.1217
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_9/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 1s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.2758
# Epoch 1: val_loss improved from inf to 0.24256, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.2758 - val_loss: 0.2426
# Epoch 2/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2425
# Epoch 2: val_loss improved from 0.24256 to 0.24213, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2425 - val_loss: 0.2421
# Epoch 3/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.2344
# Epoch 3: val_loss improved from 0.24213 to 0.21682, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2343 - val_loss: 0.2168
# Epoch 4/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.2129
# Epoch 4: val_loss improved from 0.21682 to 0.20975, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2129 - val_loss: 0.2097
# Epoch 5/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.2107
# Epoch 5: val_loss improved from 0.20975 to 0.20808, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2107 - val_loss: 0.2081
# Epoch 6/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2095
# Epoch 6: val_loss improved from 0.20808 to 0.20756, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2095 - val_loss: 0.2076
# Epoch 7/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.2087
# Epoch 7: val_loss improved from 0.20756 to 0.20625, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2088 - val_loss: 0.2063
# Epoch 8/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.2080
# Epoch 8: val_loss improved from 0.20625 to 0.20591, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2080 - val_loss: 0.2059
# Epoch 9/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.2074
# Epoch 9: val_loss did not improve from 0.20591
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.2075 - val_loss: 0.2061
# Epoch 10/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.2063
# Epoch 10: val_loss improved from 0.20591 to 0.20571, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.2063 - val_loss: 0.2057
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_tri_5_tiling_10/assets
# 2317/2317 [==============================] - 3s 1ms/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 258/258 [==============================] - 0s 1ms/step
# 2576/2576 [==============================] - 3s 1ms/step
# 2576/2576 [==============================] - 4s 2ms/step

# %%
display_fits(fits)
# Out:
# Average correlation on tiling: 0.6388864863855325
# Average MSE on tiling: 0.14038752813172187
# Average correlation on random: 0.623433330978421
# Average MSE on random: 0.08837613393893166
# Average correlation on ChrV: 0.5290083551047756
# Average MSE on ChrV: 0.2068486560116897
# Average correlation on CN: 0.5756437527011637
# Average MSE on CN: 0.1589678542255347

# %%
first_conv_model = Model(inputs = model.input, outputs = model.layers[1].output)
first_conv_output = first_conv_model.predict(X5)
pd.DataFrame(first_conv_output.reshape(first_conv_output.shape[0], -1)).to_csv(save_path + model_name+"_tiling_tiling_first_conv_output")
first_conv_output_random = first_conv_model.predict(X3)
pd.DataFrame(first_conv_output_random.reshape(first_conv_output_random.shape[0], -1)).to_csv(save_path + model_name+"_tiling_random_first_conv_output")
# Out:
# 2574/2574 [==============================] - 3s 1ms/step
# 390/390 [==============================] - 0s 985us/step

# %%
first_conv_weights = model.layers[1].weights[0]
first_conv_biases = model.layers[1].weights[1]
# Format: [Position 0: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT  Position 1: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT,
# ..., Position 20: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT]
pd.DataFrame(array(first_conv_weights).transpose((3,2,0,1)).reshape(first_conv_weights.shape[-1], -1)).to_csv(save_path + model_name+"_tiling_first_conv_kernels")
pd.DataFrame(first_conv_biases).to_csv(save_path + model_name+"_tiling_first_conv_biases")
