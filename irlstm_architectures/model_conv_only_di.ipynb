# %%
import time
import keras

from keras.models import Model
from keras.layers import Dropout, Flatten, BatchNormalization, TimeDistributed, Input, Add, Concatenate
from keras.layers import Dense, Conv2D, MaxPooling2D, LSTM, TimeDistributed, Reshape
import keras.backend as K
import keras.callbacks as callbacks

import pandas as pd
import numpy as np
from numpy import array
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
# Out:
# 2023-04-19 11:08:04.314877: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
save_path = "/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/"
model_name = "conv_only_di"
kf = KFold(n_splits = 10, shuffle =True)
num_epochs = 10

#### define functions ####

def model_cycle():
    inputs = Input(shape=(49, 16, 1))
        
    x = Conv2D(48, kernel_size=(21,16),
                   activation='relu',
                   padding='valid')(inputs)
    x = MaxPooling2D((2,1),padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # print(f"After first convolutional layer: x.shape = {x.shape}")

    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = Conv1D(48, kernel_size=(11),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After second convolutional layer: x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((24,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # print(f"After third convolutional layer, x.shape = {x.shape}")

    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    # x = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # x = MaxPooling2D((12,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)

    # # parallel line 1
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    # fx1 = Conv2D(48, kernel_size=(3,1),
    #                activation='relu',
    #                padding='same')(fx1)
    # fx1 = MaxPooling2D((2,1),padding='same')(fx1)
    # fx1 = BatchNormalization()(fx1)
    # fx1 = Dropout(0.2)(fx1)
    
    # # parallel line 2
    # fx2 = Conv2D(48, kernel_size=(11,1),
    #                activation='relu',
    #                padding='same')(x)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    # fx2 = Conv2D(48, kernel_size=(21,1),
    #                activation='relu',
    #                padding='same')(fx2)
    # fx2 = MaxPooling2D((2,1),padding='same')(fx2)
    # fx2 = BatchNormalization()(fx2)
    # fx2 = Dropout(0.2)(fx2)
    
    # # # Add
    # x1 = Concatenate(axis=-3)([fx1, fx2])
    # x = Add()([x, x1])
    # x = MaxPooling2D((2,1),padding='same')(x)
    # x = BatchNormalization()(x)
    # x = Dropout(0.2)(x)
    
    # x = Reshape((K.int_shape(x)[1], K.int_shape(x)[3]))(x)
    # x = LSTM(20, return_sequences=False)(x)
    # x = Dropout(0.2)(x)

    # x = Reshape((1, 24*48))(x)
    x = Flatten()(x)

    outputs = Dense(1, activation='linear')(x)
    # print(outputs.shape)
    network = Model(inputs, outputs)
    network.compile(optimizer='rmsprop',
                    loss='mean_squared_error')
    return network

# %%
def diOneHot(sequence):
    code = {"AA": [0], "AC": [1], "AG": [2], "AT": [3],
            "CA": [4], "CC": [5], "CG": [6], "CT": [7], 
            "GA": [8], "GC": [9], "GG": [10], "GT": [11], 
            "TA": [12], "TC": [13], "TG": [14], "TT": [15],  "N": [16]}
    onehot_encoded_seq = []
    for i, _ in enumerate(sequence[:(len(sequence)-1)]):
        onehot_encoded = np.zeros(17)
        onehot_encoded[code[sequence[i:i+2]]] = 1
        onehot_encoded_seq.append(onehot_encoded[0:16])
    return onehot_encoded_seq

# %%
def display_fits(fits):
    print(f"Average correlation on tiling: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 5])}",
          f"\nAverage MSE on tiling: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 5])}",
          f"\nAverage correlation on random: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 3])}",
          f"\nAverage MSE on random: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 3])}",
          f"\nAverage correlation on ChrV: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 7])}",
          f"\nAverage MSE on ChrV: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 7])}",
          f"\nAverage correlation on CN: {np.mean([fits[0][i] for i in range(fits[0].size) if (i % 8) == 0])}",
          f"\nAverage MSE on CN: {np.mean([fits[1][i] for i in range(fits[1].size) if (i % 8) == 0])}")

# %%
def find_c0new(dat):
  mat = np.empty((3,3), float)
  k = 2*np.pi/10.4
  n = array([26, 29, 31])
  mat[0:3,0] = 1
  mat[0:3, 1] = np.sin(n*k)
  mat[0:3, 2] = np.cos(n*k)
  inv_mat = np.linalg.inv(mat)
  c0A1A2 = array(np.matmul(dat[["n=26", "n=29", "n=31"]], np.transpose(inv_mat)))
  c0Aphi = c0A1A2
  c0Aphi[:,0] = c0A1A2[:,0]
  c0Aphi[:,1] = np.sqrt(c0A1A2[:,1]**2 + c0A1A2[:,2]**2)
  c0Aphi[:,2] <- np.sign(c0A1A2[:,2]) * np.arccos(c0A1A2[:,1]/c0Aphi[:,1])
  return c0Aphi[:,0]

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.process_time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.process_time() - self.epoch_time_start)
        
#### preparing data ####

data_cerevisiae_nucle = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle1.txt",delimiter = ",")
X1 = []
for sequence_nt in data_cerevisiae_nucle["Sequence"]:
    X1.append(diOneHot(sequence_nt))
X1 = array(X1)
X1 = X1.reshape((X1.shape[0],49,16,1))
X1_reverse = np.flip(X1,[1,2])
# Y1 = data_cerevisiae_nucle["C0"].values.astype(float)
Y1 = find_c0new(data_cerevisiae_nucle).astype(float)

# %%
data_random_library = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle3.txt",delimiter = ",")
X3 = []
for sequence_nt in data_random_library["Sequence"]:
    X3.append(diOneHot(sequence_nt))
X3 = array(X3)
X3 = X3.reshape((X3.shape[0],49,16,1))
X3_reverse = np.flip(X3,[1,2])
# Y3 = data_random_library["C0"].values.astype(float)
Y3 = find_c0new(data_random_library).astype(float)

# %%
data_tiling = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle5.txt",delimiter = ",")
X5 = []
for sequence_nt in data_tiling["Sequence"]:
    X5.append(diOneHot(sequence_nt))
X5 = array(X5)
X5 = X5.reshape((X5.shape[0],49,16,1))
X5_reverse = np.flip(X5,[1,2])
# Y5 = data_tiling["C0"].values.astype(float)
Y5 = find_c0new(data_tiling).astype(float)

# %%
data_chr5 = pd.read_csv("/Users/Brody1/Documents/Northwestern/DNA_Cyclizability/cycle6.txt",delimiter = ",")
X6 = []
for sequence_nt in data_chr5["Sequence"]:
    X6.append(diOneHot(sequence_nt))
X6 = array(X6)
X6 = X6.reshape((X6.shape[0],49,16,1))
X6_reverse = np.flip(X6,[1,2])
# Y6 = data_chr5["C0"].values.astype(float)
Y6 = find_c0new(data_chr5).astype(float)

# %%
#### tiling

VALIDATION_LOSS = []
fold_var = 1
n = Y5.shape[0]

fits = []
detrend = []
times = []
times2 = []

for train_index, val_index in kf.split(Y5):
    training_X = X5[train_index]
    training_X_reverse = X5_reverse[train_index]
    validation_X = X5[val_index]
    validation_X_reverse = X5_reverse[val_index]
    training_Y = Y5[train_index]
    validation_Y = Y5[val_index]
    # CREATE NEW MODEL
    model = model_cycle()
    # CREATE CALLBACKS
    checkpoint = callbacks.ModelCheckpoint(save_path + model_name+"_tiling_"+str(fold_var)+".h5",
                                                    monitor='val_loss', verbose=1,
                                                    save_best_only=True, mode='min')
    time_callback = TimeHistory()

    history = model.fit(training_X, training_Y,
                        epochs=num_epochs,
                        callbacks= [checkpoint, time_callback],
                        validation_data=(validation_X, validation_Y))
    model.load_weights(save_path + model_name+"_tiling_"+str(fold_var)+".h5")
    model.save(save_path+model_name+"_tiling_"+str(fold_var),save_traces=False)
    times.append(time_callback.times)

    pred_Y = model.predict(training_X)
    pred_Y = pred_Y.reshape(pred_Y.shape[0])
    pred_Y_reverse = model.predict(training_X_reverse)
    pred_Y_reverse = pred_Y_reverse.reshape(pred_Y_reverse.shape[0])
    pred_Y = (pred_Y+pred_Y_reverse)/2
    reg =  LinearRegression().fit(array(pred_Y).reshape(-1, 1), array(training_Y).reshape(-1, 1))
    
    detrend_int = reg.intercept_
    detrend_slope = reg.coef_
    detrend.append([float(detrend_int), float(detrend_slope)])

    start_time = time.process_time()
    fit = model.predict(X1)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X1_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y1)[0,1],np.mean(np.square(fit-Y1)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X3)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X3_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y3)[0,1],np.mean(np.square(fit-Y3)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(validation_X)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(validation_X_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, validation_Y)[0,1],np.mean(np.square(fit-validation_Y)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    start_time = time.process_time()
    fit = model.predict(X6)
    fit = fit.reshape(fit.shape[0])
    fit_reverse = model.predict(X6_reverse)
    fit_reverse = fit_reverse.reshape(fit_reverse.shape[0])
    reverse_corr = np.corrcoef(fit, fit_reverse)[0,1]
    fit = (fit + fit_reverse)/2
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    fits.append(fit_tmp)
    fit = detrend_int + fit * detrend_slope
    fit = fit.flatten()
    fit_tmp =[np.corrcoef(fit, Y6)[0,1],np.mean(np.square(fit-Y6)),np.mean(fit),np.std(fit),reverse_corr]
    time0 = time.process_time() - start_time
    times2.append([time0])
    fits.append(fit_tmp)
    
    K.clear_session()
    fold_var += 1
    
detrend = array(detrend)
detrend = pd.DataFrame(detrend)
detrend.to_csv(save_path +model_name+"_detrend_tiling.txt", index = False)

fits = array(fits)
fits = pd.DataFrame((fits))
fits.to_csv(save_path +model_name+ "_fits_tiling.txt", index = False)

with open(save_path +model_name+"_time_tiling.txt", "w") as file:
    for row in times:
        s = " ".join(map(str, row))
        file.write(s+'\n')

with open(save_path +model_name+"_pred_time_tiling.txt", "w") as file:
    for row in times2:
        s = " ".join(map(str, row))
        file.write(s+'\n')
# Out:
# Epoch 1/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.2001
# Epoch 1: val_loss improved from inf to 0.15554, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_1.h5
# 2317/2317 [==============================] - 19s 8ms/step - loss: 0.2001 - val_loss: 0.1555
# Epoch 2/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1518
# Epoch 2: val_loss improved from 0.15554 to 0.13605, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_1.h5
# 2317/2317 [==============================] - 16s 7ms/step - loss: 0.1519 - val_loss: 0.1361
# Epoch 3/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1462
# Epoch 3: val_loss improved from 0.13605 to 0.13203, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_1.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1461 - val_loss: 0.1320
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1422
# Epoch 4: val_loss improved from 0.13203 to 0.13110, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_1.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1422 - val_loss: 0.1311
# Epoch 5/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1386
# Epoch 5: val_loss improved from 0.13110 to 0.12810, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_1.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1386 - val_loss: 0.1281
# Epoch 6/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1366
# Epoch 6: val_loss improved from 0.12810 to 0.12477, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_1.h5
# 2317/2317 [==============================] - 16s 7ms/step - loss: 0.1365 - val_loss: 0.1248
# Epoch 7/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1355
# Epoch 7: val_loss improved from 0.12477 to 0.12460, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_1.h5
# 2317/2317 [==============================] - 19s 8ms/step - loss: 0.1354 - val_loss: 0.1246
# Epoch 8/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1333
# Epoch 8: val_loss improved from 0.12460 to 0.12311, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_1.h5
# 2317/2317 [==============================] - 18s 8ms/step - loss: 0.1334 - val_loss: 0.1231
# Epoch 9/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1325
# Epoch 9: val_loss did not improve from 0.12311
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.1325 - val_loss: 0.1244
# Epoch 10/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1320
# Epoch 10: val_loss improved from 0.12311 to 0.12104, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_1.h5
# 2317/2317 [==============================] - 17s 7ms/step - loss: 0.1321 - val_loss: 0.1210
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_1/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_1/assets
# 2317/2317 [==============================] - 5s 2ms/step
# 2317/2317 [==============================] - 5s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# Epoch 1/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1964
# Epoch 1: val_loss improved from inf to 0.13288, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_2.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.1963 - val_loss: 0.1329
# Epoch 2/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1432
# Epoch 2: val_loss improved from 0.13288 to 0.12852, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_2.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1432 - val_loss: 0.1285
# Epoch 3/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1389
# Epoch 3: val_loss improved from 0.12852 to 0.12641, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_2.h5
# 2317/2317 [==============================] - 11s 5ms/step - loss: 0.1389 - val_loss: 0.1264
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1355
# Epoch 4: val_loss improved from 0.12641 to 0.12337, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_2.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1355 - val_loss: 0.1234
# Epoch 5/10
# 2304/2317 [============================>.] - ETA: 0s - loss: 0.1333
# Epoch 5: val_loss improved from 0.12337 to 0.11908, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_2.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1335 - val_loss: 0.1191
# Epoch 6/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1317
# Epoch 6: val_loss did not improve from 0.11908
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1317 - val_loss: 0.1233
# Epoch 7/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1304
# Epoch 7: val_loss improved from 0.11908 to 0.11786, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_2.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1303 - val_loss: 0.1179
# Epoch 8/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1294
# Epoch 8: val_loss did not improve from 0.11786
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1294 - val_loss: 0.1194
# Epoch 9/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1289
# Epoch 9: val_loss improved from 0.11786 to 0.11689, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_2.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1289 - val_loss: 0.1169
# Epoch 10/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1279
# Epoch 10: val_loss did not improve from 0.11689
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1279 - val_loss: 0.1212
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_2/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_2/assets
# 2317/2317 [==============================] - 4s 2ms/step
# 2317/2317 [==============================] - 4s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# Epoch 1/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1934
# Epoch 1: val_loss improved from inf to 0.14108, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_3.h5
# 2317/2317 [==============================] - 15s 7ms/step - loss: 0.1934 - val_loss: 0.1411
# Epoch 2/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1422
# Epoch 2: val_loss improved from 0.14108 to 0.12987, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_3.h5
# 2317/2317 [==============================] - 15s 6ms/step - loss: 0.1422 - val_loss: 0.1299
# Epoch 3/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1356
# Epoch 3: val_loss improved from 0.12987 to 0.12679, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_3.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1356 - val_loss: 0.1268
# Epoch 4/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1321
# Epoch 4: val_loss did not improve from 0.12679
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1322 - val_loss: 0.1276
# Epoch 5/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1304
# Epoch 5: val_loss improved from 0.12679 to 0.12322, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_3.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1304 - val_loss: 0.1232
# Epoch 6/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1294
# Epoch 6: val_loss did not improve from 0.12322
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1294 - val_loss: 0.1235
# Epoch 7/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1272
# Epoch 7: val_loss improved from 0.12322 to 0.12024, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_3.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1272 - val_loss: 0.1202
# Epoch 8/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1261
# Epoch 8: val_loss did not improve from 0.12024
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1261 - val_loss: 0.1219
# Epoch 9/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1246
# Epoch 9: val_loss improved from 0.12024 to 0.11964, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_3.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1246 - val_loss: 0.1196
# Epoch 10/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1244
# Epoch 10: val_loss did not improve from 0.11964
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1244 - val_loss: 0.1207
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_3/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_3/assets
# 2317/2317 [==============================] - 5s 2ms/step
# 2317/2317 [==============================] - 5s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# Epoch 1/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1931
# Epoch 1: val_loss improved from inf to 0.13845, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_4.h5
# 2317/2317 [==============================] - 14s 6ms/step - loss: 0.1929 - val_loss: 0.1384
# Epoch 2/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1458
# Epoch 2: val_loss improved from 0.13845 to 0.13159, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_4.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1458 - val_loss: 0.1316
# Epoch 3/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1411
# Epoch 3: val_loss improved from 0.13159 to 0.12903, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_4.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1411 - val_loss: 0.1290
# Epoch 4/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1380
# Epoch 4: val_loss improved from 0.12903 to 0.12803, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1380 - val_loss: 0.1280
# Epoch 5/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1358
# Epoch 5: val_loss improved from 0.12803 to 0.12548, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1357 - val_loss: 0.1255
# Epoch 6/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1351
# Epoch 6: val_loss improved from 0.12548 to 0.12460, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_4.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1351 - val_loss: 0.1246
# Epoch 7/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1332
# Epoch 7: val_loss did not improve from 0.12460
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1332 - val_loss: 0.1246
# Epoch 8/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1326
# Epoch 8: val_loss improved from 0.12460 to 0.12303, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_4.h5
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1326 - val_loss: 0.1230
# Epoch 9/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1321
# Epoch 9: val_loss did not improve from 0.12303
# 2317/2317 [==============================] - 13s 6ms/step - loss: 0.1320 - val_loss: 0.1236
# Epoch 10/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1310
# Epoch 10: val_loss did not improve from 0.12303
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1311 - val_loss: 0.1232
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_4/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_4/assets
# 2317/2317 [==============================] - 4s 2ms/step
# 2317/2317 [==============================] - 5s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 623/623 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 390/390 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 258/258 [==============================] - 1s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# 2576/2576 [==============================] - 5s 2ms/step
# Epoch 1/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1998
# Epoch 1: val_loss improved from inf to 0.14533, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_5.h5
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1995 - val_loss: 0.1453
# Epoch 2/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1471
# Epoch 2: val_loss improved from 0.14533 to 0.13229, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_5.h5
# 2317/2317 [==============================] - 12s 5ms/step - loss: 0.1471 - val_loss: 0.1323
# Epoch 3/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1409
# Epoch 3: val_loss did not improve from 0.13229
# 2317/2317 [==============================] - 13s 5ms/step - loss: 0.1408 - val_loss: 0.1360
# Epoch 4/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1378
# Epoch 4: val_loss improved from 0.13229 to 0.12675, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1378 - val_loss: 0.1268
# Epoch 5/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1362
# Epoch 5: val_loss improved from 0.12675 to 0.12671, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_5.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1362 - val_loss: 0.1267
# Epoch 6/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1349
# Epoch 6: val_loss did not improve from 0.12671
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1349 - val_loss: 0.1270
# Epoch 7/10
# 2304/2317 [============================>.] - ETA: 0s - loss: 0.1324
# Epoch 7: val_loss improved from 0.12671 to 0.12474, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_5.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1324 - val_loss: 0.1247
# Epoch 8/10
# 2316/2317 [============================>.] - ETA: 0s - loss: 0.1320
# Epoch 8: val_loss did not improve from 0.12474
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1320 - val_loss: 0.1248
# Epoch 9/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1314
# Epoch 9: val_loss improved from 0.12474 to 0.12410, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_5.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1314 - val_loss: 0.1241
# Epoch 10/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1309
# Epoch 10: val_loss did not improve from 0.12410
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1309 - val_loss: 0.1251
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_5/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_5/assets
# 2317/2317 [==============================] - 2s 913us/step
# 2317/2317 [==============================] - 2s 974us/step
# 623/623 [==============================] - 1s 896us/step
# 623/623 [==============================] - 1s 927us/step
# 390/390 [==============================] - 0s 917us/step
# 390/390 [==============================] - 0s 900us/step
# 258/258 [==============================] - 0s 894us/step
# 258/258 [==============================] - 0s 901us/step
# 2576/2576 [==============================] - 2s 943us/step
# 2576/2576 [==============================] - 2s 905us/step
# Epoch 1/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1926
# Epoch 1: val_loss improved from inf to 0.13777, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_6.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1926 - val_loss: 0.1378
# Epoch 2/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1434
# Epoch 2: val_loss improved from 0.13777 to 0.13010, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_6.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1434 - val_loss: 0.1301
# Epoch 3/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1373
# Epoch 3: val_loss did not improve from 0.13010
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1373 - val_loss: 0.1323
# Epoch 4/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1343
# Epoch 4: val_loss improved from 0.13010 to 0.12739, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_6.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1342 - val_loss: 0.1274
# Epoch 5/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1320
# Epoch 5: val_loss improved from 0.12739 to 0.12620, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_6.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1320 - val_loss: 0.1262
# Epoch 6/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1299
# Epoch 6: val_loss improved from 0.12620 to 0.12112, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_6.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1300 - val_loss: 0.1211
# Epoch 7/10
# 2299/2317 [============================>.] - ETA: 0s - loss: 0.1284
# Epoch 7: val_loss improved from 0.12112 to 0.11982, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_6.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1286 - val_loss: 0.1198
# Epoch 8/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1279
# Epoch 8: val_loss improved from 0.11982 to 0.11926, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_6.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1280 - val_loss: 0.1193
# Epoch 9/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1276
# Epoch 9: val_loss did not improve from 0.11926
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1277 - val_loss: 0.1200
# Epoch 10/10
# 2310/2317 [============================>.] - ETA: 0s - loss: 0.1256
# Epoch 10: val_loss improved from 0.11926 to 0.11708, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_6.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1256 - val_loss: 0.1171
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_6/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_6/assets
# 2317/2317 [==============================] - 2s 947us/step
# 2317/2317 [==============================] - 2s 1ms/step
# 623/623 [==============================] - 1s 925us/step
# 623/623 [==============================] - 1s 960us/step
# 390/390 [==============================] - 0s 909us/step
# 390/390 [==============================] - 0s 925us/step
# 258/258 [==============================] - 0s 903us/step
# 258/258 [==============================] - 0s 909us/step
# 2576/2576 [==============================] - 2s 910us/step
# 2576/2576 [==============================] - 2s 919us/step
# Epoch 1/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1975
# Epoch 1: val_loss improved from inf to 0.13747, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_7.h5
# 2317/2317 [==============================] - 8s 3ms/step - loss: 0.1974 - val_loss: 0.1375
# Epoch 2/10
# 2303/2317 [============================>.] - ETA: 0s - loss: 0.1431
# Epoch 2: val_loss improved from 0.13747 to 0.12863, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_7.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1431 - val_loss: 0.1286
# Epoch 3/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1361
# Epoch 3: val_loss improved from 0.12863 to 0.12298, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_7.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1361 - val_loss: 0.1230
# Epoch 4/10
# 2301/2317 [============================>.] - ETA: 0s - loss: 0.1335
# Epoch 4: val_loss did not improve from 0.12298
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1334 - val_loss: 0.1256
# Epoch 5/10
# 2301/2317 [============================>.] - ETA: 0s - loss: 0.1313
# Epoch 5: val_loss did not improve from 0.12298
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1312 - val_loss: 0.1239
# Epoch 6/10
# 2306/2317 [============================>.] - ETA: 0s - loss: 0.1297
# Epoch 6: val_loss improved from 0.12298 to 0.12112, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_7.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1296 - val_loss: 0.1211
# Epoch 7/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1283
# Epoch 7: val_loss improved from 0.12112 to 0.11841, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_7.h5
# 2317/2317 [==============================] - 15s 7ms/step - loss: 0.1283 - val_loss: 0.1184
# Epoch 8/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1262
# Epoch 8: val_loss improved from 0.11841 to 0.11819, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_7.h5
# 2317/2317 [==============================] - 10s 4ms/step - loss: 0.1262 - val_loss: 0.1182
# Epoch 9/10
# 2300/2317 [============================>.] - ETA: 0s - loss: 0.1261
# Epoch 9: val_loss improved from 0.11819 to 0.11559, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_7.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1262 - val_loss: 0.1156
# Epoch 10/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1252
# Epoch 10: val_loss did not improve from 0.11559
# 2317/2317 [==============================] - 8s 3ms/step - loss: 0.1251 - val_loss: 0.1176
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_7/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_7/assets
# 2317/2317 [==============================] - 2s 1ms/step
# 2317/2317 [==============================] - 2s 977us/step
# 623/623 [==============================] - 1s 907us/step
# 623/623 [==============================] - 1s 904us/step
# 390/390 [==============================] - 0s 911us/step
# 390/390 [==============================] - 0s 901us/step
# 258/258 [==============================] - 0s 908us/step
# 258/258 [==============================] - 0s 989us/step
# 2576/2576 [==============================] - 2s 919us/step
# 2576/2576 [==============================] - 2s 929us/step
# Epoch 1/10
# 2307/2317 [============================>.] - ETA: 0s - loss: 0.1951
# Epoch 1: val_loss improved from inf to 0.13616, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_8.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1949 - val_loss: 0.1362
# Epoch 2/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1414
# Epoch 2: val_loss improved from 0.13616 to 0.13400, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_8.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1413 - val_loss: 0.1340
# Epoch 3/10
# 2312/2317 [============================>.] - ETA: 0s - loss: 0.1375
# Epoch 3: val_loss improved from 0.13400 to 0.12585, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_8.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1375 - val_loss: 0.1259
# Epoch 4/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1346
# Epoch 4: val_loss improved from 0.12585 to 0.12443, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_8.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1347 - val_loss: 0.1244
# Epoch 5/10
# 2303/2317 [============================>.] - ETA: 0s - loss: 0.1325
# Epoch 5: val_loss did not improve from 0.12443
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1326 - val_loss: 0.1325
# Epoch 6/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1308
# Epoch 6: val_loss improved from 0.12443 to 0.12240, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_8.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1308 - val_loss: 0.1224
# Epoch 7/10
# 2308/2317 [============================>.] - ETA: 0s - loss: 0.1297
# Epoch 7: val_loss did not improve from 0.12240
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1297 - val_loss: 0.1247
# Epoch 8/10
# 2303/2317 [============================>.] - ETA: 0s - loss: 0.1288
# Epoch 8: val_loss did not improve from 0.12240
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1287 - val_loss: 0.1234
# Epoch 9/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1286
# Epoch 9: val_loss did not improve from 0.12240
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1287 - val_loss: 0.1245
# Epoch 10/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1278
# Epoch 10: val_loss improved from 0.12240 to 0.12112, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_8.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1278 - val_loss: 0.1211
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_8/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_8/assets
# 2317/2317 [==============================] - 2s 1ms/step
# 2317/2317 [==============================] - 2s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 913us/step
# 258/258 [==============================] - 0s 962us/step
# 258/258 [==============================] - 0s 905us/step
# 2576/2576 [==============================] - 3s 999us/step
# 2576/2576 [==============================] - 3s 983us/step
# Epoch 1/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1930
# Epoch 1: val_loss improved from inf to 0.14244, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_9.h5
# 2317/2317 [==============================] - 8s 3ms/step - loss: 0.1929 - val_loss: 0.1424
# Epoch 2/10
# 2313/2317 [============================>.] - ETA: 0s - loss: 0.1421
# Epoch 2: val_loss improved from 0.14244 to 0.13236, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_9.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1422 - val_loss: 0.1324
# Epoch 3/10
# 2317/2317 [==============================] - ETA: 0s - loss: 0.1361
# Epoch 3: val_loss improved from 0.13236 to 0.12616, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_9.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1361 - val_loss: 0.1262
# Epoch 4/10
# 2299/2317 [============================>.] - ETA: 0s - loss: 0.1329
# Epoch 4: val_loss improved from 0.12616 to 0.12376, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_9.h5
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1330 - val_loss: 0.1238
# Epoch 5/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1306
# Epoch 5: val_loss did not improve from 0.12376
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1306 - val_loss: 0.1241
# Epoch 6/10
# 2299/2317 [============================>.] - ETA: 0s - loss: 0.1293
# Epoch 6: val_loss improved from 0.12376 to 0.12294, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_9.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1294 - val_loss: 0.1229
# Epoch 7/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1272
# Epoch 7: val_loss improved from 0.12294 to 0.12103, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_9.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1272 - val_loss: 0.1210
# Epoch 8/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1270
# Epoch 8: val_loss did not improve from 0.12103
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1270 - val_loss: 0.1218
# Epoch 9/10
# 2302/2317 [============================>.] - ETA: 0s - loss: 0.1265
# Epoch 9: val_loss improved from 0.12103 to 0.12008, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_9.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1265 - val_loss: 0.1201
# Epoch 10/10
# 2303/2317 [============================>.] - ETA: 0s - loss: 0.1258
# Epoch 10: val_loss did not improve from 0.12008
# 2317/2317 [==============================] - 6s 3ms/step - loss: 0.1257 - val_loss: 0.1203
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_9/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_9/assets
# 2317/2317 [==============================] - 2s 981us/step
# 2317/2317 [==============================] - 3s 1ms/step
# 623/623 [==============================] - 1s 1ms/step
# 623/623 [==============================] - 1s 931us/step
# 390/390 [==============================] - 0s 1ms/step
# 390/390 [==============================] - 0s 969us/step
# 258/258 [==============================] - 0s 951us/step
# 258/258 [==============================] - 0s 953us/step
# 2576/2576 [==============================] - 3s 988us/step
# 2576/2576 [==============================] - 3s 1ms/step
# Epoch 1/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1936
# Epoch 1: val_loss improved from inf to 0.13779, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_10.h5
# 2317/2317 [==============================] - 8s 3ms/step - loss: 0.1933 - val_loss: 0.1378
# Epoch 2/10
# 2299/2317 [============================>.] - ETA: 0s - loss: 0.1433
# Epoch 2: val_loss improved from 0.13779 to 0.13183, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_10.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1433 - val_loss: 0.1318
# Epoch 3/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1392
# Epoch 3: val_loss improved from 0.13183 to 0.12828, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_10.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1392 - val_loss: 0.1283
# Epoch 4/10
# 2305/2317 [============================>.] - ETA: 0s - loss: 0.1350
# Epoch 4: val_loss improved from 0.12828 to 0.12507, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_10.h5
# 2317/2317 [==============================] - 9s 4ms/step - loss: 0.1350 - val_loss: 0.1251
# Epoch 5/10
# 2301/2317 [============================>.] - ETA: 0s - loss: 0.1337
# Epoch 5: val_loss did not improve from 0.12507
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1337 - val_loss: 0.1256
# Epoch 6/10
# 2309/2317 [============================>.] - ETA: 0s - loss: 0.1322
# Epoch 6: val_loss improved from 0.12507 to 0.12225, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_10.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1322 - val_loss: 0.1222
# Epoch 7/10
# 2315/2317 [============================>.] - ETA: 0s - loss: 0.1306
# Epoch 7: val_loss did not improve from 0.12225
# 2317/2317 [==============================] - 8s 3ms/step - loss: 0.1307 - val_loss: 0.1265
# Epoch 8/10
# 2314/2317 [============================>.] - ETA: 0s - loss: 0.1297
# Epoch 8: val_loss did not improve from 0.12225
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1297 - val_loss: 0.1234
# Epoch 9/10
# 2299/2317 [============================>.] - ETA: 0s - loss: 0.1282
# Epoch 9: val_loss improved from 0.12225 to 0.12212, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_10.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1283 - val_loss: 0.1221
# Epoch 10/10
# 2311/2317 [============================>.] - ETA: 0s - loss: 0.1281
# Epoch 10: val_loss improved from 0.12212 to 0.12020, saving model to /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_10.h5
# 2317/2317 [==============================] - 7s 3ms/step - loss: 0.1281 - val_loss: 0.1202
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_10/assets
# INFO:tensorflow:Assets written to: /Users/Brody1/Documents/Northwestern/DNA_Cyclizability/benchmarks/deep-learning/conv_only_di_tiling_10/assets
# 2317/2317 [==============================] - 2s 973us/step
# 2317/2317 [==============================] - 2s 938us/step
# 623/623 [==============================] - 1s 979us/step
# 623/623 [==============================] - 1s 942us/step
# 390/390 [==============================] - 0s 978us/step
# 390/390 [==============================] - 0s 920us/step
# 258/258 [==============================] - 0s 984us/step
# 258/258 [==============================] - 0s 911us/step
# 2576/2576 [==============================] - 3s 983us/step
# 2576/2576 [==============================] - 3s 1ms/step

# %%
display_fits(fits)
# Out:
# Average correlation on tiling: 0.67426231755881
# Average MSE on tiling: 0.13214937320980397
# Average correlation on random: 0.6230225236672291
# Average MSE on random: 0.0889255883408688
# Average correlation on ChrV: 0.5436017179109801
# Average MSE on ChrV: 0.20532247836800482
# Average correlation on CN: 0.6064081103873904
# Average MSE on CN: 0.1396598564199207

# %%
first_conv_model = Model(inputs = model.input, outputs = model.layers[1].output)
first_conv_output = first_conv_model.predict(X5)
pd.DataFrame(first_conv_output.reshape(first_conv_output.shape[0], -1)).to_csv(save_path + model_name+"_tiling_tiling_first_conv_output")
first_conv_output_random = first_conv_model.predict(X3)
pd.DataFrame(first_conv_output_random.reshape(first_conv_output_random.shape[0], -1)).to_csv(save_path + model_name+"_tiling_random_first_conv_output")
# Out:
# 2574/2574 [==============================] - 3s 1ms/step
# 390/390 [==============================] - 0s 1ms/step

# %%
first_conv_weights = model.layers[1].weights[0]
first_conv_biases = model.layers[1].weights[1]
# Format: [Position 0: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT  Position 1: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT,
# ..., Position 20: AAA, AAC, ..., CAA, CAC, ..., TTG, TTT]
pd.DataFrame(array(first_conv_weights).transpose((3,2,0,1)).reshape(first_conv_weights.shape[-1], -1)).to_csv(save_path + model_name+"_tiling_first_conv_kernels")
pd.DataFrame(first_conv_biases).to_csv(save_path + model_name+"_tiling_first_conv_biases")
